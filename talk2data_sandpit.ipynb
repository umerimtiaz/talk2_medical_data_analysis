# %%
"""
Copyright 2024 USF Australia

Licensed under the MIT License

Author: Umer Imtiaz - umer.imiaz@gmail.com
Date: 24/8/2024
Version: 0.00
Code type: Alpha

This file contains the implementation of talk2 algorithm
work with memory and conversation. This will be hosted on the
umerai.com website as a product demo.

reference is the link below
https://python.langchain.com/v0.2/docs/tutorials/qa_chat_history/
"""
# Out:
# '\nCopyright 2024 USF Australia\n\nLicensed under the MIT License\n\nAuthor: Umer Imtiaz - umer.imiaz@gmail.com\nDate: 24/8/2024\nVersion: 0.00\nCode type: Alpha\n\nThis file contains the implementation of talk2 algorithm\nwork with memory and conversation. This will be hosted on the\numerai.com website as a product demo.\n\nreference is the link below\nhttps://python.langchain.com/v0.2/docs/tutorials/qa_chat_history/\n'

# %% [markdown]
# ### Step 1: Loading the keys from a "keys.config" file

# %%
# ensuring safe programming
try:
    with open('keys.env', 'r', encoding="utf-8") as keys_file:
        key_lines = keys_file.readlines()
        keys_dict = dict(line.strip().split('=') for line in key_lines)
except FileNotFoundError:
    print("Error: keys.config file not found")
    exit()
except Exception as e:
    print (f"Error: An error occured while reading keys.config file: {e}")
    exit()

#print(f"dict = {keys_dict}")

# %%
#open the config file to read openai and langchain keys
# with open('keys.config', 'r', encoding="utf-8") as keys_file:
#     key_lines = keys_file.readlines()
#     keys_dict = dict(line.strip().split('=') for line in key_lines)

#loading values in the variables
try:
    openapi_key = keys_dict['openapi_key']
    # print(f"openapi_key={openapi_key}")
except KeyError:
    # print(f"Error: '{openapi_key}' not found in keys.config")
    print("Error: OPENAI key not found")

try:
    langchain_key = keys_dict['langchain_key']
    # print(f"langchain_key={langchain_key}")
except KeyError:
    # print(f"Error: '{langchain_key}' not found in keys.config")
    print("Error: langchain key not found - Langsmith traces will not log")

# %%
import openai
import os
from langchain_openai import ChatOpenAI

#setting the enviornment variables with the openai key values
os.environ['OPENAI_API_KEY'] = openapi_key
openai.api_key  = os.getenv('OPENAI_API_KEY')

""" print(os.environ['OPENAI_API_KEY']) """
# Out:
# " print(os.environ['OPENAI_API_KEY']) "

# %%
# setting the enviornment variables with langchain key values
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = langchain_key

""" print(os.environ['LANGCHAIN_API_KEY']) """
# Out:
# " print(os.environ['LANGCHAIN_API_KEY']) "

# %%
"""
This code takes a list of langchain Document objects and print. 
The document has two components page_contect->str and metadata->dict 
"""
def print_list_of_documents(loader_docs):
    counter=0
    print(loader_docs.__class__)
    for data in loader_docs:
        counter += 1
        print(f"\n\n{counter} {data.__class__}: {data}")
        # for key, val in data.items():
        #     print(f"\nkey: {key} ; value: {val}")
    counter = 0

# %% [markdown]
# ### Step 2: Load the data from the sources

# %%
# Data source 1/4
# load data from the website
# reference : https://python.langchain.com/v0.1/docs/use_cases/web_scraping/

from langchain_community.document_loaders import WebBaseLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
# important variables
url_uci = "https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic"

#Step 2.1: Web page loading using a url or list of urls

web_page = WebBaseLoader(url_uci)
web_page_loader = web_page.load()
# print(web_page_loader.__class__)
# print(web_loader)
#Step 2.2: converting html page to (a document base object type) 
# simple text page with meta as dict, and page_content
#It's best suited for scenarios where the goal is to extract human-readable text 
# without needing to manipulate specific HTML elements.
""" from langchain_community.document_transformers import Html2TextTransformer

html2text = Html2TextTransformer()
web_docs2text = html2text.transform_documents(web_loader)
print(f"page contents: {web_docs2text[0].page_content[0:500]}")
print(f" meta data: {web_docs2text[0].metadata}")

for key, value in web_docs2text[0].metadata.items():
    print(f"\n{key}:{value}")
 """
#spliting Document object to smaller document objects 
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 500, chunk_overlap=100, length_function=len, is_separator_regex=False)
web_page_loader_docs = text_splitter.split_documents(web_page_loader)

#displaying Documents in the list of the documents
#print_list_of_documents(web_page_loader_docs)

# %% [markdown]
# ### step 3: saving in data base

# %%
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings
from langchain_openai import ChatOpenAI

#LLM modlel type - https://platform.openai.com/docs/models/gpt-4o-mini
llm = ChatOpenAI(model="gpt-4o-mini")
#Embedding model type
embdedding = OpenAIEmbeddings(model="text-embedding-3-large")
#setting up database store
vector_store = Chroma(collection_name="dpad_talk2data", embedding_function=embdedding, persist_directory="./chroma_langchain_db")

documents= web_page_loader_docs

# %%
# adding documents with unique ids of each
from uuid import uuid4

uuids = [str(uuid4()) for _ in range(len(documents))] # "_" can be "x", it does not matter. It is not used, anyway
print(uuids.__class__, len(uuids), uuids)
# Out:
# <class 'list'> 17 ['0d7062bf-6a55-4aa3-9fc7-3cf8b8b529ac', '7890ac3a-274e-4f8b-b770-58008e4b82d1', '8bbf2a1a-6fc6-4ebf-9ffb-0a8790cf84a2', '15448b60-4e2c-4dce-adc6-73455f216cea', 'dcc54eeb-2b00-4d4e-aa52-8b6fd6c8182f', 'a3006cb1-7486-403c-b0fd-4f6a64206cc1', 'e72c506e-a15f-41f0-8386-d121a34fab42', 'bbb78aa9-9233-4151-b1e8-105bbd64ee65', '9f6f1a2b-2089-485a-87db-9b47f9be109b', '289ab5cf-7d0a-4a07-a807-c2f194a19ed0', '0f24a7ad-8e46-462c-bc64-adb601c81a6b', '27d2c363-7908-4758-995a-f9c6867cb181', '2e9e92a0-86bb-43c9-b1b9-7cdf793d27c6', 'abe4a926-ef47-497a-8af8-4c52fcc34637', 'f144fdb9-582c-4430-b18b-7eb480f8f0ac', '0fc6b095-3c85-4562-9b7b-f8570df30ae3', 'ec37ff19-fdfe-4379-b7ae-814daa529095']

# %%
# step 2: Interacting - adding, storing, updating - playaround with the data
# storing data in chroma_langchain_db collection name is dpad_talk2data
# https://platform.openai.com/docs/models
#vector_store.from_documents(documents=documents,embedding=embdedding, ids=uuids)
vector_store.add_documents(documents=documents,embeddings=embdedding, ids=uuids)
# Out:
# ['0d7062bf-6a55-4aa3-9fc7-3cf8b8b529ac',
#  '7890ac3a-274e-4f8b-b770-58008e4b82d1',
#  '8bbf2a1a-6fc6-4ebf-9ffb-0a8790cf84a2',
#  '15448b60-4e2c-4dce-adc6-73455f216cea',
#  'dcc54eeb-2b00-4d4e-aa52-8b6fd6c8182f',
#  'a3006cb1-7486-403c-b0fd-4f6a64206cc1',
#  'e72c506e-a15f-41f0-8386-d121a34fab42',
#  'bbb78aa9-9233-4151-b1e8-105bbd64ee65',
#  '9f6f1a2b-2089-485a-87db-9b47f9be109b',
#  '289ab5cf-7d0a-4a07-a807-c2f194a19ed0',
#  '0f24a7ad-8e46-462c-bc64-adb601c81a6b',
#  '27d2c363-7908-4758-995a-f9c6867cb181',
#  '2e9e92a0-86bb-43c9-b1b9-7cdf793d27c6',
#  'abe4a926-ef47-497a-8af8-4c52fcc34637',
#  'f144fdb9-582c-4430-b18b-7eb480f8f0ac',
#  '0fc6b095-3c85-4562-9b7b-f8570df30ae3',
#  'ec37ff19-fdfe-4379-b7ae-814daa529095']

# %%
retriever = vector_store.as_retriever()

# %%
# 2. Incorporate the retriever into a question-answering chain.
system_prompt = (
    "You are an assistant for question-answering tasks. "
    "Use the following pieces of retrieved context to answer "
    "the question. If you don't know the answer, say that you "
    "don't know. Use three sentences maximum and keep the "
    "answer concise."
    "\n\n"
    "{context}"
)
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        ("human", "{input}"),
    ]
)

from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains import create_retrieval_chain
question_answer_chain = create_stuff_documents_chain(llm, prompt)
rag_chain = create_retrieval_chain(retriever, question_answer_chain)

# %%
response = rag_chain.invoke({"input": "What is Task Decomposition?"})
response["answer"]
#print(response)
# Out:
# "I don't know."

# %%
from langchain.chains import create_history_aware_retriever
from langchain_core.prompts import MessagesPlaceholder

contextualize_q_system_prompt = (
    "Given a chat history and the latest user question "
    "which might reference context in the chat history, "
    "formulate a standalone question which can be understood "
    "without the chat history. Do NOT answer the question, "
    "just reformulate it if needed and otherwise return it as is."
)

contextualize_q_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", contextualize_q_system_prompt),
        MessagesPlaceholder("chat_history"),
        ("human", "{input}"),
    ]
)
history_aware_retriever = create_history_aware_retriever(
    llm, retriever, contextualize_q_prompt
)

# %%
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain

qa_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        MessagesPlaceholder("chat_history"),
        ("human", "{input}"),
    ]
)


question_answer_chain = create_stuff_documents_chain(llm, qa_prompt)

rag_chain = create_retrieval_chain(history_aware_retriever, question_answer_chain)

# %%
from langchain_core.messages import AIMessage, HumanMessage

chat_history = []

question = "provide me the list of parameters of breast cancer prognosis?"
ai_msg_1 = rag_chain.invoke({"input": question, "chat_history": chat_history})
print(ai_msg_1["answer"])
chat_history.extend(
    [
        HumanMessage(content=question),
        AIMessage(content=ai_msg_1["answer"]),
    ]
)

second_question = "Tell me more of R and how can we identify it?"
ai_msg_2 = rag_chain.invoke({"input": second_question, "chat_history": chat_history})

print(ai_msg_2["answer"])
# Out:
# The Breast Cancer Wisconsin (Prognostic) dataset contains 33 features, but specific parameters are not listed in the provided context. Generally, these parameters may include clinical measurements, tumor characteristics, and patient demographics. For an accurate list of parameters, you would need to refer to the dataset directly on the UCI Machine Learning Repository.
# In the context of the provided information, "R" stands for recurrent cases of breast cancer. Recurrent cases can typically be identified through the analysis of clinical data, including the patient's history of tumor recurrence, time to recur, and other clinical features that may indicate the likelihood of recurrence. Specific methods, such as the Recurrence Surface Approximation (RSA) model, help predict time to recur using both recurrent and nonrecurrent cases.

# %%
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

store = {}


def get_session_history(session_id: str) -> BaseChatMessageHistory:
    if session_id not in store:
        store[session_id] = ChatMessageHistory()
    return store[session_id]


conversational_rag_chain = RunnableWithMessageHistory(
    rag_chain,
    get_session_history,
    input_messages_key="input",
    history_messages_key="chat_history",
    output_messages_key="answer",
)

# %%
conversational_rag_chain.invoke(
    {"input": "What is Task Decomposition?"},
    config={
        "configurable": {"session_id": "abc123"}
    },  # constructs a key "abc123" in `store`.
)["answer"]
# Out:
# "I don't know."

# %%
conversational_rag_chain.invoke(
    {"input": "What are common ways of doing it?"},
    config={"configurable": {"session_id": "abc123"}},
)["answer"]
# Out:
# "I don't know."

# %%
for message in store["abc123"].messages:
    if isinstance(message, AIMessage):
        prefix = "AI"
    else:
        prefix = "User"

    print(f"{prefix}: {message.content}\n")
# Out:
# User: What is Task Decomposition?
#
# AI: I don't know.
#
# User: What are common ways of doing it?
#
# AI: I don't know.

# %%
print(type(response))
for key, val in response.items():
    print(key, val.__class__, val)
    if isinstance(val, list):
        for list_val in val:
            print(f"\nYES {list_val}\n")
# Out:
# <class 'dict'>
# input <class 'str'> What is Task Decomposition?
# context <class 'list'> [Document(metadata={'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}, page_content='The separation described above was obtained using Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree Construction Via Linear Programming." Proceedings of the 4th Midwest Artificial Intelligence and Cognitive Science Society, pp. 97-101, 1992], a classification method which uses linear programming to construct a decision tree.  Relevant features were selected using an exhaustive search in the space of 1-4 features and 1-3 separating planes.'), Document(metadata={'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}, page_content='The separation described above was obtained using Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree Construction Via Linear Programming." Proceedings of the 4th Midwest Artificial Intelligence and Cognitive Science Society, pp. 97-101, 1992], a classification method which uses linear programming to construct a decision tree.  Relevant features were selected using an exhaustive search in the space of 1-4 features and 1-3 separating planes.'), Document(metadata={'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}, page_content='The separation described above was obtained using Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree Construction Via Linear Programming." Proceedings of the 4th Midwest Artificial Intelligence and Cognitive Science Society, pp. 97-101, 1992], a classification method which uses linear programming to construct a decision tree.  Relevant features were selected using an exhaustive search in the space of 1-4 features and 1-3 separating planes.'), Document(metadata={'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}, page_content='The Recurrence Surface Approximation (RSA) method is a linear programming model which predicts Time To Recur using both recurrent and nonrecurrent cases.  See references (i) and (ii) above for details of the RSA method. \r\n\r\nThis database is also available through the UW CS ftp server:\r\n\r\nftp ftp.cs.wisc.edu')]
#
# YES page_content='The separation described above was obtained using Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree Construction Via Linear Programming." Proceedings of the 4th Midwest Artificial Intelligence and Cognitive Science Society, pp. 97-101, 1992], a classification method which uses linear programming to construct a decision tree.  Relevant features were selected using an exhaustive search in the space of 1-4 features and 1-3 separating planes.' metadata={'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}
#
#
# YES page_content='The separation described above was obtained using Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree Construction Via Linear Programming." Proceedings of the 4th Midwest Artificial Intelligence and Cognitive Science Society, pp. 97-101, 1992], a classification method which uses linear programming to construct a decision tree.  Relevant features were selected using an exhaustive search in the space of 1-4 features and 1-3 separating planes.' metadata={'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}
#
#
# YES page_content='The separation described above was obtained using Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree Construction Via Linear Programming." Proceedings of the 4th Midwest Artificial Intelligence and Cognitive Science Society, pp. 97-101, 1992], a classification method which uses linear programming to construct a decision tree.  Relevant features were selected using an exhaustive search in the space of 1-4 features and 1-3 separating planes.' metadata={'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}
#
#
# YES page_content='The Recurrence Surface Approximation (RSA) method is a linear programming model which predicts Time To Recur using both recurrent and nonrecurrent cases.  See references (i) and (ii) above for details of the RSA method.
#
# This database is also available through the UW CS ftp server:
#
# ftp ftp.cs.wisc.edu' metadata={'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}
#
# answer <class 'str'> I don't know.

# %%
response = rag_chain.invoke({"input": "provide me a list of parameters used in breast cancer machine learning?"})
response["answer"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 response = rag_chain.invoke({"input": "provide me a list of parameters used in breast cancer machine learning?"})
#       2 response["answer"]
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\base.py:5094, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5088 def invoke(
#    5089     self,
#    5090     input: Input,
#    5091     config: Optional[RunnableConfig] = None,
#    5092     **kwargs: Optional[Any],
#    5093 ) -> Output:
# -> 5094     return self.bound.invoke(
#    5095         input,
#    5096         self._merge_configs(config),
#    5097         **{**self.kwargs, **kwargs},
#    5098     )
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\base.py:2878, in RunnableSequence.invoke(self, input, config, **kwargs)
#    2876             input = context.run(step.invoke, input, config, **kwargs)
#    2877         else:
# -> 2878             input = context.run(step.invoke, input, config)
#    2879 # finish the root run
#    2880 except BaseException as e:
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\passthrough.py:495, in RunnableAssign.invoke(self, input, config, **kwargs)
#     489 def invoke(
#     490     self,
#     491     input: Dict[str, Any],
#     492     config: Optional[RunnableConfig] = None,
#     493     **kwargs: Any,
#     494 ) -> Dict[str, Any]:
# --> 495     return self._call_with_config(self._invoke, input, config, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\base.py:1785, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#    1781     context = copy_context()
#    1782     context.run(_set_config_context, child_config)
#    1783     output = cast(
#    1784         Output,
# -> 1785         context.run(
#    1786             call_func_with_variable_args,  # type: ignore[arg-type]
#    1787             func,  # type: ignore[arg-type]
#    1788             input,  # type: ignore[arg-type]
#    1789             config,
#    1790             run_manager,
#    1791             **kwargs,
#    1792         ),
#    1793     )
#    1794 except BaseException as e:
#    1795     run_manager.on_chain_error(e)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\config.py:397, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     395 if run_manager is not None and accepts_run_manager(func):
#     396     kwargs["run_manager"] = run_manager
# --> 397 return func(input, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\passthrough.py:482, in RunnableAssign._invoke(self, input, run_manager, config, **kwargs)
#     469 def _invoke(
#     470     self,
#     471     input: Dict[str, Any],
#    (...)
#     474     **kwargs: Any,
#     475 ) -> Dict[str, Any]:
#     476     assert isinstance(
#     477         input, dict
#     478     ), "The input to RunnablePassthrough.assign() must be a dict."
#     480     return {
#     481         **input,
# --> 482         **self.mapper.invoke(
#     483             input,
#     484             patch_config(config, callbacks=run_manager.get_child()),
#     485             **kwargs,
#     486         ),
#     487     }
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\base.py:3580, in RunnableParallel.invoke(self, input, config)
#    3575     with get_executor_for_config(config) as executor:
#    3576         futures = [
#    3577             executor.submit(_invoke_step, step, input, config, key)
#    3578             for key, step in steps.items()
#    3579         ]
# -> 3580         output = {key: future.result() for key, future in zip(steps, futures)}
#    3581 # finish the root run
#    3582 except BaseException as e:
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\base.py:3564, in RunnableParallel.invoke.<locals>._invoke_step(step, input, config, key)
#    3562 context = copy_context()
#    3563 context.run(_set_config_context, child_config)
# -> 3564 return context.run(
#    3565     step.invoke,
#    3566     input,
#    3567     child_config,
#    3568 )
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\base.py:5094, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5088 def invoke(
#    5089     self,
#    5090     input: Input,
#    5091     config: Optional[RunnableConfig] = None,
#    5092     **kwargs: Optional[Any],
#    5093 ) -> Output:
# -> 5094     return self.bound.invoke(
#    5095         input,
#    5096         self._merge_configs(config),
#    5097         **{**self.kwargs, **kwargs},
#    5098     )
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\base.py:2878, in RunnableSequence.invoke(self, input, config, **kwargs)
#    2876             input = context.run(step.invoke, input, config, **kwargs)
#    2877         else:
# -> 2878             input = context.run(step.invoke, input, config)
#    2879 # finish the root run
#    2880 except BaseException as e:
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\prompts\base.py:179, in BasePromptTemplate.invoke(self, input, config)
#     177 if self.tags:
#     178     config["tags"] = config["tags"] + self.tags
# --> 179 return self._call_with_config(
#     180     self._format_prompt_with_error_handling,
#     181     input,
#     182     config,
#     183     run_type="prompt",
#     184 )
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\base.py:1785, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#    1781     context = copy_context()
#    1782     context.run(_set_config_context, child_config)
#    1783     output = cast(
#    1784         Output,
# -> 1785         context.run(
#    1786             call_func_with_variable_args,  # type: ignore[arg-type]
#    1787             func,  # type: ignore[arg-type]
#    1788             input,  # type: ignore[arg-type]
#    1789             config,
#    1790             run_manager,
#    1791             **kwargs,
#    1792         ),
#    1793     )
#    1794 except BaseException as e:
#    1795     run_manager.on_chain_error(e)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\config.py:397, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     395 if run_manager is not None and accepts_run_manager(func):
#     396     kwargs["run_manager"] = run_manager
# --> 397 return func(input, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\prompts\base.py:153, in BasePromptTemplate._format_prompt_with_error_handling(self, inner_input)
#     152 def _format_prompt_with_error_handling(self, inner_input: Dict) -> PromptValue:
# --> 153     _inner_input = self._validate_input(inner_input)
#     154     return self.format_prompt(**_inner_input)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\prompts\base.py:145, in BasePromptTemplate._validate_input(self, inner_input)
#     143 missing = set(self.input_variables).difference(inner_input)
#     144 if missing:
# --> 145     raise KeyError(
#     146         f"Input to {self.__class__.__name__} is missing variables {missing}. "
#     147         f" Expected: {self.input_variables}"
#     148         f" Received: {list(inner_input.keys())}"
#     149     )
#     150 return inner_input
#
# KeyError: "Input to ChatPromptTemplate is missing variables {'chat_history'}.  Expected: ['chat_history', 'context', 'input'] Received: ['input', 'context']"

# %%
response = rag_chain.invoke({"input": "what was observed at the time of surgery?"})
response["answer"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 response = rag_chain.invoke({"input": "what was observed at the time of surgery?"})
#       2 response["answer"]
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\base.py:5094, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5088 def invoke(
#    5089     self,
#    5090     input: Input,
#    5091     config: Optional[RunnableConfig] = None,
#    5092     **kwargs: Optional[Any],
#    5093 ) -> Output:
# -> 5094     return self.bound.invoke(
#    5095         input,
#    5096         self._merge_configs(config),
#    5097         **{**self.kwargs, **kwargs},
#    5098     )
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\base.py:2878, in RunnableSequence.invoke(self, input, config, **kwargs)
#    2876             input = context.run(step.invoke, input, config, **kwargs)
#    2877         else:
# -> 2878             input = context.run(step.invoke, input, config)
#    2879 # finish the root run
#    2880 except BaseException as e:
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\passthrough.py:495, in RunnableAssign.invoke(self, input, config, **kwargs)
#     489 def invoke(
#     490     self,
#     491     input: Dict[str, Any],
#     492     config: Optional[RunnableConfig] = None,
#     493     **kwargs: Any,
#     494 ) -> Dict[str, Any]:
# --> 495     return self._call_with_config(self._invoke, input, config, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\base.py:1785, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#    1781     context = copy_context()
#    1782     context.run(_set_config_context, child_config)
#    1783     output = cast(
#    1784         Output,
# -> 1785         context.run(
#    1786             call_func_with_variable_args,  # type: ignore[arg-type]
#    1787             func,  # type: ignore[arg-type]
#    1788             input,  # type: ignore[arg-type]
#    1789             config,
#    1790             run_manager,
#    1791             **kwargs,
#    1792         ),
#    1793     )
#    1794 except BaseException as e:
#    1795     run_manager.on_chain_error(e)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\config.py:397, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     395 if run_manager is not None and accepts_run_manager(func):
#     396     kwargs["run_manager"] = run_manager
# --> 397 return func(input, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\passthrough.py:482, in RunnableAssign._invoke(self, input, run_manager, config, **kwargs)
#     469 def _invoke(
#     470     self,
#     471     input: Dict[str, Any],
#    (...)
#     474     **kwargs: Any,
#     475 ) -> Dict[str, Any]:
#     476     assert isinstance(
#     477         input, dict
#     478     ), "The input to RunnablePassthrough.assign() must be a dict."
#     480     return {
#     481         **input,
# --> 482         **self.mapper.invoke(
#     483             input,
#     484             patch_config(config, callbacks=run_manager.get_child()),
#     485             **kwargs,
#     486         ),
#     487     }
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\base.py:3580, in RunnableParallel.invoke(self, input, config)
#    3575     with get_executor_for_config(config) as executor:
#    3576         futures = [
#    3577             executor.submit(_invoke_step, step, input, config, key)
#    3578             for key, step in steps.items()
#    3579         ]
# -> 3580         output = {key: future.result() for key, future in zip(steps, futures)}
#    3581 # finish the root run
#    3582 except BaseException as e:
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\base.py:3564, in RunnableParallel.invoke.<locals>._invoke_step(step, input, config, key)
#    3562 context = copy_context()
#    3563 context.run(_set_config_context, child_config)
# -> 3564 return context.run(
#    3565     step.invoke,
#    3566     input,
#    3567     child_config,
#    3568 )
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\base.py:5094, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5088 def invoke(
#    5089     self,
#    5090     input: Input,
#    5091     config: Optional[RunnableConfig] = None,
#    5092     **kwargs: Optional[Any],
#    5093 ) -> Output:
# -> 5094     return self.bound.invoke(
#    5095         input,
#    5096         self._merge_configs(config),
#    5097         **{**self.kwargs, **kwargs},
#    5098     )
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\base.py:2878, in RunnableSequence.invoke(self, input, config, **kwargs)
#    2876             input = context.run(step.invoke, input, config, **kwargs)
#    2877         else:
# -> 2878             input = context.run(step.invoke, input, config)
#    2879 # finish the root run
#    2880 except BaseException as e:
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\prompts\base.py:179, in BasePromptTemplate.invoke(self, input, config)
#     177 if self.tags:
#     178     config["tags"] = config["tags"] + self.tags
# --> 179 return self._call_with_config(
#     180     self._format_prompt_with_error_handling,
#     181     input,
#     182     config,
#     183     run_type="prompt",
#     184 )
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\base.py:1785, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#    1781     context = copy_context()
#    1782     context.run(_set_config_context, child_config)
#    1783     output = cast(
#    1784         Output,
# -> 1785         context.run(
#    1786             call_func_with_variable_args,  # type: ignore[arg-type]
#    1787             func,  # type: ignore[arg-type]
#    1788             input,  # type: ignore[arg-type]
#    1789             config,
#    1790             run_manager,
#    1791             **kwargs,
#    1792         ),
#    1793     )
#    1794 except BaseException as e:
#    1795     run_manager.on_chain_error(e)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\config.py:397, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     395 if run_manager is not None and accepts_run_manager(func):
#     396     kwargs["run_manager"] = run_manager
# --> 397 return func(input, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\prompts\base.py:153, in BasePromptTemplate._format_prompt_with_error_handling(self, inner_input)
#     152 def _format_prompt_with_error_handling(self, inner_input: Dict) -> PromptValue:
# --> 153     _inner_input = self._validate_input(inner_input)
#     154     return self.format_prompt(**_inner_input)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\prompts\base.py:145, in BasePromptTemplate._validate_input(self, inner_input)
#     143 missing = set(self.input_variables).difference(inner_input)
#     144 if missing:
# --> 145     raise KeyError(
#     146         f"Input to {self.__class__.__name__} is missing variables {missing}. "
#     147         f" Expected: {self.input_variables}"
#     148         f" Received: {list(inner_input.keys())}"
#     149     )
#     150 return inner_input
#
# KeyError: "Input to ChatPromptTemplate is missing variables {'chat_history'}.  Expected: ['chat_history', 'context', 'input'] Received: ['input', 'context']"

# %%
response = rag_chain.invoke({"input": "list and explain class labels?"})
response["answer"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 response = rag_chain.invoke({"input": "list and explain class labels?"})
#       2 response["answer"]
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\base.py:5094, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5088 def invoke(
#    5089     self,
#    5090     input: Input,
#    5091     config: Optional[RunnableConfig] = None,
#    5092     **kwargs: Optional[Any],
#    5093 ) -> Output:
# -> 5094     return self.bound.invoke(
#    5095         input,
#    5096         self._merge_configs(config),
#    5097         **{**self.kwargs, **kwargs},
#    5098     )
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\base.py:2878, in RunnableSequence.invoke(self, input, config, **kwargs)
#    2876             input = context.run(step.invoke, input, config, **kwargs)
#    2877         else:
# -> 2878             input = context.run(step.invoke, input, config)
#    2879 # finish the root run
#    2880 except BaseException as e:
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\passthrough.py:495, in RunnableAssign.invoke(self, input, config, **kwargs)
#     489 def invoke(
#     490     self,
#     491     input: Dict[str, Any],
#     492     config: Optional[RunnableConfig] = None,
#     493     **kwargs: Any,
#     494 ) -> Dict[str, Any]:
# --> 495     return self._call_with_config(self._invoke, input, config, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\base.py:1785, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#    1781     context = copy_context()
#    1782     context.run(_set_config_context, child_config)
#    1783     output = cast(
#    1784         Output,
# -> 1785         context.run(
#    1786             call_func_with_variable_args,  # type: ignore[arg-type]
#    1787             func,  # type: ignore[arg-type]
#    1788             input,  # type: ignore[arg-type]
#    1789             config,
#    1790             run_manager,
#    1791             **kwargs,
#    1792         ),
#    1793     )
#    1794 except BaseException as e:
#    1795     run_manager.on_chain_error(e)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\config.py:397, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     395 if run_manager is not None and accepts_run_manager(func):
#     396     kwargs["run_manager"] = run_manager
# --> 397 return func(input, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\passthrough.py:482, in RunnableAssign._invoke(self, input, run_manager, config, **kwargs)
#     469 def _invoke(
#     470     self,
#     471     input: Dict[str, Any],
#    (...)
#     474     **kwargs: Any,
#     475 ) -> Dict[str, Any]:
#     476     assert isinstance(
#     477         input, dict
#     478     ), "The input to RunnablePassthrough.assign() must be a dict."
#     480     return {
#     481         **input,
# --> 482         **self.mapper.invoke(
#     483             input,
#     484             patch_config(config, callbacks=run_manager.get_child()),
#     485             **kwargs,
#     486         ),
#     487     }
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\base.py:3580, in RunnableParallel.invoke(self, input, config)
#    3575     with get_executor_for_config(config) as executor:
#    3576         futures = [
#    3577             executor.submit(_invoke_step, step, input, config, key)
#    3578             for key, step in steps.items()
#    3579         ]
# -> 3580         output = {key: future.result() for key, future in zip(steps, futures)}
#    3581 # finish the root run
#    3582 except BaseException as e:
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\base.py:3564, in RunnableParallel.invoke.<locals>._invoke_step(step, input, config, key)
#    3562 context = copy_context()
#    3563 context.run(_set_config_context, child_config)
# -> 3564 return context.run(
#    3565     step.invoke,
#    3566     input,
#    3567     child_config,
#    3568 )
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\base.py:5094, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5088 def invoke(
#    5089     self,
#    5090     input: Input,
#    5091     config: Optional[RunnableConfig] = None,
#    5092     **kwargs: Optional[Any],
#    5093 ) -> Output:
# -> 5094     return self.bound.invoke(
#    5095         input,
#    5096         self._merge_configs(config),
#    5097         **{**self.kwargs, **kwargs},
#    5098     )
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\base.py:2878, in RunnableSequence.invoke(self, input, config, **kwargs)
#    2876             input = context.run(step.invoke, input, config, **kwargs)
#    2877         else:
# -> 2878             input = context.run(step.invoke, input, config)
#    2879 # finish the root run
#    2880 except BaseException as e:
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\prompts\base.py:179, in BasePromptTemplate.invoke(self, input, config)
#     177 if self.tags:
#     178     config["tags"] = config["tags"] + self.tags
# --> 179 return self._call_with_config(
#     180     self._format_prompt_with_error_handling,
#     181     input,
#     182     config,
#     183     run_type="prompt",
#     184 )
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\base.py:1785, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#    1781     context = copy_context()
#    1782     context.run(_set_config_context, child_config)
#    1783     output = cast(
#    1784         Output,
# -> 1785         context.run(
#    1786             call_func_with_variable_args,  # type: ignore[arg-type]
#    1787             func,  # type: ignore[arg-type]
#    1788             input,  # type: ignore[arg-type]
#    1789             config,
#    1790             run_manager,
#    1791             **kwargs,
#    1792         ),
#    1793     )
#    1794 except BaseException as e:
#    1795     run_manager.on_chain_error(e)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\runnables\config.py:397, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     395 if run_manager is not None and accepts_run_manager(func):
#     396     kwargs["run_manager"] = run_manager
# --> 397 return func(input, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\prompts\base.py:153, in BasePromptTemplate._format_prompt_with_error_handling(self, inner_input)
#     152 def _format_prompt_with_error_handling(self, inner_input: Dict) -> PromptValue:
# --> 153     _inner_input = self._validate_input(inner_input)
#     154     return self.format_prompt(**_inner_input)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\prompts\base.py:145, in BasePromptTemplate._validate_input(self, inner_input)
#     143 missing = set(self.input_variables).difference(inner_input)
#     144 if missing:
# --> 145     raise KeyError(
#     146         f"Input to {self.__class__.__name__} is missing variables {missing}. "
#     147         f" Expected: {self.input_variables}"
#     148         f" Received: {list(inner_input.keys())}"
#     149     )
#     150 return inner_input
#
# KeyError: "Input to ChatPromptTemplate is missing variables {'chat_history'}.  Expected: ['chat_history', 'context', 'input'] Received: ['input', 'context']"

# %%
results = vector_store.similarity_search(query="discover data set",k=7)
for doc in results:
    print(f"* {doc.page_content} [{doc.metadata}]")
# Out:
# * Features 33   Dataset Information    Additional Information  Each record represents follow-up data for one breast cancer case.  These are consecutive patients seen by Dr. Wolberg since 1984, and include only those cases exhibiting invasive breast cancer and no evidence of distant metastases at the time of diagnosis. [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
# * Features 33   Dataset Information    Additional Information  Each record represents follow-up data for one breast cancer case.  These are consecutive patients seen by Dr. Wolberg since 1984, and include only those cases exhibiting invasive breast cancer and no evidence of distant metastases at the time of diagnosis. [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
# * Features 33   Dataset Information    Additional Information  Each record represents follow-up data for one breast cancer case.  These are consecutive patients seen by Dr. Wolberg since 1984, and include only those cases exhibiting invasive breast cancer and no evidence of distant metastases at the time of diagnosis. [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
# * you acknowledge and accept the cookies and privacy practices used by the UCI Machine Learning Repository. Accept Read Policy  The Project About Us CML National Science Foundation Navigation Home View Datasets Donate a Dataset Logistics Contact Privacy Notice Feature Request or Bug Report  Browse Datasets Donate a Dataset Link an external Dataset  Who We Are Citation Metadata Contact Information   Login [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
# * you acknowledge and accept the cookies and privacy practices used by the UCI Machine Learning Repository. Accept Read Policy  The Project About Us CML National Science Foundation Navigation Home View Datasets Donate a Dataset Logistics Contact Privacy Notice Feature Request or Bug Report  Browse Datasets Donate a Dataset Link an external Dataset  Who We Are Citation Metadata Contact Information   Login [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
# * you acknowledge and accept the cookies and privacy practices used by the UCI Machine Learning Repository. Accept Read Policy  The Project About Us CML National Science Foundation Navigation Home View Datasets Donate a Dataset Logistics Contact Privacy Notice Feature Request or Bug Report  Browse Datasets Donate a Dataset Link an external Dataset  Who We Are Citation Metadata Contact Information   Login [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
# * Submit Cancel     Download (21KB)  Import in Python  Install the ucimlrepo package    pip install ucimlrepo Import the dataset into your code    from ucimlrepo import fetch_ucirepo
#
# # fetch dataset
# breast_cancer_wisconsin_prognostic = fetch_ucirepo(id=16)
#
# # data (as pandas dataframes)
# X = breast_cancer_wisconsin_prognostic.data.features
# y = breast_cancer_wisconsin_prognostic.data.targets
#
# # metadata
# print(breast_cancer_wisconsin_prognostic.metadata)
#
# # variable information [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]

# %%
results = vector_store.similarity_search_with_score(query="discover data set",k=7)
for doc, score in results:
    print(f"* [SIM={score:3f}] {doc.page_content} [{doc.metadata}]")
# Out:
# * [SIM=1.108000] Features 33   Dataset Information    Additional Information  Each record represents follow-up data for one breast cancer case.  These are consecutive patients seen by Dr. Wolberg since 1984, and include only those cases exhibiting invasive breast cancer and no evidence of distant metastases at the time of diagnosis. [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
# * [SIM=1.108121] Features 33   Dataset Information    Additional Information  Each record represents follow-up data for one breast cancer case.  These are consecutive patients seen by Dr. Wolberg since 1984, and include only those cases exhibiting invasive breast cancer and no evidence of distant metastases at the time of diagnosis. [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
# * [SIM=1.108471] Features 33   Dataset Information    Additional Information  Each record represents follow-up data for one breast cancer case.  These are consecutive patients seen by Dr. Wolberg since 1984, and include only those cases exhibiting invasive breast cancer and no evidence of distant metastases at the time of diagnosis. [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
# * [SIM=1.108797] you acknowledge and accept the cookies and privacy practices used by the UCI Machine Learning Repository. Accept Read Policy  The Project About Us CML National Science Foundation Navigation Home View Datasets Donate a Dataset Logistics Contact Privacy Notice Feature Request or Bug Report  Browse Datasets Donate a Dataset Link an external Dataset  Who We Are Citation Metadata Contact Information   Login [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
# * [SIM=1.108934] you acknowledge and accept the cookies and privacy practices used by the UCI Machine Learning Repository. Accept Read Policy  The Project About Us CML National Science Foundation Navigation Home View Datasets Donate a Dataset Logistics Contact Privacy Notice Feature Request or Bug Report  Browse Datasets Donate a Dataset Link an external Dataset  Who We Are Citation Metadata Contact Information   Login [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
# * [SIM=1.108934] you acknowledge and accept the cookies and privacy practices used by the UCI Machine Learning Repository. Accept Read Policy  The Project About Us CML National Science Foundation Navigation Home View Datasets Donate a Dataset Logistics Contact Privacy Notice Feature Request or Bug Report  Browse Datasets Donate a Dataset Link an external Dataset  Who We Are Citation Metadata Contact Information   Login [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
# * [SIM=1.156486] Submit Cancel     Download (21KB)  Import in Python  Install the ucimlrepo package    pip install ucimlrepo Import the dataset into your code    from ucimlrepo import fetch_ucirepo
#
# # fetch dataset
# breast_cancer_wisconsin_prognostic = fetch_ucirepo(id=16)
#
# # data (as pandas dataframes)
# X = breast_cancer_wisconsin_prognostic.data.features
# y = breast_cancer_wisconsin_prognostic.data.targets
#
# # metadata
# print(breast_cancer_wisconsin_prognostic.metadata)
#
# # variable information [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]

# %%
vector_store.reset_collection()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 vector_store.reset_collection()
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_chroma\vectorstores.py:720, in Chroma.reset_collection(self)
#     715 def reset_collection(self) -> None:
#     716     """Resets the collection.
#     717
#     718     Resets the collection by deleting the collection and recreating an empty one.
#     719     """
# --> 720     self.delete_collection()
#     721     self.__ensure_collection()
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_chroma\vectorstores.py:712, in Chroma.delete_collection(self)
#     710 def delete_collection(self) -> None:
#     711     """Delete the collection."""
# --> 712     self._client.delete_collection(self._collection.name)
#     713     self._chroma_collection = None
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\chromadb\api\client.py:198, in Client.delete_collection(self, name)
#     193 @override
#     194 def delete_collection(
#     195     self,
#     196     name: str,
#     197 ) -> None:
# --> 198     return self._server.delete_collection(
#     199         name=name,
#     200         tenant=self.tenant,
#     201         database=self.database,
#     202     )
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\chromadb\telemetry\opentelemetry\__init__.py:146, in trace_method.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     144 global tracer, granularity
#     145 if trace_granularity < granularity:
# --> 146     return f(*args, **kwargs)
#     147 if not tracer:
#     148     return f(*args, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\chromadb\api\segment.py:321, in SegmentAPI.delete_collection(self, name, tenant, database)
#     317 if existing:
#     318     self._sysdb.delete_collection(
#     319         existing[0].id, tenant=tenant, database=database
#     320     )
# --> 321     for s in self._manager.delete_segments(existing[0].id):
#     322         self._sysdb.delete_segment(s)
#     323     if existing and existing[0].id in self._collection_cache:
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\chromadb\telemetry\opentelemetry\__init__.py:146, in trace_method.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     144 global tracer, granularity
#     145 if trace_granularity < granularity:
# --> 146     return f(*args, **kwargs)
#     147 if not tracer:
#     148     return f(*args, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\chromadb\segment\impl\manager\local.py:159, in LocalSegmentManager.delete_segments(self, collection_id)
#     157 if segment["type"] == SegmentType.HNSW_LOCAL_PERSISTED.value:
#     158     instance = self.get_segment(collection_id, VectorReader)
# --> 159     instance.delete()
#     160 elif segment["type"] == SegmentType.SQLITE.value:
#     161     instance = self.get_segment(collection_id, MetadataReader)  # type: ignore[assignment]
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\chromadb\telemetry\opentelemetry\__init__.py:146, in trace_method.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     144 global tracer, granularity
#     145 if trace_granularity < granularity:
# --> 146     return f(*args, **kwargs)
#     147 if not tracer:
#     148     return f(*args, **kwargs)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\chromadb\segment\impl\vector\local_persistent_hnsw.py:482, in PersistentLocalHnswSegment.delete(self)
#     480 if os.path.exists(data_path):
#     481     self.close_persistent_index()
# --> 482     shutil.rmtree(data_path, ignore_errors=False)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\shutil.py:781, in rmtree(path, ignore_errors, onerror, onexc, dir_fd)
#     779     # can't continue even if onexc hook returns
#     780     return
# --> 781 return _rmtree_unsafe(path, onexc)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\shutil.py:635, in _rmtree_unsafe(path, onexc)
#     633             os.unlink(fullname)
#     634         except OSError as err:
# --> 635             onexc(os.unlink, fullname, err)
#     636 try:
#     637     os.rmdir(path)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\shutil.py:633, in _rmtree_unsafe(path, onexc)
#     631 fullname = os.path.join(dirpath, name)
#     632 try:
# --> 633     os.unlink(fullname)
#     634 except OSError as err:
#     635     onexc(os.unlink, fullname, err)
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: './chroma_langchain_db\\768f2bb9-825a-4915-b724-62f6ecc2bee7\\data_level0.bin'

# %%
all_data = vector_store._collection.get()
all_ids = all_data['ids']
print(all_data['ids'])
print(len(all_data['ids']))
# retrieved_documents = vector_store.get_by_ids(all_ids)
# print(retrieved_documents)
# Out:
# ['04bb801b-29f1-4ce0-916b-0f127d7ebb1b', '0d7062bf-6a55-4aa3-9fc7-3cf8b8b529ac', '0f24a7ad-8e46-462c-bc64-adb601c81a6b', '0fc6b095-3c85-4562-9b7b-f8570df30ae3', '0ffe75a1-ce7f-44fb-8841-7485dc04f4fe', '12fef564-7c05-4dac-8157-299ef08abc92', '1353e61a-dbb7-4b11-8efd-f68701d06b01', '15448b60-4e2c-4dce-adc6-73455f216cea', '171a5050-f23a-47af-839e-64f42e6b2c31', '1a1b8804-4072-4cd6-99a3-45fd3d9d3d74', '27d2c363-7908-4758-995a-f9c6867cb181', '289ab5cf-7d0a-4a07-a807-c2f194a19ed0', '2e9e92a0-86bb-43c9-b1b9-7cdf793d27c6', '33003111-bdd5-44b1-bfba-648528d11da2', '37813ae9-ae15-4aaa-84a3-347523d66767', '378e19c7-af07-4a72-98e0-c073b61c1415', '4601b115-995d-452f-a123-2fb2e028f66e', '53526b6b-3e78-4314-afc8-8b2a432f2d0d', '5683a8f6-18f3-438a-8782-1f3a196bd708', '584a3a90-0c15-4f58-9ceb-b269beed8e85', '5e4905ae-e0d7-4f8b-a09c-21ad137b926d', '616b620a-6049-4502-b7de-a020b2134f5e', '6753899e-9829-4d89-bc50-36e0f2930901', '690af81f-be0a-4ca8-817f-0483f39e2ab5', '71c7c5b5-ef1b-489a-88ae-c3ca936f5f2a', '73b02572-2166-4ea3-8707-1d75a42c4149', '7890ac3a-274e-4f8b-b770-58008e4b82d1', '8bbf2a1a-6fc6-4ebf-9ffb-0a8790cf84a2', '8bce4be3-5de3-4afa-85b0-bebec33ba31b', '96eb9023-eef0-41d0-9d71-463618ce6c2c', '9730ab8c-13a5-4b23-87e4-f29731ef48fa', '97870998-59d1-441e-9e92-62626ba29cb9', '9f6f1a2b-2089-485a-87db-9b47f9be109b', 'a3006cb1-7486-403c-b0fd-4f6a64206cc1', 'a5839c22-4321-43b7-803b-30e8b8b2201e', 'a59add8e-e2db-4ed9-9970-c925c53ae03f', 'abe4a926-ef47-497a-8af8-4c52fcc34637', 'ad3d7a9c-c53b-4096-8c18-b4958d48854b', 'ae92c314-3f29-4d56-85ff-1e62733c1d78', 'b76d11d4-c366-4ef9-b2b5-01e20fce6283', 'bbb78aa9-9233-4151-b1e8-105bbd64ee65', 'c591fb8f-d184-4b34-b48a-42aafc719886', 'cac4bd1a-099d-48a1-b88c-1bfffe813f5a', 'dc9e27d2-8ebc-46fe-ab9e-e36fb3d3f1ed', 'dcc54eeb-2b00-4d4e-aa52-8b6fd6c8182f', 'e0396bf4-8c33-411a-8129-5c5a0358f168', 'e72c506e-a15f-41f0-8386-d121a34fab42', 'ec37ff19-fdfe-4379-b7ae-814daa529095', 'f05c33ad-ddbc-45f6-ab10-4bbd4347bdbc', 'f144fdb9-582c-4430-b18b-7eb480f8f0ac', 'f360c79f-cacf-4038-a4be-4847dcd4a582']
# 51

# %%
#vector_store.delete_collection()
#vector_store.reset_collection()
def print_vector_stores(uuids, vector_store):
    counter = 0
    for x in range(len(uuids)):
        counter += 1
        record = vector_store.get(uuids[x])
        print(counter, record)
        for key, val in record.items():
            print(f"\nkey: {key} ; value: {val}")
        print(f"\n print records / total records: {counter} / {len(uuids)}\n")
    couner = 0
    #vector_store.delete_collection()

# %%
print_vector_stores(uuids, vector_store)
# ??add_document() suppose to keep adding/appending data with uuids but it is not happening. This needs to explored
# embeddings value is None - This should be 3072/1536 size vector embedding - this needs to explore as well
# Out:
# 1 {'ids': ['0d7062bf-6a55-4aa3-9fc7-3cf8b8b529ac'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['UCI Machine Learning Repository\n\n\n\n\nBreast Cancer Wisconsin (Prognostic) - UCI Machine Learning Repository'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
#
# key: ids ; value: ['0d7062bf-6a55-4aa3-9fc7-3cf8b8b529ac']
#
# key: embeddings ; value: None
#
# key: metadatas ; value: [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
#
# key: documents ; value: ['UCI Machine Learning Repository\n\n\n\n\nBreast Cancer Wisconsin (Prognostic) - UCI Machine Learning Repository']
#
# key: uris ; value: None
#
# key: data ; value: None
#
# key: included ; value: ['metadatas', 'documents']
#
#  print records / total records: 1 / 17
#
# 2 {'ids': ['7890ac3a-274e-4f8b-b770-58008e4b82d1'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['Datasets Contribute Dataset Donate New Link External About Us Who We Are Citation Metadata Contact Information           Login       Breast Cancer Wisconsin (Prognostic)  Donated on 11/30/1995     Prognostic Wisconsin Breast Cancer Database  Dataset Characteristics Multivariate Subject Area Health and Medicine Associated Tasks Classification, Regression Feature Type Real # Instances 198 # Features 33   Dataset Information    Additional Information  Each record represents follow-up data'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
#
# key: ids ; value: ['7890ac3a-274e-4f8b-b770-58008e4b82d1']
#
# key: embeddings ; value: None
#
# key: metadatas ; value: [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
#
# key: documents ; value: ['Datasets Contribute Dataset Donate New Link External About Us Who We Are Citation Metadata Contact Information           Login       Breast Cancer Wisconsin (Prognostic)  Donated on 11/30/1995     Prognostic Wisconsin Breast Cancer Database  Dataset Characteristics Multivariate Subject Area Health and Medicine Associated Tasks Classification, Regression Feature Type Real # Instances 198 # Features 33   Dataset Information    Additional Information  Each record represents follow-up data']
#
# key: uris ; value: None
#
# key: data ; value: None
#
# key: included ; value: ['metadatas', 'documents']
#
#  print records / total records: 2 / 17
#
# 3 {'ids': ['8bbf2a1a-6fc6-4ebf-9ffb-0a8790cf84a2'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['Features 33   Dataset Information    Additional Information  Each record represents follow-up data for one breast cancer case.  These are consecutive patients seen by Dr. Wolberg since 1984, and include only those cases exhibiting invasive breast cancer and no evidence of distant metastases at the time of diagnosis.'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
#
# key: ids ; value: ['8bbf2a1a-6fc6-4ebf-9ffb-0a8790cf84a2']
#
# key: embeddings ; value: None
#
# key: metadatas ; value: [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
#
# key: documents ; value: ['Features 33   Dataset Information    Additional Information  Each record represents follow-up data for one breast cancer case.  These are consecutive patients seen by Dr. Wolberg since 1984, and include only those cases exhibiting invasive breast cancer and no evidence of distant metastases at the time of diagnosis.']
#
# key: uris ; value: None
#
# key: data ; value: None
#
# key: included ; value: ['metadatas', 'documents']
#
#  print records / total records: 3 / 17
#
# 4 {'ids': ['15448b60-4e2c-4dce-adc6-73455f216cea'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['The first 30 features are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass.  They describe characteristics of the cell nuclei present in the image. A few of the images can be found at http://www.cs.wisc.edu/~street/images/'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
#
# key: ids ; value: ['15448b60-4e2c-4dce-adc6-73455f216cea']
#
# key: embeddings ; value: None
#
# key: metadatas ; value: [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
#
# key: documents ; value: ['The first 30 features are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass.  They describe characteristics of the cell nuclei present in the image. A few of the images can be found at http://www.cs.wisc.edu/~street/images/']
#
# key: uris ; value: None
#
# key: data ; value: None
#
# key: included ; value: ['metadatas', 'documents']
#
#  print records / total records: 4 / 17
#
# 5 {'ids': ['dcc54eeb-2b00-4d4e-aa52-8b6fd6c8182f'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['The separation described above was obtained using Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree Construction Via Linear Programming." Proceedings of the 4th Midwest Artificial Intelligence and Cognitive Science Society, pp. 97-101, 1992], a classification method which uses linear programming to construct a decision tree.  Relevant features were selected using an exhaustive search in the space of 1-4 features and 1-3 separating planes.'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
#
# key: ids ; value: ['dcc54eeb-2b00-4d4e-aa52-8b6fd6c8182f']
#
# key: embeddings ; value: None
#
# key: metadatas ; value: [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
#
# key: documents ; value: ['The separation described above was obtained using Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree Construction Via Linear Programming." Proceedings of the 4th Midwest Artificial Intelligence and Cognitive Science Society, pp. 97-101, 1992], a classification method which uses linear programming to construct a decision tree.  Relevant features were selected using an exhaustive search in the space of 1-4 features and 1-3 separating planes.']
#
# key: uris ; value: None
#
# key: data ; value: None
#
# key: included ; value: ['metadatas', 'documents']
#
#  print records / total records: 5 / 17
#
# 6 {'ids': ['a3006cb1-7486-403c-b0fd-4f6a64206cc1'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['The actual linear program used to obtain the separating plane in the 3-dimensional space is that described in: \r\n[K. P. Bennett and O. L. Mangasarian: "Robust Linear Programming Discrimination of Two Linearly Inseparable Sets", Optimization Methods and Software 1, 1992, 23-34].'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
#
# key: ids ; value: ['a3006cb1-7486-403c-b0fd-4f6a64206cc1']
#
# key: embeddings ; value: None
#
# key: metadatas ; value: [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
#
# key: documents ; value: ['The actual linear program used to obtain the separating plane in the 3-dimensional space is that described in: \r\n[K. P. Bennett and O. L. Mangasarian: "Robust Linear Programming Discrimination of Two Linearly Inseparable Sets", Optimization Methods and Software 1, 1992, 23-34].']
#
# key: uris ; value: None
#
# key: data ; value: None
#
# key: included ; value: ['metadatas', 'documents']
#
#  print records / total records: 6 / 17
#
# 7 {'ids': ['e72c506e-a15f-41f0-8386-d121a34fab42'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['The Recurrence Surface Approximation (RSA) method is a linear programming model which predicts Time To Recur using both recurrent and nonrecurrent cases.  See references (i) and (ii) above for details of the RSA method. \r\n\r\nThis database is also available through the UW CS ftp server:\r\n\r\nftp ftp.cs.wisc.edu'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
#
# key: ids ; value: ['e72c506e-a15f-41f0-8386-d121a34fab42']
#
# key: embeddings ; value: None
#
# key: metadatas ; value: [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
#
# key: documents ; value: ['The Recurrence Surface Approximation (RSA) method is a linear programming model which predicts Time To Recur using both recurrent and nonrecurrent cases.  See references (i) and (ii) above for details of the RSA method. \r\n\r\nThis database is also available through the UW CS ftp server:\r\n\r\nftp ftp.cs.wisc.edu']
#
# key: uris ; value: None
#
# key: data ; value: None
#
# key: included ; value: ['metadatas', 'documents']
#
#  print records / total records: 7 / 17
#
# 8 {'ids': ['bbb78aa9-9233-4151-b1e8-105bbd64ee65'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['cd math-prog/cpo-dataset/machine-learn/WPBC/  Has Missing Values?  Yes     Variables Table      Variable NameRoleTypeDescriptionUnitsMissing Values IDIDIntegerno TimeFeatureIntegerno radius1FeatureContinuousno texture1FeatureContinuousno perimeter1FeatureContinuousno area1FeatureContinuousno smoothness1FeatureContinuousno compactness1FeatureContinuousno concavity1FeatureContinuousno concave_points1FeatureContinuousno  Rows per page 510152025 0 to 10 of 35    Additional Variable Information'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
#
# key: ids ; value: ['bbb78aa9-9233-4151-b1e8-105bbd64ee65']
#
# key: embeddings ; value: None
#
# key: metadatas ; value: [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
#
# key: documents ; value: ['cd math-prog/cpo-dataset/machine-learn/WPBC/  Has Missing Values?  Yes     Variables Table      Variable NameRoleTypeDescriptionUnitsMissing Values IDIDIntegerno TimeFeatureIntegerno radius1FeatureContinuousno texture1FeatureContinuousno perimeter1FeatureContinuousno area1FeatureContinuousno smoothness1FeatureContinuousno compactness1FeatureContinuousno concavity1FeatureContinuousno concave_points1FeatureContinuousno  Rows per page 510152025 0 to 10 of 35    Additional Variable Information']
#
# key: uris ; value: None
#
# key: data ; value: None
#
# key: included ; value: ['metadatas', 'documents']
#
#  print records / total records: 8 / 17
#
# 9 {'ids': ['9f6f1a2b-2089-485a-87db-9b47f9be109b'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['Rows per page 510152025 0 to 10 of 35    Additional Variable Information       1) ID number'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
#
# key: ids ; value: ['9f6f1a2b-2089-485a-87db-9b47f9be109b']
#
# key: embeddings ; value: None
#
# key: metadatas ; value: [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
#
# key: documents ; value: ['Rows per page 510152025 0 to 10 of 35    Additional Variable Information       1) ID number']
#
# key: uris ; value: None
#
# key: data ; value: None
#
# key: included ; value: ['metadatas', 'documents']
#
#  print records / total records: 9 / 17
#
# 10 {'ids': ['289ab5cf-7d0a-4a07-a807-c2f194a19ed0'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['2) Outcome (R = recur, N = nonrecur)\n3) Time (recurrence time if field 2 = R, disease-free time if \n\tfield 2\t= N)\n4-33) Ten real-valued features are computed for each cell nucleus:'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
#
# key: ids ; value: ['289ab5cf-7d0a-4a07-a807-c2f194a19ed0']
#
# key: embeddings ; value: None
#
# key: metadatas ; value: [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
#
# key: documents ; value: ['2) Outcome (R = recur, N = nonrecur)\n3) Time (recurrence time if field 2 = R, disease-free time if \n\tfield 2\t= N)\n4-33) Ten real-valued features are computed for each cell nucleus:']
#
# key: uris ; value: None
#
# key: data ; value: None
#
# key: included ; value: ['metadatas', 'documents']
#
#  print records / total records: 10 / 17
#
# 11 {'ids': ['0f24a7ad-8e46-462c-bc64-adb601c81a6b'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['a) radius (mean of distances from center to points on the perimeter)\n\tb) texture (standard deviation of gray-scale values)\n\tc) perimeter\n\td) area\n\te) smoothness (local variation in radius lengths)\n\tf) compactness (perimeter^2 / area - 1.0)\n\tg) concavity (severity of concave portions of the contour)\n\th) concave points (number of concave portions of the contour)\n\ti) symmetry \n\tj) fractal dimension ("coastline approximation" - 1)'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
#
# key: ids ; value: ['0f24a7ad-8e46-462c-bc64-adb601c81a6b']
#
# key: embeddings ; value: None
#
# key: metadatas ; value: [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
#
# key: documents ; value: ['a) radius (mean of distances from center to points on the perimeter)\n\tb) texture (standard deviation of gray-scale values)\n\tc) perimeter\n\td) area\n\te) smoothness (local variation in radius lengths)\n\tf) compactness (perimeter^2 / area - 1.0)\n\tg) concavity (severity of concave portions of the contour)\n\th) concave points (number of concave portions of the contour)\n\ti) symmetry \n\tj) fractal dimension ("coastline approximation" - 1)']
#
# key: uris ; value: None
#
# key: data ; value: None
#
# key: included ; value: ['metadatas', 'documents']
#
#  print records / total records: 11 / 17
#
# 12 {'ids': ['27d2c363-7908-4758-995a-f9c6867cb181'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['34) Tumor size - diameter of the excised tumor in centimeters\n35) Lymph node status - number of positive axillary lymph nodes\nobserved at time of surgery  Class Labels  R = recur, N = nonrecur    Dataset Files     FileSize wpbc.data44KB wpbc.names5.7KB    Reviews    There are no reviews for this dataset yet. Login to Write a Review   Write a Review   0  Comments'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
#
# key: ids ; value: ['27d2c363-7908-4758-995a-f9c6867cb181']
#
# key: embeddings ; value: None
#
# key: metadatas ; value: [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
#
# key: documents ; value: ['34) Tumor size - diameter of the excised tumor in centimeters\n35) Lymph node status - number of positive axillary lymph nodes\nobserved at time of surgery  Class Labels  R = recur, N = nonrecur    Dataset Files     FileSize wpbc.data44KB wpbc.names5.7KB    Reviews    There are no reviews for this dataset yet. Login to Write a Review   Write a Review   0  Comments']
#
# key: uris ; value: None
#
# key: data ; value: None
#
# key: included ; value: ['metadatas', 'documents']
#
#  print records / total records: 12 / 17
#
# 13 {'ids': ['2e9e92a0-86bb-43c9-b1b9-7cdf793d27c6'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['Submit Cancel     Download (21KB)  Import in Python  Install the ucimlrepo package    pip install ucimlrepo Import the dataset into your code    from ucimlrepo import fetch_ucirepo \n  \n# fetch dataset \nbreast_cancer_wisconsin_prognostic = fetch_ucirepo(id=16) \n  \n# data (as pandas dataframes) \nX = breast_cancer_wisconsin_prognostic.data.features \ny = breast_cancer_wisconsin_prognostic.data.targets \n  \n# metadata \nprint(breast_cancer_wisconsin_prognostic.metadata) \n  \n# variable information'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
#
# key: ids ; value: ['2e9e92a0-86bb-43c9-b1b9-7cdf793d27c6']
#
# key: embeddings ; value: None
#
# key: metadatas ; value: [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
#
# key: documents ; value: ['Submit Cancel     Download (21KB)  Import in Python  Install the ucimlrepo package    pip install ucimlrepo Import the dataset into your code    from ucimlrepo import fetch_ucirepo \n  \n# fetch dataset \nbreast_cancer_wisconsin_prognostic = fetch_ucirepo(id=16) \n  \n# data (as pandas dataframes) \nX = breast_cancer_wisconsin_prognostic.data.features \ny = breast_cancer_wisconsin_prognostic.data.targets \n  \n# metadata \nprint(breast_cancer_wisconsin_prognostic.metadata) \n  \n# variable information']
#
# key: uris ; value: None
#
# key: data ; value: None
#
# key: included ; value: ['metadatas', 'documents']
#
#  print records / total records: 13 / 17
#
# 14 {'ids': ['abe4a926-ef47-497a-8af8-4c52fcc34637'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['# metadata \nprint(breast_cancer_wisconsin_prognostic.metadata) \n  \n# variable information \nprint(breast_cancer_wisconsin_prognostic.variables)'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
#
# key: ids ; value: ['abe4a926-ef47-497a-8af8-4c52fcc34637']
#
# key: embeddings ; value: None
#
# key: metadatas ; value: [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
#
# key: documents ; value: ['# metadata \nprint(breast_cancer_wisconsin_prognostic.metadata) \n  \n# variable information \nprint(breast_cancer_wisconsin_prognostic.variables)']
#
# key: uris ; value: None
#
# key: data ; value: None
#
# key: included ; value: ['metadatas', 'documents']
#
#  print records / total records: 14 / 17
#
# 15 {'ids': ['f144fdb9-582c-4430-b18b-7eb480f8f0ac'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['# variable information \nprint(breast_cancer_wisconsin_prognostic.variables) \n View the full documentation Cite   0 citations  43707 views Citation     Wolberg, W., Street, W., & Mangasarian, O. (1995). Breast Cancer Wisconsin (Prognostic) [Dataset]. UCI Machine Learning Repository. https://doi.org/10.24432/C5GK50. Style: APAMLAChicagoVancouverIEEEBibTeX    Creators    William Wolberg    W. Street    Olvi Mangasarian     DOI 10.24432/C5GK50  License This dataset is licensed under a'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
#
# key: ids ; value: ['f144fdb9-582c-4430-b18b-7eb480f8f0ac']
#
# key: embeddings ; value: None
#
# key: metadatas ; value: [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
#
# key: documents ; value: ['# variable information \nprint(breast_cancer_wisconsin_prognostic.variables) \n View the full documentation Cite   0 citations  43707 views Citation     Wolberg, W., Street, W., & Mangasarian, O. (1995). Breast Cancer Wisconsin (Prognostic) [Dataset]. UCI Machine Learning Repository. https://doi.org/10.24432/C5GK50. Style: APAMLAChicagoVancouverIEEEBibTeX    Creators    William Wolberg    W. Street    Olvi Mangasarian     DOI 10.24432/C5GK50  License This dataset is licensed under a']
#
# key: uris ; value: None
#
# key: data ; value: None
#
# key: included ; value: ['metadatas', 'documents']
#
#  print records / total records: 15 / 17
#
# 16 {'ids': ['0fc6b095-3c85-4562-9b7b-f8570df30ae3'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['Creative Commons Attribution 4.0 International\n(CC BY 4.0) license. This allows for the sharing and adaptation of the datasets for any purpose,\nprovided that the appropriate credit is given.  By using the UCI Machine Learning Repository,'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
#
# key: ids ; value: ['0fc6b095-3c85-4562-9b7b-f8570df30ae3']
#
# key: embeddings ; value: None
#
# key: metadatas ; value: [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
#
# key: documents ; value: ['Creative Commons Attribution 4.0 International\n(CC BY 4.0) license. This allows for the sharing and adaptation of the datasets for any purpose,\nprovided that the appropriate credit is given.  By using the UCI Machine Learning Repository,']
#
# key: uris ; value: None
#
# key: data ; value: None
#
# key: included ; value: ['metadatas', 'documents']
#
#  print records / total records: 16 / 17
#
# 17 {'ids': ['ec37ff19-fdfe-4379-b7ae-814daa529095'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['you acknowledge and accept the cookies and privacy practices used by the UCI Machine Learning Repository. Accept Read Policy  The Project About Us CML National Science Foundation Navigation Home View Datasets Donate a Dataset Logistics Contact Privacy Notice Feature Request or Bug Report  Browse Datasets Donate a Dataset Link an external Dataset  Who We Are Citation Metadata Contact Information   Login'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
#
# key: ids ; value: ['ec37ff19-fdfe-4379-b7ae-814daa529095']
#
# key: embeddings ; value: None
#
# key: metadatas ; value: [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}]
#
# key: documents ; value: ['you acknowledge and accept the cookies and privacy practices used by the UCI Machine Learning Repository. Accept Read Policy  The Project About Us CML National Science Foundation Navigation Home View Datasets Donate a Dataset Logistics Contact Privacy Notice Feature Request or Bug Report  Browse Datasets Donate a Dataset Link an external Dataset  Who We Are Citation Metadata Contact Information   Login']
#
# key: uris ; value: None
#
# key: data ; value: None
#
# key: included ; value: ['metadatas', 'documents']
#
#  print records / total records: 17 / 17

# %%
# Data source 2/4
#load the data from the 'data_info_table.csv' 
from langchain_community.document_loaders import CSVLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
#instantiate
data_info_table = CSVLoader(file_path='./data_info_table.csv',
                                   csv_args={
                                       'delimiter': ';',
                                       'quotechar': '"',
                                       'fieldnames': ['name', 'role', 'type', 'demographic', 'description', 'units', 'missing_values']
                                   })
data_info_table_loader = data_info_table.load()
""" for doc in data_info_table_docs:
    print(f"{doc.page_content[:10000]}")
    print(f"{doc.metadata}") """

#spliting Document object to smaller document objects 
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 500, chunk_overlap=100, length_function=len, is_separator_regex=False)
original_data_loader_docs = text_splitter.split_documents(data_info_table_loader)
print(f"{original_data_loader_docs.__class__}")
counter=0
for data in data_info_table_loader:
    counter += 1
    print(f"\n\n{counter}{data.__class__}: {data}")
counter = 0
# Out:
# <class 'list'>
#
#
# 1<class 'langchain_core.documents.base.Document'>: page_content='name: name
# role: role
# type: type
# demographic: demographic
# description: description
# units: units
# missing_values: missing_values' metadata={'source': './data_info_table.csv', 'row': 0}
#
#
# 2<class 'langchain_core.documents.base.Document'>: page_content='name: ID
# role: ID
# type: Integer
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 1}
#
#
# 3<class 'langchain_core.documents.base.Document'>: page_content='name: Time
# role: Feature
# type: Integer
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 2}
#
#
# 4<class 'langchain_core.documents.base.Document'>: page_content='name: radius1
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 3}
#
#
# 5<class 'langchain_core.documents.base.Document'>: page_content='name: texture1
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 4}
#
#
# 6<class 'langchain_core.documents.base.Document'>: page_content='name: perimeter1
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 5}
#
#
# 7<class 'langchain_core.documents.base.Document'>: page_content='name: area1
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 6}
#
#
# 8<class 'langchain_core.documents.base.Document'>: page_content='name: smoothness1
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 7}
#
#
# 9<class 'langchain_core.documents.base.Document'>: page_content='name: compactness1
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 8}
#
#
# 10<class 'langchain_core.documents.base.Document'>: page_content='name: concavity1
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 9}
#
#
# 11<class 'langchain_core.documents.base.Document'>: page_content='name: concave_points1
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 10}
#
#
# 12<class 'langchain_core.documents.base.Document'>: page_content='name: symmetry1
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 11}
#
#
# 13<class 'langchain_core.documents.base.Document'>: page_content='name: fractal_dimension1
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 12}
#
#
# 14<class 'langchain_core.documents.base.Document'>: page_content='name: radius2
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 13}
#
#
# 15<class 'langchain_core.documents.base.Document'>: page_content='name: texture2
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 14}
#
#
# 16<class 'langchain_core.documents.base.Document'>: page_content='name: perimeter2
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 15}
#
#
# 17<class 'langchain_core.documents.base.Document'>: page_content='name: area2
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 16}
#
#
# 18<class 'langchain_core.documents.base.Document'>: page_content='name: smoothness2
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 17}
#
#
# 19<class 'langchain_core.documents.base.Document'>: page_content='name: compactness2
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 18}
#
#
# 20<class 'langchain_core.documents.base.Document'>: page_content='name: concavity2
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 19}
#
#
# 21<class 'langchain_core.documents.base.Document'>: page_content='name: concave_points2
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 20}
#
#
# 22<class 'langchain_core.documents.base.Document'>: page_content='name: symmetry2
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 21}
#
#
# 23<class 'langchain_core.documents.base.Document'>: page_content='name: fractal_dimension2
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 22}
#
#
# 24<class 'langchain_core.documents.base.Document'>: page_content='name: radius3
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 23}
#
#
# 25<class 'langchain_core.documents.base.Document'>: page_content='name: texture3
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 24}
#
#
# 26<class 'langchain_core.documents.base.Document'>: page_content='name: perimeter3
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 25}
#
#
# 27<class 'langchain_core.documents.base.Document'>: page_content='name: area3
# role: Feature
# type: Integer
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 26}
#
#
# 28<class 'langchain_core.documents.base.Document'>: page_content='name: smoothness3
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 27}
#
#
# 29<class 'langchain_core.documents.base.Document'>: page_content='name: compactness3
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 28}
#
#
# 30<class 'langchain_core.documents.base.Document'>: page_content='name: concavity3
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 29}
#
#
# 31<class 'langchain_core.documents.base.Document'>: page_content='name: concave_points3
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 30}
#
#
# 32<class 'langchain_core.documents.base.Document'>: page_content='name: symmetry3
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 31}
#
#
# 33<class 'langchain_core.documents.base.Document'>: page_content='name: fractal_dimension3
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 32}
#
#
# 34<class 'langchain_core.documents.base.Document'>: page_content='name: tumor_size
# role: Feature
# type: Continuous
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 33}
#
#
# 35<class 'langchain_core.documents.base.Document'>: page_content='name: lymph_node_status
# role: Feature
# type: Integer
# demographic: NA
# description: NA
# units: NA
# missing_values: yes' metadata={'source': './data_info_table.csv', 'row': 34}
#
#
# 36<class 'langchain_core.documents.base.Document'>: page_content='name: Outcome
# role: Target
# type: Categorical
# demographic: NA
# description: NA
# units: NA
# missing_values: no' metadata={'source': './data_info_table.csv', 'row': 35}

# %%
# Data source 3/4
#load the tables data from the 'original_data.csv'
#instantiate
original_data = CSVLoader(file_path='./original_data.csv',
                                   csv_args={
                                       'delimiter': ';',
                                       'quotechar': '"',
                                       'fieldnames': ['Time',
                                                      'radius1','texture1','perimeter1','area1','smoothness1','compactness1','concavity1','concave_points1','symmetry1','fractal_dimension1',
                                                      'radius2','texture2','perimeter2','area2','smoothness2','compactness2','concavity2','concave_points2','symmetry2','fractal_dimension2',
                                                      'radius3','texture3','perimeter3','area3','smoothness3','compactness3','concavity3','concave_points3','symmetry3','fractal_dimension3',
                                                      'tumor_size','lymph_node_status','Outcome']
                                   })
original_data_loader = original_data.load()
""" for doc in original_data_loader:
    print(f"{doc.page_content[:10000]}")
    print(f"{doc.metadata}") """

#spliting Document object to smaller document objects 
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 500, chunk_overlap=100, length_function=len, is_separator_regex=False)
original_data_loader_docs = text_splitter.split_documents(original_data_loader)
counter=0
for data in original_data_loader_docs:
    counter += 1
    print(f"\n\n{counter}{data.__class__}: {data}")
counter = 0
# Out:
# 1<class 'langchain_core.documents.base.Document'>: page_content='Time: Time
# radius1: radius1
# texture1: texture1
# perimeter1: perimeter1
# area1: area1
# smoothness1: smoothness1
# compactness1: compactness1
# concavity1: concavity1
# concave_points1: concave_points1
# symmetry1: symmetry1
# fractal_dimension1: fractal_dimension1
# radius2: radius2
# texture2: texture2
# perimeter2: perimeter2
# area2: area2
# smoothness2: smoothness2
# compactness2: compactness2
# concavity2: concavity2
# concave_points2: concave_points2
# symmetry2: symmetry2
# fractal_dimension2: fractal_dimension2' metadata={'source': './original_data.csv', 'row': 0}
#
#
# 2<class 'langchain_core.documents.base.Document'>: page_content='concave_points2: concave_points2
# symmetry2: symmetry2
# fractal_dimension2: fractal_dimension2
# radius3: radius3
# texture3: texture3
# perimeter3: perimeter3
# area3: area3
# smoothness3: smoothness3
# compactness3: compactness3
# concavity3: concavity3
# concave_points3: concave_points3
# symmetry3: symmetry3
# fractal_dimension3: fractal_dimension3
# tumor_size: tumor_size
# lymph_node_status: lymph_node_status
# Outcome: Outcome' metadata={'source': './original_data.csv', 'row': 0}
#
#
# 3<class 'langchain_core.documents.base.Document'>: page_content='Time: 31
# radius1: 18.02
# texture1: 27.6
# perimeter1: 117.5
# area1: 1013.0
# smoothness1: 0.09489
# compactness1: 0.1036
# concavity1: 0.1086
# concave_points1: 0.07055
# symmetry1: 0.1865
# fractal_dimension1: 0.06333
# radius2: 0.6249
# texture2: 1.89
# perimeter2: 3.972
# area2: 71.55
# smoothness2: 0.004433
# compactness2: 0.01421
# concavity2: 0.03233
# concave_points2: 0.009854
# symmetry2: 0.01694
# fractal_dimension2: 0.003495
# radius3: 21.63
# texture3: 37.08
# perimeter3: 139.7
# area3: 1436.0
# smoothness3: 0.1195' metadata={'source': './original_data.csv', 'row': 1}
#
#
# 4<class 'langchain_core.documents.base.Document'>: page_content='radius3: 21.63
# texture3: 37.08
# perimeter3: 139.7
# area3: 1436.0
# smoothness3: 0.1195
# compactness3: 0.1926
# concavity3: 0.314
# concave_points3: 0.117
# symmetry3: 0.2677
# fractal_dimension3: 0.08113
# tumor_size: 5.0
# lymph_node_status: 5.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 1}
#
#
# 5<class 'langchain_core.documents.base.Document'>: page_content='Time: 61
# radius1: 17.99
# texture1: 10.38
# perimeter1: 122.8
# area1: 1001.0
# smoothness1: 0.1184
# compactness1: 0.2776
# concavity1: 0.3001
# concave_points1: 0.1471
# symmetry1: 0.2419
# fractal_dimension1: 0.07871
# radius2: 1.095
# texture2: 0.9053
# perimeter2: 8.589
# area2: 153.4
# smoothness2: 0.006399
# compactness2: 0.04904
# concavity2: 0.05373
# concave_points2: 0.01587
# symmetry2: 0.03003
# fractal_dimension2: 0.006193
# radius3: 25.38
# texture3: 17.33
# perimeter3: 184.6
# area3: 2019.0
# smoothness3: 0.1622' metadata={'source': './original_data.csv', 'row': 2}
#
#
# 6<class 'langchain_core.documents.base.Document'>: page_content='radius3: 25.38
# texture3: 17.33
# perimeter3: 184.6
# area3: 2019.0
# smoothness3: 0.1622
# compactness3: 0.6656
# concavity3: 0.7119
# concave_points3: 0.2654
# symmetry3: 0.4601
# fractal_dimension3: 0.1189
# tumor_size: 3.0
# lymph_node_status: 2.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 2}
#
#
# 7<class 'langchain_core.documents.base.Document'>: page_content='Time: 116
# radius1: 21.37
# texture1: 17.44
# perimeter1: 137.5
# area1: 1373.0
# smoothness1: 0.08836
# compactness1: 0.1189
# concavity1: 0.1255
# concave_points1: 0.0818
# symmetry1: 0.2333
# fractal_dimension1: 0.0601
# radius2: 0.5854
# texture2: 0.6105
# perimeter2: 3.928
# area2: 82.15
# smoothness2: 0.006167
# compactness2: 0.03449
# concavity2: 0.033
# concave_points2: 0.01805
# symmetry2: 0.03094
# fractal_dimension2: 0.005039
# radius3: 24.9
# texture3: 20.98
# perimeter3: 159.1
# area3: 1949.0
# smoothness3: 0.1188' metadata={'source': './original_data.csv', 'row': 3}
#
#
# 8<class 'langchain_core.documents.base.Document'>: page_content='radius3: 24.9
# texture3: 20.98
# perimeter3: 159.1
# area3: 1949.0
# smoothness3: 0.1188
# compactness3: 0.3449
# concavity3: 0.3414
# concave_points3: 0.2032
# symmetry3: 0.4334
# fractal_dimension3: 0.09067
# tumor_size: 2.5
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 3}
#
#
# 9<class 'langchain_core.documents.base.Document'>: page_content='Time: 123
# radius1: 11.42
# texture1: 20.38
# perimeter1: 77.58
# area1: 386.1
# smoothness1: 0.1425
# compactness1: 0.2839
# concavity1: 0.2414
# concave_points1: 0.1052
# symmetry1: 0.2597
# fractal_dimension1: 0.09744
# radius2: 0.4956
# texture2: 1.156
# perimeter2: 3.445
# area2: 27.23
# smoothness2: 0.00911
# compactness2: 0.07458
# concavity2: 0.05661
# concave_points2: 0.01867
# symmetry2: 0.05963
# fractal_dimension2: 0.009208
# radius3: 14.91
# texture3: 26.5
# perimeter3: 98.87
# area3: 567.7
# smoothness3: 0.2098' metadata={'source': './original_data.csv', 'row': 4}
#
#
# 10<class 'langchain_core.documents.base.Document'>: page_content='radius3: 14.91
# texture3: 26.5
# perimeter3: 98.87
# area3: 567.7
# smoothness3: 0.2098
# compactness3: 0.8663
# concavity3: 0.6869
# concave_points3: 0.2575
# symmetry3: 0.6638
# fractal_dimension3: 0.173
# tumor_size: 2.0
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 4}
#
#
# 11<class 'langchain_core.documents.base.Document'>: page_content='Time: 27
# radius1: 20.29
# texture1: 14.34
# perimeter1: 135.1
# area1: 1297.0
# smoothness1: 0.1003
# compactness1: 0.1328
# concavity1: 0.198
# concave_points1: 0.1043
# symmetry1: 0.1809
# fractal_dimension1: 0.05883
# radius2: 0.7572
# texture2: 0.7813
# perimeter2: 5.438
# area2: 94.44
# smoothness2: 0.01149
# compactness2: 0.02461
# concavity2: 0.05688
# concave_points2: 0.01885
# symmetry2: 0.01756
# fractal_dimension2: 0.005115
# radius3: 22.54
# texture3: 16.67
# perimeter3: 152.2
# area3: 1575.0
# smoothness3: 0.1374' metadata={'source': './original_data.csv', 'row': 5}
#
#
# 12<class 'langchain_core.documents.base.Document'>: page_content='radius3: 22.54
# texture3: 16.67
# perimeter3: 152.2
# area3: 1575.0
# smoothness3: 0.1374
# compactness3: 0.205
# concavity3: 0.4
# concave_points3: 0.1625
# symmetry3: 0.2364
# fractal_dimension3: 0.07678
# tumor_size: 3.5
# lymph_node_status: 0.0
# Outcome: R' metadata={'source': './original_data.csv', 'row': 5}
#
#
# 13<class 'langchain_core.documents.base.Document'>: page_content='Time: 77
# radius1: 12.75
# texture1: 15.29
# perimeter1: 84.6
# area1: 502.7
# smoothness1: 0.1189
# compactness1: 0.1569
# concavity1: 0.1664
# concave_points1: 0.07666
# symmetry1: 0.1995
# fractal_dimension1: 0.07164
# radius2: 0.3877
# texture2: 0.7402
# perimeter2: 2.999
# area2: 30.85
# smoothness2: 0.007775
# compactness2: 0.02987
# concavity2: 0.04561
# concave_points2: 0.01357
# symmetry2: 0.01774
# fractal_dimension2: 0.005114
# radius3: 15.51
# texture3: 20.37
# perimeter3: 107.3
# area3: 733.2
# smoothness3: 0.1706' metadata={'source': './original_data.csv', 'row': 6}
#
#
# 14<class 'langchain_core.documents.base.Document'>: page_content='radius3: 15.51
# texture3: 20.37
# perimeter3: 107.3
# area3: 733.2
# smoothness3: 0.1706
# compactness3: 0.4196
# concavity3: 0.5999
# concave_points3: 0.1709
# symmetry3: 0.3485
# fractal_dimension3: 0.1179
# tumor_size: 2.5
# lymph_node_status: 0.0
# Outcome: R' metadata={'source': './original_data.csv', 'row': 6}
#
#
# 15<class 'langchain_core.documents.base.Document'>: page_content='Time: 60
# radius1: 18.98
# texture1: 19.61
# perimeter1: 124.4
# area1: 1112.0
# smoothness1: 0.09087
# compactness1: 0.1237
# concavity1: 0.1213
# concave_points1: 0.0891
# symmetry1: 0.1727
# fractal_dimension1: 0.05767
# radius2: 0.5285
# texture2: 0.8434
# perimeter2: 3.592
# area2: 61.21
# smoothness2: 0.003703
# compactness2: 0.02354
# concavity2: 0.02222
# concave_points2: 0.01332
# symmetry2: 0.01378
# fractal_dimension2: 0.003926
# radius3: 23.39
# texture3: 25.45
# perimeter3: 152.6
# area3: 1593.0
# smoothness3: 0.1144' metadata={'source': './original_data.csv', 'row': 7}
#
#
# 16<class 'langchain_core.documents.base.Document'>: page_content='radius3: 23.39
# texture3: 25.45
# perimeter3: 152.6
# area3: 1593.0
# smoothness3: 0.1144
# compactness3: 0.3371
# concavity3: 0.299
# concave_points3: 0.1922
# symmetry3: 0.2726
# fractal_dimension3: 0.09581
# tumor_size: 1.5
# lymph_node_status: NA
# Outcome: N' metadata={'source': './original_data.csv', 'row': 7}
#
#
# 17<class 'langchain_core.documents.base.Document'>: page_content='Time: 77
# radius1: 13.71
# texture1: 20.83
# perimeter1: 90.2
# area1: 577.9
# smoothness1: 0.1189
# compactness1: 0.1645
# concavity1: 0.09366
# concave_points1: 0.05985
# symmetry1: 0.2196
# fractal_dimension1: 0.07451
# radius2: 0.5835
# texture2: 1.377
# perimeter2: 3.856
# area2: 50.96
# smoothness2: 0.008805
# compactness2: 0.03029
# concavity2: 0.02488
# concave_points2: 0.01448
# symmetry2: 0.01486
# fractal_dimension2: 0.005412
# radius3: 17.06
# texture3: 28.14
# perimeter3: 110.6
# area3: 897.0
# smoothness3: 0.1654' metadata={'source': './original_data.csv', 'row': 8}
#
#
# 18<class 'langchain_core.documents.base.Document'>: page_content='radius3: 17.06
# texture3: 28.14
# perimeter3: 110.6
# area3: 897.0
# smoothness3: 0.1654
# compactness3: 0.3682
# concavity3: 0.2678
# concave_points3: 0.1556
# symmetry3: 0.3196
# fractal_dimension3: 0.1151
# tumor_size: 4.0
# lymph_node_status: 10.0
# Outcome: R' metadata={'source': './original_data.csv', 'row': 8}
#
#
# 19<class 'langchain_core.documents.base.Document'>: page_content='Time: 119
# radius1: 13.0
# texture1: 21.82
# perimeter1: 87.5
# area1: 519.8
# smoothness1: 0.1273
# compactness1: 0.1932
# concavity1: 0.1859
# concave_points1: 0.09353
# symmetry1: 0.235
# fractal_dimension1: 0.07389
# radius2: 0.3063
# texture2: 1.002
# perimeter2: 2.406
# area2: 24.32
# smoothness2: 0.005731
# compactness2: 0.03502
# concavity2: 0.03553
# concave_points2: 0.01226
# symmetry2: 0.02143
# fractal_dimension2: 0.003749
# radius3: 15.49
# texture3: 30.73
# perimeter3: 106.2
# area3: 739.3
# smoothness3: 0.1703' metadata={'source': './original_data.csv', 'row': 9}
#
#
# 20<class 'langchain_core.documents.base.Document'>: page_content='radius3: 15.49
# texture3: 30.73
# perimeter3: 106.2
# area3: 739.3
# smoothness3: 0.1703
# compactness3: 0.5401
# concavity3: 0.539
# concave_points3: 0.206
# symmetry3: 0.4378
# fractal_dimension3: 0.1072
# tumor_size: 2.0
# lymph_node_status: 1.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 9}
#
#
# 21<class 'langchain_core.documents.base.Document'>: page_content='Time: 76
# radius1: 12.46
# texture1: 24.04
# perimeter1: 83.97
# area1: 475.9
# smoothness1: 0.1186
# compactness1: 0.2396
# concavity1: 0.2273
# concave_points1: 0.08543
# symmetry1: 0.203
# fractal_dimension1: 0.08243
# radius2: 0.2976
# texture2: 1.599
# perimeter2: 2.039
# area2: 23.94
# smoothness2: 0.007149
# compactness2: 0.07217
# concavity2: 0.07743
# concave_points2: 0.01432
# symmetry2: 0.01789
# fractal_dimension2: 0.01008
# radius3: 15.09
# texture3: 40.68
# perimeter3: 97.65
# area3: 711.4
# smoothness3: 0.1853' metadata={'source': './original_data.csv', 'row': 10}
#
#
# 22<class 'langchain_core.documents.base.Document'>: page_content='radius3: 15.09
# texture3: 40.68
# perimeter3: 97.65
# area3: 711.4
# smoothness3: 0.1853
# compactness3: 1.058
# concavity3: 1.105
# concave_points3: 0.221
# symmetry3: 0.4366
# fractal_dimension3: 0.2075
# tumor_size: 6.0
# lymph_node_status: 20.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 10}
#
#
# 23<class 'langchain_core.documents.base.Document'>: page_content='Time: 123
# radius1: 16.02
# texture1: 23.24
# perimeter1: 102.7
# area1: 797.8
# smoothness1: 0.08206
# compactness1: 0.06669
# concavity1: 0.03299
# concave_points1: 0.03323
# symmetry1: 0.1528
# fractal_dimension1: 0.05697
# radius2: 0.3795
# texture2: 1.187
# perimeter2: 2.466
# area2: 40.51
# smoothness2: 0.004029
# compactness2: 0.009269
# concavity2: 0.01101
# concave_points2: 0.007591
# symmetry2: 0.0146
# fractal_dimension2: 0.003042
# radius3: 19.19
# texture3: 33.88
# perimeter3: 123.8
# area3: 1150.0
# smoothness3: 0.1181' metadata={'source': './original_data.csv', 'row': 11}
#
#
# 24<class 'langchain_core.documents.base.Document'>: page_content='radius3: 19.19
# texture3: 33.88
# perimeter3: 123.8
# area3: 1150.0
# smoothness3: 0.1181
# compactness3: 0.1551
# concavity3: 0.1459
# concave_points3: 0.09975
# symmetry3: 0.2948
# fractal_dimension3: 0.08452
# tumor_size: 2.0
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 11}
#
#
# 25<class 'langchain_core.documents.base.Document'>: page_content='Time: 125
# radius1: 15.78
# texture1: 17.89
# perimeter1: 103.6
# area1: 781.0
# smoothness1: 0.0971
# compactness1: 0.1292
# concavity1: 0.09954
# concave_points1: 0.06606
# symmetry1: 0.1842
# fractal_dimension1: 0.06082
# radius2: 0.5058
# texture2: 0.9849
# perimeter2: 3.564
# area2: 54.16
# smoothness2: 0.005771
# compactness2: 0.04061
# concavity2: 0.02791
# concave_points2: 0.01282
# symmetry2: 0.02008
# fractal_dimension2: 0.004144
# radius3: 20.42
# texture3: 27.28
# perimeter3: 136.5
# area3: 1299.0
# smoothness3: 0.1396' metadata={'source': './original_data.csv', 'row': 12}
#
#
# 26<class 'langchain_core.documents.base.Document'>: page_content='radius3: 20.42
# texture3: 27.28
# perimeter3: 136.5
# area3: 1299.0
# smoothness3: 0.1396
# compactness3: 0.5609
# concavity3: 0.3965
# concave_points3: 0.181
# symmetry3: 0.3792
# fractal_dimension3: 0.1048
# tumor_size: 1.4
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 12}
#
#
# 27<class 'langchain_core.documents.base.Document'>: page_content='Time: 117
# radius1: 15.85
# texture1: 23.95
# perimeter1: 103.7
# area1: 782.7
# smoothness1: 0.08401
# compactness1: 0.1002
# concavity1: 0.09938
# concave_points1: 0.05364
# symmetry1: 0.1847
# fractal_dimension1: 0.05338
# radius2: 0.4033
# texture2: 1.078
# perimeter2: 2.903
# area2: 36.58
# smoothness2: 0.009769
# compactness2: 0.03126
# concavity2: 0.05051
# concave_points2: 0.01992
# symmetry2: 0.02981
# fractal_dimension2: 0.003002
# radius3: 16.84
# texture3: 27.66
# perimeter3: 112.0
# area3: 876.5
# smoothness3: 0.1131' metadata={'source': './original_data.csv', 'row': 13}
#
#
# 28<class 'langchain_core.documents.base.Document'>: page_content='radius3: 16.84
# texture3: 27.66
# perimeter3: 112.0
# area3: 876.5
# smoothness3: 0.1131
# compactness3: 0.1924
# concavity3: 0.2322
# concave_points3: 0.1119
# symmetry3: 0.2809
# fractal_dimension3: 0.06287
# tumor_size: 1.0
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 13}
#
#
# 29<class 'langchain_core.documents.base.Document'>: page_content='Time: 36
# radius1: 14.54
# texture1: 27.54
# perimeter1: 96.73
# area1: 658.8
# smoothness1: 0.1139
# compactness1: 0.1595
# concavity1: 0.1639
# concave_points1: 0.07364
# symmetry1: 0.2303
# fractal_dimension1: 0.07077
# radius2: 0.37
# texture2: 1.033
# perimeter2: 2.879
# area2: 32.55
# smoothness2: 0.005607
# compactness2: 0.0424
# concavity2: 0.04741
# concave_points2: 0.0109
# symmetry2: 0.01857
# fractal_dimension2: 0.005466
# radius3: 17.46
# texture3: 37.13
# perimeter3: 124.1
# area3: 943.2
# smoothness3: 0.1678
# compactness3: 0.6577' metadata={'source': './original_data.csv', 'row': 14}
#
#
# 30<class 'langchain_core.documents.base.Document'>: page_content='texture3: 37.13
# perimeter3: 124.1
# area3: 943.2
# smoothness3: 0.1678
# compactness3: 0.6577
# concavity3: 0.7026
# concave_points3: 0.1712
# symmetry3: 0.4218
# fractal_dimension3: 0.1341
# tumor_size: 6.0
# lymph_node_status: 6.0
# Outcome: R' metadata={'source': './original_data.csv', 'row': 14}
#
#
# 31<class 'langchain_core.documents.base.Document'>: page_content='Time: 123
# radius1: 14.68
# texture1: 20.13
# perimeter1: 94.74
# area1: 684.5
# smoothness1: 0.09867
# compactness1: 0.072
# concavity1: 0.07395
# concave_points1: 0.05259
# symmetry1: 0.1586
# fractal_dimension1: 0.05922
# radius2: 0.4727
# texture2: 1.24
# perimeter2: 3.195
# area2: 45.4
# smoothness2: 0.005718
# compactness2: 0.01162
# concavity2: 0.01998
# concave_points2: 0.01109
# symmetry2: 0.0141
# fractal_dimension2: 0.002085
# radius3: 19.07
# texture3: 30.88
# perimeter3: 123.4
# area3: 1138.0
# smoothness3: 0.1464' metadata={'source': './original_data.csv', 'row': 15}
#
#
# 32<class 'langchain_core.documents.base.Document'>: page_content='radius3: 19.07
# texture3: 30.88
# perimeter3: 123.4
# area3: 1138.0
# smoothness3: 0.1464
# compactness3: 0.1871
# concavity3: 0.2914
# concave_points3: 0.1609
# symmetry3: 0.3029
# fractal_dimension3: 0.08216
# tumor_size: 1.1
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 15}
#
#
# 33<class 'langchain_core.documents.base.Document'>: page_content='Time: 10
# radius1: 16.13
# texture1: 20.68
# perimeter1: 108.1
# area1: 798.8
# smoothness1: 0.117
# compactness1: 0.2022
# concavity1: 0.1722
# concave_points1: 0.1028
# symmetry1: 0.2164
# fractal_dimension1: 0.07356
# radius2: 0.5692
# texture2: 1.073
# perimeter2: 3.854
# area2: 54.18
# smoothness2: 0.007026
# compactness2: 0.02501
# concavity2: 0.03188
# concave_points2: 0.01297
# symmetry2: 0.01689
# fractal_dimension2: 0.004142
# radius3: 20.96
# texture3: 31.48
# perimeter3: 136.8
# area3: 1315.0
# smoothness3: 0.1789' metadata={'source': './original_data.csv', 'row': 16}
#
#
# 34<class 'langchain_core.documents.base.Document'>: page_content='radius3: 20.96
# texture3: 31.48
# perimeter3: 136.8
# area3: 1315.0
# smoothness3: 0.1789
# compactness3: 0.4233
# concavity3: 0.4784
# concave_points3: 0.2073
# symmetry3: 0.3706
# fractal_dimension3: 0.1142
# tumor_size: 3.0
# lymph_node_status: 1.0
# Outcome: R' metadata={'source': './original_data.csv', 'row': 16}
#
#
# 35<class 'langchain_core.documents.base.Document'>: page_content='Time: 20
# radius1: 15.34
# texture1: 14.26
# perimeter1: 102.5
# area1: 704.4
# smoothness1: 0.1073
# compactness1: 0.2135
# concavity1: 0.2077
# concave_points1: 0.09756
# symmetry1: 0.2521
# fractal_dimension1: 0.07032
# radius2: 0.4388
# texture2: 0.7096
# perimeter2: 3.384
# area2: 44.91
# smoothness2: 0.006789
# compactness2: 0.05328
# concavity2: 0.06446
# concave_points2: 0.02252
# symmetry2: 0.03672
# fractal_dimension2: 0.004394
# radius3: 18.07
# texture3: 19.08
# perimeter3: 125.1
# area3: 980.9
# smoothness3: 0.139' metadata={'source': './original_data.csv', 'row': 17}
#
#
# 36<class 'langchain_core.documents.base.Document'>: page_content='radius3: 18.07
# texture3: 19.08
# perimeter3: 125.1
# area3: 980.9
# smoothness3: 0.139
# compactness3: 0.5954
# concavity3: 0.6305
# concave_points3: 0.2393
# symmetry3: 0.4667
# fractal_dimension3: 0.09946
# tumor_size: 1.3
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 17}
#
#
# 37<class 'langchain_core.documents.base.Document'>: page_content='Time: 10
# radius1: 21.16
# texture1: 23.04
# perimeter1: 137.2
# area1: 1404.0
# smoothness1: 0.09428
# compactness1: 0.1022
# concavity1: 0.1097
# concave_points1: 0.08632
# symmetry1: 0.1769
# fractal_dimension1: 0.05278
# radius2: 0.6917
# texture2: 1.127
# perimeter2: 4.303
# area2: 93.99
# smoothness2: 0.004728
# compactness2: 0.01259
# concavity2: 0.01715
# concave_points2: 0.01038
# symmetry2: 0.01083
# fractal_dimension2: 0.001987
# radius3: 29.17
# texture3: 35.59
# perimeter3: 188.0
# area3: 2615.0
# smoothness3: 0.1401' metadata={'source': './original_data.csv', 'row': 18}
#
#
# 38<class 'langchain_core.documents.base.Document'>: page_content='radius3: 29.17
# texture3: 35.59
# perimeter3: 188.0
# area3: 2615.0
# smoothness3: 0.1401
# compactness3: 0.26
# concavity3: 0.3155
# concave_points3: 0.2009
# symmetry3: 0.2822
# fractal_dimension3: 0.07526
# tumor_size: 4.0
# lymph_node_status: 1.0
# Outcome: R' metadata={'source': './original_data.csv', 'row': 18}
#
#
# 39<class 'langchain_core.documents.base.Document'>: page_content='Time: 96
# radius1: 16.65
# texture1: 21.38
# perimeter1: 110.0
# area1: 904.6
# smoothness1: 0.1121
# compactness1: 0.1457
# concavity1: 0.1525
# concave_points1: 0.0917
# symmetry1: 0.1995
# fractal_dimension1: 0.0633
# radius2: 0.8068
# texture2: 0.9017
# perimeter2: 5.455
# area2: 102.6
# smoothness2: 0.006048
# compactness2: 0.01882
# concavity2: 0.02741
# concave_points2: 0.0113
# symmetry2: 0.01468
# fractal_dimension2: 0.002801
# radius3: 26.46
# texture3: 31.56
# perimeter3: 177.0
# area3: 2215.0
# smoothness3: 0.1805' metadata={'source': './original_data.csv', 'row': 19}
#
#
# 40<class 'langchain_core.documents.base.Document'>: page_content='radius3: 26.46
# texture3: 31.56
# perimeter3: 177.0
# area3: 2215.0
# smoothness3: 0.1805
# compactness3: 0.3578
# concavity3: 0.4695
# concave_points3: 0.2095
# symmetry3: 0.3613
# fractal_dimension3: 0.09564
# tumor_size: 3.0
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 19}
#
#
# 41<class 'langchain_core.documents.base.Document'>: page_content='Time: 116
# radius1: 17.14
# texture1: 16.4
# perimeter1: 116.0
# area1: 912.7
# smoothness1: 0.1186
# compactness1: 0.2276
# concavity1: 0.2229
# concave_points1: 0.1401
# symmetry1: 0.304
# fractal_dimension1: 0.07413
# radius2: 1.046
# texture2: 0.976
# perimeter2: 7.276
# area2: 111.4
# smoothness2: 0.008029
# compactness2: 0.03799
# concavity2: 0.03732
# concave_points2: 0.02397
# symmetry2: 0.02308
# fractal_dimension2: 0.007444
# radius3: 22.25
# texture3: 21.4
# perimeter3: 152.4
# area3: 1461.0
# smoothness3: 0.1545' metadata={'source': './original_data.csv', 'row': 20}
#
#
# 42<class 'langchain_core.documents.base.Document'>: page_content='radius3: 22.25
# texture3: 21.4
# perimeter3: 152.4
# area3: 1461.0
# smoothness3: 0.1545
# compactness3: 0.3949
# concavity3: 0.3853
# concave_points3: 0.255
# symmetry3: 0.4066
# fractal_dimension3: 0.1059
# tumor_size: 4.4
# lymph_node_status: 1.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 20}
#
#
# 43<class 'langchain_core.documents.base.Document'>: page_content='Time: 103
# radius1: 14.58
# texture1: 21.53
# perimeter1: 97.41
# area1: 644.8
# smoothness1: 0.1054
# compactness1: 0.1868
# concavity1: 0.1425
# concave_points1: 0.08783
# symmetry1: 0.2252
# fractal_dimension1: 0.06924
# radius2: 0.2545
# texture2: 0.9832
# perimeter2: 2.11
# area2: 21.05
# smoothness2: 0.004452
# compactness2: 0.03055
# concavity2: 0.02681
# concave_points2: 0.01352
# symmetry2: 0.01454
# fractal_dimension2: 0.003711
# radius3: 17.62
# texture3: 33.21
# perimeter3: 122.4
# area3: 896.9
# smoothness3: 0.1525' metadata={'source': './original_data.csv', 'row': 21}
#
#
# 44<class 'langchain_core.documents.base.Document'>: page_content='radius3: 17.62
# texture3: 33.21
# perimeter3: 122.4
# area3: 896.9
# smoothness3: 0.1525
# compactness3: 0.6643
# concavity3: 0.5539
# concave_points3: 0.2701
# symmetry3: 0.4264
# fractal_dimension3: 0.1275
# tumor_size: 2.5
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 21}
#
#
# 45<class 'langchain_core.documents.base.Document'>: page_content='Time: 16
# radius1: 18.61
# texture1: 20.25
# perimeter1: 122.1
# area1: 1094.0
# smoothness1: 0.0944
# compactness1: 0.1066
# concavity1: 0.149
# concave_points1: 0.07731
# symmetry1: 0.1697
# fractal_dimension1: 0.05699
# radius2: 0.8529
# texture2: 1.849
# perimeter2: 5.632
# area2: 93.54
# smoothness2: 0.01075
# compactness2: 0.02722
# concavity2: 0.05081
# concave_points2: 0.01911
# symmetry2: 0.02293
# fractal_dimension2: 0.004217
# radius3: 21.31
# texture3: 27.26
# perimeter3: 139.9
# area3: 1403.0
# smoothness3: 0.1338' metadata={'source': './original_data.csv', 'row': 22}
#
#
# 46<class 'langchain_core.documents.base.Document'>: page_content='radius3: 21.31
# texture3: 27.26
# perimeter3: 139.9
# area3: 1403.0
# smoothness3: 0.1338
# compactness3: 0.2117
# concavity3: 0.3446
# concave_points3: 0.149
# symmetry3: 0.2341
# fractal_dimension3: 0.07421
# tumor_size: 3.4
# lymph_node_status: 13.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 22}
#
#
# 47<class 'langchain_core.documents.base.Document'>: page_content='Time: 52
# radius1: 15.3
# texture1: 25.27
# perimeter1: 102.4
# area1: 732.4
# smoothness1: 0.1082
# compactness1: 0.1697
# concavity1: 0.1683
# concave_points1: 0.08751
# symmetry1: 0.1926
# fractal_dimension1: 0.0654
# radius2: 0.439
# texture2: 1.012
# perimeter2: 3.498
# area2: 43.5
# smoothness2: 0.005233
# compactness2: 0.03057
# concavity2: 0.03576
# concave_points2: 0.01083
# symmetry2: 0.01768
# fractal_dimension2: 0.002967
# radius3: 20.27
# texture3: 36.71
# perimeter3: 149.3
# area3: 1269.0
# smoothness3: 0.1641
# compactness3: 0.611' metadata={'source': './original_data.csv', 'row': 23}
#
#
# 48<class 'langchain_core.documents.base.Document'>: page_content='texture3: 36.71
# perimeter3: 149.3
# area3: 1269.0
# smoothness3: 0.1641
# compactness3: 0.611
# concavity3: 0.6335
# concave_points3: 0.2024
# symmetry3: 0.4027
# fractal_dimension3: 0.09876
# tumor_size: 2.0
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 23}
#
#
# 49<class 'langchain_core.documents.base.Document'>: page_content='Time: 94
# radius1: 17.57
# texture1: 15.05
# perimeter1: 115.0
# area1: 955.1
# smoothness1: 0.09847
# compactness1: 0.1157
# concavity1: 0.09875
# concave_points1: 0.07953
# symmetry1: 0.1739
# fractal_dimension1: 0.06149
# radius2: 0.6003
# texture2: 0.8225
# perimeter2: 4.655
# area2: 61.1
# smoothness2: 0.005627
# compactness2: 0.03033
# concavity2: 0.03407
# concave_points2: 0.01354
# symmetry2: 0.01925
# fractal_dimension2: 0.003742
# radius3: 20.01
# texture3: 19.52
# perimeter3: 134.9
# area3: 1227.0
# smoothness3: 0.1255' metadata={'source': './original_data.csv', 'row': 24}
#
#
# 50<class 'langchain_core.documents.base.Document'>: page_content='radius3: 20.01
# texture3: 19.52
# perimeter3: 134.9
# area3: 1227.0
# smoothness3: 0.1255
# compactness3: 0.2812
# concavity3: 0.2489
# concave_points3: 0.1456
# symmetry3: 0.2756
# fractal_dimension3: 0.07919
# tumor_size: 4.0
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 24}
#
#
# 51<class 'langchain_core.documents.base.Document'>: page_content='Time: 116
# radius1: 11.84
# texture1: 18.7
# perimeter1: 77.93
# area1: 440.6
# smoothness1: 0.1109
# compactness1: 0.1516
# concavity1: 0.1218
# concave_points1: 0.05182
# symmetry1: 0.2301
# fractal_dimension1: 0.07799
# radius2: 0.4825
# texture2: 1.03
# perimeter2: 3.475
# area2: 41.0
# smoothness2: 0.005551
# compactness2: 0.03414
# concavity2: 0.04205
# concave_points2: 0.01044
# symmetry2: 0.02273
# fractal_dimension2: 0.005667
# radius3: 16.82
# texture3: 28.12
# perimeter3: 119.4
# area3: 888.7
# smoothness3: 0.1637' metadata={'source': './original_data.csv', 'row': 25}
#
#
# 52<class 'langchain_core.documents.base.Document'>: page_content='radius3: 16.82
# texture3: 28.12
# perimeter3: 119.4
# area3: 888.7
# smoothness3: 0.1637
# compactness3: 0.5775
# concavity3: 0.6956
# concave_points3: 0.1546
# symmetry3: 0.4761
# fractal_dimension3: 0.1402
# tumor_size: 3.0
# lymph_node_status: 2.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 25}
#
#
# 53<class 'langchain_core.documents.base.Document'>: page_content='Time: 87
# radius1: 17.02
# texture1: 23.98
# perimeter1: 112.8
# area1: 899.3
# smoothness1: 0.1197
# compactness1: 0.1496
# concavity1: 0.2417
# concave_points1: 0.1203
# symmetry1: 0.2248
# fractal_dimension1: 0.06382
# radius2: 0.6009
# texture2: 1.398
# perimeter2: 3.999
# area2: 67.78
# smoothness2: 0.008268
# compactness2: 0.03082
# concavity2: 0.05042
# concave_points2: 0.01112
# symmetry2: 0.02102
# fractal_dimension2: 0.003854
# radius3: 20.88
# texture3: 32.09
# perimeter3: 136.1
# area3: 1344.0
# smoothness3: 0.1634' metadata={'source': './original_data.csv', 'row': 26}
#
#
# 54<class 'langchain_core.documents.base.Document'>: page_content='radius3: 20.88
# texture3: 32.09
# perimeter3: 136.1
# area3: 1344.0
# smoothness3: 0.1634
# compactness3: 0.3559
# concavity3: 0.5588
# concave_points3: 0.1847
# symmetry3: 0.353
# fractal_dimension3: 0.08482
# tumor_size: 1.3
# lymph_node_status: 1.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 26}
#
#
# 55<class 'langchain_core.documents.base.Document'>: page_content='Time: 53
# radius1: 19.27
# texture1: 26.47
# perimeter1: 127.9
# area1: 1162.0
# smoothness1: 0.09401
# compactness1: 0.1719
# concavity1: 0.1657
# concave_points1: 0.07593
# symmetry1: 0.1853
# fractal_dimension1: 0.06261
# radius2: 0.5558
# texture2: 0.6062
# perimeter2: 3.528
# area2: 68.17
# smoothness2: 0.005015
# compactness2: 0.03318
# concavity2: 0.03497
# concave_points2: 0.009643
# symmetry2: 0.01543
# fractal_dimension2: 0.003896
# radius3: 24.15
# texture3: 30.9
# perimeter3: 161.4
# area3: 1813.0
# smoothness3: 0.1509' metadata={'source': './original_data.csv', 'row': 27}
#
#
# 56<class 'langchain_core.documents.base.Document'>: page_content='radius3: 24.15
# texture3: 30.9
# perimeter3: 161.4
# area3: 1813.0
# smoothness3: 0.1509
# compactness3: 0.659
# concavity3: 0.6091
# concave_points3: 0.1785
# symmetry3: 0.3672
# fractal_dimension3: 0.1123
# tumor_size: 3.5
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 27}
#
#
# 57<class 'langchain_core.documents.base.Document'>: page_content='Time: 109
# radius1: 16.13
# texture1: 17.88
# perimeter1: 107.0
# area1: 807.2
# smoothness1: 0.104
# compactness1: 0.1559
# concavity1: 0.1354
# concave_points1: 0.07752
# symmetry1: 0.1998
# fractal_dimension1: 0.06515
# radius2: 0.334
# texture2: 0.6857
# perimeter2: 2.183
# area2: 35.03
# smoothness2: 0.004185
# compactness2: 0.02868
# concavity2: 0.02664
# concave_points2: 0.009067
# symmetry2: 0.01703
# fractal_dimension2: 0.003817
# radius3: 20.21
# texture3: 27.26
# perimeter3: 132.7
# area3: 1261.0
# smoothness3: 0.1446' metadata={'source': './original_data.csv', 'row': 28}
#
#
# 58<class 'langchain_core.documents.base.Document'>: page_content='radius3: 20.21
# texture3: 27.26
# perimeter3: 132.7
# area3: 1261.0
# smoothness3: 0.1446
# compactness3: 0.5804
# concavity3: 0.5274
# concave_points3: 0.1864
# symmetry3: 0.427
# fractal_dimension3: 0.1233
# tumor_size: 2.5
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 28}
#
#
# 59<class 'langchain_core.documents.base.Document'>: page_content='Time: 12
# radius1: 16.74
# texture1: 21.59
# perimeter1: 110.1
# area1: 869.5
# smoothness1: 0.0961
# compactness1: 0.1336
# concavity1: 0.1348
# concave_points1: 0.06018
# symmetry1: 0.1896
# fractal_dimension1: 0.05656
# radius2: 0.4615
# texture2: 0.9197
# perimeter2: 3.008
# area2: 45.19
# smoothness2: 0.005776
# compactness2: 0.02499
# concavity2: 0.03695
# concave_points2: 0.01195
# symmetry2: 0.02789
# fractal_dimension2: 0.002665
# radius3: 20.01
# texture3: 29.02
# perimeter3: 133.5
# area3: 1229.0
# smoothness3: 0.1563' metadata={'source': './original_data.csv', 'row': 29}
#
#
# 60<class 'langchain_core.documents.base.Document'>: page_content='radius3: 20.01
# texture3: 29.02
# perimeter3: 133.5
# area3: 1229.0
# smoothness3: 0.1563
# compactness3: 0.3835
# concavity3: 0.5409
# concave_points3: 0.1813
# symmetry3: 0.4863
# fractal_dimension3: 0.08633
# tumor_size: 1.5
# lymph_node_status: NA
# Outcome: N' metadata={'source': './original_data.csv', 'row': 29}
#
#
# 61<class 'langchain_core.documents.base.Document'>: page_content='Time: 31
# radius1: 14.25
# texture1: 21.72
# perimeter1: 93.63
# area1: 633.0
# smoothness1: 0.09823
# compactness1: 0.1098
# concavity1: 0.1319
# concave_points1: 0.05598
# symmetry1: 0.1885
# fractal_dimension1: 0.06125
# radius2: 0.286
# texture2: 1.019
# perimeter2: 2.657
# area2: 24.91
# smoothness2: 0.005878
# compactness2: 0.02995
# concavity2: 0.04815
# concave_points2: 0.01161
# symmetry2: 0.02028
# fractal_dimension2: 0.004022
# radius3: 15.89
# texture3: 30.36
# perimeter3: 116.2
# area3: 799.6
# smoothness3: 0.1446' metadata={'source': './original_data.csv', 'row': 30}
#
#
# 62<class 'langchain_core.documents.base.Document'>: page_content='radius3: 15.89
# texture3: 30.36
# perimeter3: 116.2
# area3: 799.6
# smoothness3: 0.1446
# compactness3: 0.4238
# concavity3: 0.5186
# concave_points3: 0.1447
# symmetry3: 0.3591
# fractal_dimension3: 0.1014
# tumor_size: 3.0
# lymph_node_status: 13.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 30}
#
#
# 63<class 'langchain_core.documents.base.Document'>: page_content='Time: 72
# radius1: 14.99
# texture1: 25.2
# perimeter1: 95.54
# area1: 698.8
# smoothness1: 0.09387
# compactness1: 0.05131
# concavity1: 0.02398
# concave_points1: 0.02899
# symmetry1: 0.1565
# fractal_dimension1: 0.05504
# radius2: 1.214
# texture2: 2.188
# perimeter2: 8.077
# area2: 106.0
# smoothness2: 0.006883
# compactness2: 0.01094
# concavity2: 0.01818
# concave_points2: 0.01917
# symmetry2: 0.007882
# fractal_dimension2: 0.001754
# radius3: 14.99
# texture3: 25.2
# perimeter3: 95.54
# area3: 698.8
# smoothness3: 0.09387' metadata={'source': './original_data.csv', 'row': 31}
#
#
# 64<class 'langchain_core.documents.base.Document'>: page_content='radius3: 14.99
# texture3: 25.2
# perimeter3: 95.54
# area3: 698.8
# smoothness3: 0.09387
# compactness3: 0.05131
# concavity3: 0.02398
# concave_points3: 0.02899
# symmetry3: 0.1565
# fractal_dimension3: 0.05504
# tumor_size: 3.5
# lymph_node_status: 10.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 31}
#
#
# 65<class 'langchain_core.documents.base.Document'>: page_content='Time: 76
# radius1: 13.48
# texture1: 20.82
# perimeter1: 88.4
# area1: 559.2
# smoothness1: 0.1016
# compactness1: 0.1255
# concavity1: 0.1063
# concave_points1: 0.05439
# symmetry1: 0.172
# fractal_dimension1: 0.06419
# radius2: 0.213
# texture2: 0.5914
# perimeter2: 1.545
# area2: 18.52
# smoothness2: 0.005367
# compactness2: 0.02239
# concavity2: 0.03049
# concave_points2: 0.01262
# symmetry2: 0.01377
# fractal_dimension2: 0.003187
# radius3: 15.53
# texture3: 26.02
# perimeter3: 107.3
# area3: 740.4
# smoothness3: 0.161' metadata={'source': './original_data.csv', 'row': 32}
#
#
# 66<class 'langchain_core.documents.base.Document'>: page_content='radius3: 15.53
# texture3: 26.02
# perimeter3: 107.3
# area3: 740.4
# smoothness3: 0.161
# compactness3: 0.4225
# concavity3: 0.503
# concave_points3: 0.2258
# symmetry3: 0.2807
# fractal_dimension3: 0.1071
# tumor_size: 2.5
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 32}
#
#
# 67<class 'langchain_core.documents.base.Document'>: page_content='Time: 34
# radius1: 13.44
# texture1: 21.58
# perimeter1: 86.18
# area1: 563.0
# smoothness1: 0.08162
# compactness1: 0.06031
# concavity1: 0.0311
# concave_points1: 0.02031
# symmetry1: 0.1784
# fractal_dimension1: 0.05587
# radius2: 0.2385
# texture2: 0.8265
# perimeter2: 1.572
# area2: 20.53
# smoothness2: 0.00328
# compactness2: 0.01102
# concavity2: 0.0139
# concave_points2: 0.006881
# symmetry2: 0.0138
# fractal_dimension2: 0.001286
# radius3: 15.93
# texture3: 30.25
# perimeter3: 102.5
# area3: 787.9
# smoothness3: 0.1094' metadata={'source': './original_data.csv', 'row': 33}
#
#
# 68<class 'langchain_core.documents.base.Document'>: page_content='radius3: 15.93
# texture3: 30.25
# perimeter3: 102.5
# area3: 787.9
# smoothness3: 0.1094
# compactness3: 0.2043
# concavity3: 0.2085
# concave_points3: 0.1112
# symmetry3: 0.2994
# fractal_dimension3: 0.07146
# tumor_size: 1.5
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 33}
#
#
# 69<class 'langchain_core.documents.base.Document'>: page_content='Time: 99
# radius1: 10.95
# texture1: 21.35
# perimeter1: 71.9
# area1: 371.1
# smoothness1: 0.1227
# compactness1: 0.1218
# concavity1: 0.1044
# concave_points1: 0.05669
# symmetry1: 0.1895
# fractal_dimension1: 0.0687
# radius2: 0.2366
# texture2: 1.428
# perimeter2: 1.822
# area2: 16.97
# smoothness2: 0.008064
# compactness2: 0.01764
# concavity2: 0.02595
# concave_points2: 0.01037
# symmetry2: 0.01357
# fractal_dimension2: 0.00304
# radius3: 12.84
# texture3: 35.34
# perimeter3: 87.22
# area3: 514.0
# smoothness3: 0.1909' metadata={'source': './original_data.csv', 'row': 34}
#
#
# 70<class 'langchain_core.documents.base.Document'>: page_content='radius3: 12.84
# texture3: 35.34
# perimeter3: 87.22
# area3: 514.0
# smoothness3: 0.1909
# compactness3: 0.2698
# concavity3: 0.4023
# concave_points3: 0.1424
# symmetry3: 0.2964
# fractal_dimension3: 0.09606
# tumor_size: 2.7
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 34}
#
#
# 71<class 'langchain_core.documents.base.Document'>: page_content='Time: 9
# radius1: 19.07
# texture1: 24.81
# perimeter1: 128.3
# area1: 1104.0
# smoothness1: 0.09081
# compactness1: 0.219
# concavity1: 0.2107
# concave_points1: 0.09961
# symmetry1: 0.231
# fractal_dimension1: 0.06343
# radius2: 0.9811
# texture2: 1.666
# perimeter2: 8.83
# area2: 104.9
# smoothness2: 0.006548
# compactness2: 0.1006
# concavity2: 0.09723
# concave_points2: 0.02638
# symmetry2: 0.05333
# fractal_dimension2: 0.007646
# radius3: 24.09
# texture3: 33.17
# perimeter3: 177.4
# area3: 1651.0
# smoothness3: 0.1247' metadata={'source': './original_data.csv', 'row': 35}
#
#
# 72<class 'langchain_core.documents.base.Document'>: page_content='radius3: 24.09
# texture3: 33.17
# perimeter3: 177.4
# area3: 1651.0
# smoothness3: 0.1247
# compactness3: 0.7444
# concavity3: 0.7242
# concave_points3: 0.2493
# symmetry3: 0.467
# fractal_dimension3: 0.1038
# tumor_size: 2.3
# lymph_node_status: 0.0
# Outcome: R' metadata={'source': './original_data.csv', 'row': 35}
#
#
# 73<class 'langchain_core.documents.base.Document'>: page_content='Time: 114
# radius1: 13.28
# texture1: 20.28
# perimeter1: 87.32
# area1: 545.2
# smoothness1: 0.1041
# compactness1: 0.1436
# concavity1: 0.09847
# concave_points1: 0.06158
# symmetry1: 0.1974
# fractal_dimension1: 0.06782
# radius2: 0.3704
# texture2: 0.8249
# perimeter2: 2.427
# area2: 31.33
# smoothness2: 0.005072
# compactness2: 0.02147
# concavity2: 0.02185
# concave_points2: 0.00956
# symmetry2: 0.01719
# fractal_dimension2: 0.003317
# radius3: 17.38
# texture3: 28.0
# perimeter3: 113.1
# area3: 907.2
# smoothness3: 0.153' metadata={'source': './original_data.csv', 'row': 36}
#
#
# 74<class 'langchain_core.documents.base.Document'>: page_content='radius3: 17.38
# texture3: 28.0
# perimeter3: 113.1
# area3: 907.2
# smoothness3: 0.153
# compactness3: 0.3724
# concavity3: 0.3664
# concave_points3: 0.1492
# symmetry3: 0.3739
# fractal_dimension3: 0.1027
# tumor_size: 2.6
# lymph_node_status: 1.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 36}
#
#
# 75<class 'langchain_core.documents.base.Document'>: page_content='Time: 76
# radius1: 13.17
# texture1: 21.81
# perimeter1: 85.42
# area1: 531.5
# smoothness1: 0.09714
# compactness1: 0.1047
# concavity1: 0.08259
# concave_points1: 0.05252
# symmetry1: 0.1746
# fractal_dimension1: 0.06177
# radius2: 0.1938
# texture2: 0.6123
# perimeter2: 1.334
# area2: 14.49
# smoothness2: 0.00335
# compactness2: 0.01384
# concavity2: 0.01452
# concave_points2: 0.006853
# symmetry2: 0.01113
# fractal_dimension2: 0.00172
# radius3: 16.23
# texture3: 29.89
# perimeter3: 105.5
# area3: 740.7
# smoothness3: 0.1503' metadata={'source': './original_data.csv', 'row': 37}
#
#
# 76<class 'langchain_core.documents.base.Document'>: page_content='radius3: 16.23
# texture3: 29.89
# perimeter3: 105.5
# area3: 740.7
# smoothness3: 0.1503
# compactness3: 0.3904
# concavity3: 0.3728
# concave_points3: 0.1607
# symmetry3: 0.3693
# fractal_dimension3: 0.09618
# tumor_size: 1.7
# lymph_node_status: 1.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 37}
#
#
# 77<class 'langchain_core.documents.base.Document'>: page_content='Time: 8
# radius1: 18.65
# texture1: 17.6
# perimeter1: 123.7
# area1: 1076.0
# smoothness1: 0.1099
# compactness1: 0.1686
# concavity1: 0.1974
# concave_points1: 0.1009
# symmetry1: 0.1907
# fractal_dimension1: 0.06049
# radius2: 0.6289
# texture2: 0.6633
# perimeter2: 4.293
# area2: 71.56
# smoothness2: 0.006294
# compactness2: 0.03994
# concavity2: 0.05554
# concave_points2: 0.01695
# symmetry2: 0.02428
# fractal_dimension2: 0.003535
# radius3: 22.82
# texture3: 21.32
# perimeter3: 150.6
# area3: 1567.0
# smoothness3: 0.1679' metadata={'source': './original_data.csv', 'row': 38}
#
#
# 78<class 'langchain_core.documents.base.Document'>: page_content='radius3: 22.82
# texture3: 21.32
# perimeter3: 150.6
# area3: 1567.0
# smoothness3: 0.1679
# compactness3: 0.509
# concavity3: 0.7345
# concave_points3: 0.2378
# symmetry3: 0.3799
# fractal_dimension3: 0.09185
# tumor_size: 1.8
# lymph_node_status: 0.0
# Outcome: R' metadata={'source': './original_data.csv', 'row': 38}
#
#
# 79<class 'langchain_core.documents.base.Document'>: page_content='Time: 111
# radius1: 13.17
# texture1: 18.66
# perimeter1: 85.98
# area1: 534.6
# smoothness1: 0.1158
# compactness1: 0.1231
# concavity1: 0.1226
# concave_points1: 0.0734
# symmetry1: 0.2128
# fractal_dimension1: 0.06777
# radius2: 0.2871
# texture2: 0.8937
# perimeter2: 1.897
# area2: 24.25
# smoothness2: 0.006532
# compactness2: 0.02336
# concavity2: 0.02905
# concave_points2: 0.01215
# symmetry2: 0.01743
# fractal_dimension2: 0.003643
# radius3: 15.67
# texture3: 27.95
# perimeter3: 102.8
# area3: 759.4
# smoothness3: 0.1786' metadata={'source': './original_data.csv', 'row': 39}
#
#
# 80<class 'langchain_core.documents.base.Document'>: page_content='radius3: 15.67
# texture3: 27.95
# perimeter3: 102.8
# area3: 759.4
# smoothness3: 0.1786
# compactness3: 0.4166
# concavity3: 0.5006
# concave_points3: 0.2088
# symmetry3: 0.39
# fractal_dimension3: 0.1179
# tumor_size: 1.0
# lymph_node_status: 1.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 39}
#
#
# 81<class 'langchain_core.documents.base.Document'>: page_content='Time: 48
# radius1: 15.1
# texture1: 22.02
# perimeter1: 97.26
# area1: 712.8
# smoothness1: 0.09056
# compactness1: 0.07081
# concavity1: 0.05253
# concave_points1: 0.03334
# symmetry1: 0.1616
# fractal_dimension1: 0.05684
# radius2: 0.3105
# texture2: 0.8339
# perimeter2: 2.097
# area2: 29.91
# smoothness2: 0.004675
# compactness2: 0.0103
# concavity2: 0.01603
# concave_points2: 0.009222
# symmetry2: 0.01095
# fractal_dimension2: 0.001629
# radius3: 18.1
# texture3: 31.69
# perimeter3: 117.7
# area3: 1030.0
# smoothness3: 0.1389' metadata={'source': './original_data.csv', 'row': 40}
#
#
# 82<class 'langchain_core.documents.base.Document'>: page_content='radius3: 18.1
# texture3: 31.69
# perimeter3: 117.7
# area3: 1030.0
# smoothness3: 0.1389
# compactness3: 0.2057
# concavity3: 0.2712
# concave_points3: 0.153
# symmetry3: 0.2675
# fractal_dimension3: 0.07873
# tumor_size: 2.5
# lymph_node_status: 0.0
# Outcome: R' metadata={'source': './original_data.csv', 'row': 40}
#
#
# 83<class 'langchain_core.documents.base.Document'>: page_content='Time: 11
# radius1: 19.21
# texture1: 18.57
# perimeter1: 125.5
# area1: 1152.0
# smoothness1: 0.1053
# compactness1: 0.1267
# concavity1: 0.1323
# concave_points1: 0.08994
# symmetry1: 0.1917
# fractal_dimension1: 0.05961
# radius2: 0.7275
# texture2: 1.193
# perimeter2: 4.837
# area2: 102.5
# smoothness2: 0.006458
# compactness2: 0.02306
# concavity2: 0.02945
# concave_points2: 0.01538
# symmetry2: 0.01852
# fractal_dimension2: 0.002608
# radius3: 26.14
# texture3: 28.14
# perimeter3: 170.1
# area3: 2145.0
# smoothness3: 0.1624' metadata={'source': './original_data.csv', 'row': 41}
#
#
# 84<class 'langchain_core.documents.base.Document'>: page_content='radius3: 26.14
# texture3: 28.14
# perimeter3: 170.1
# area3: 2145.0
# smoothness3: 0.1624
# compactness3: 0.3511
# concavity3: 0.3879
# concave_points3: 0.2091
# symmetry3: 0.3537
# fractal_dimension3: 0.08294
# tumor_size: 3.2
# lymph_node_status: 13.0
# Outcome: R' metadata={'source': './original_data.csv', 'row': 41}
#
#
# 85<class 'langchain_core.documents.base.Document'>: page_content='Time: 62
# radius1: 14.71
# texture1: 21.59
# perimeter1: 95.55
# area1: 656.9
# smoothness1: 0.1137
# compactness1: 0.1365
# concavity1: 0.1293
# concave_points1: 0.08123
# symmetry1: 0.2027
# fractal_dimension1: 0.06758
# radius2: 0.4226
# texture2: 1.15
# perimeter2: 2.735
# area2: 40.09
# smoothness2: 0.003659
# compactness2: 0.02855
# concavity2: 0.02572
# concave_points2: 0.01272
# symmetry2: 0.01817
# fractal_dimension2: 0.004108
# radius3: 17.87
# texture3: 30.7
# perimeter3: 115.7
# area3: 985.5
# smoothness3: 0.1368' metadata={'source': './original_data.csv', 'row': 42}
#
#
# 86<class 'langchain_core.documents.base.Document'>: page_content='radius3: 17.87
# texture3: 30.7
# perimeter3: 115.7
# area3: 985.5
# smoothness3: 0.1368
# compactness3: 0.429
# concavity3: 0.3587
# concave_points3: 0.1834
# symmetry3: 0.3698
# fractal_dimension3: 0.1094
# tumor_size: 6.5
# lymph_node_status: 6.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 42}
#
#
# 87<class 'langchain_core.documents.base.Document'>: page_content='Time: 34
# radius1: 14.25
# texture1: 22.15
# perimeter1: 96.42
# area1: 645.7
# smoothness1: 0.1049
# compactness1: 0.2008
# concavity1: 0.2135
# concave_points1: 0.08653
# symmetry1: 0.1949
# fractal_dimension1: 0.07292
# radius2: 0.7036
# texture2: 1.268
# perimeter2: 5.373
# area2: 60.78
# smoothness2: 0.009407
# compactness2: 0.07056
# concavity2: 0.06899
# concave_points2: 0.01848
# symmetry2: 0.017
# fractal_dimension2: 0.006113
# radius3: 17.67
# texture3: 29.51
# perimeter3: 119.1
# area3: 959.5
# smoothness3: 0.164' metadata={'source': './original_data.csv', 'row': 43}
#
#
# 88<class 'langchain_core.documents.base.Document'>: page_content='radius3: 17.67
# texture3: 29.51
# perimeter3: 119.1
# area3: 959.5
# smoothness3: 0.164
# compactness3: 0.6247
# concavity3: 0.6922
# concave_points3: 0.1785
# symmetry3: 0.2844
# fractal_dimension3: 0.1132
# tumor_size: 1.5
# lymph_node_status: 0.0
# Outcome: R' metadata={'source': './original_data.csv', 'row': 43}
#
#
# 89<class 'langchain_core.documents.base.Document'>: page_content='Time: 19
# radius1: 12.68
# texture1: 23.84
# perimeter1: 82.69
# area1: 499.0
# smoothness1: 0.1122
# compactness1: 0.1262
# concavity1: 0.1128
# concave_points1: 0.06873
# symmetry1: 0.1905
# fractal_dimension1: 0.0659
# radius2: 0.4255
# texture2: 1.178
# perimeter2: 2.927
# area2: 36.46
# smoothness2: 0.007781
# compactness2: 0.02648
# concavity2: 0.02973
# concave_points2: 0.0129
# symmetry2: 0.01635
# fractal_dimension2: 0.003601
# radius3: 17.09
# texture3: 33.47
# perimeter3: 111.8
# area3: 888.3
# smoothness3: 0.1851' metadata={'source': './original_data.csv', 'row': 44}
#
#
# 90<class 'langchain_core.documents.base.Document'>: page_content='radius3: 17.09
# texture3: 33.47
# perimeter3: 111.8
# area3: 888.3
# smoothness3: 0.1851
# compactness3: 0.4061
# concavity3: 0.4024
# concave_points3: 0.1716
# symmetry3: 0.3383
# fractal_dimension3: 0.1031
# tumor_size: 1.2
# lymph_node_status: 1.0
# Outcome: R' metadata={'source': './original_data.csv', 'row': 44}
#
#
# 91<class 'langchain_core.documents.base.Document'>: page_content='Time: 106
# radius1: 14.78
# texture1: 23.94
# perimeter1: 97.4
# area1: 668.3
# smoothness1: 0.1172
# compactness1: 0.1479
# concavity1: 0.1267
# concave_points1: 0.09029
# symmetry1: 0.1953
# fractal_dimension1: 0.06654
# radius2: 0.3577
# texture2: 1.281
# perimeter2: 2.45
# area2: 35.24
# smoothness2: 0.006703
# compactness2: 0.0231
# concavity2: 0.02315
# concave_points2: 0.01184
# symmetry2: 0.019
# fractal_dimension2: 0.003224
# radius3: 17.31
# texture3: 33.39
# perimeter3: 114.6
# area3: 925.1
# smoothness3: 0.1648
# compactness3: 0.3416' metadata={'source': './original_data.csv', 'row': 45}
#
#
# 92<class 'langchain_core.documents.base.Document'>: page_content='texture3: 33.39
# perimeter3: 114.6
# area3: 925.1
# smoothness3: 0.1648
# compactness3: 0.3416
# concavity3: 0.3024
# concave_points3: 0.1614
# symmetry3: 0.3321
# fractal_dimension3: 0.08911
# tumor_size: 1.2
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 45}
#
#
# 93<class 'langchain_core.documents.base.Document'>: page_content='Time: 70
# radius1: 17.2
# texture1: 24.52
# perimeter1: 114.2
# area1: 929.4
# smoothness1: 0.1071
# compactness1: 0.183
# concavity1: 0.1692
# concave_points1: 0.07944
# symmetry1: 0.1927
# fractal_dimension1: 0.06487
# radius2: 0.5907
# texture2: 1.041
# perimeter2: 3.705
# area2: 69.47
# smoothness2: 0.00582
# compactness2: 0.05616
# concavity2: 0.04252
# concave_points2: 0.01127
# symmetry2: 0.01527
# fractal_dimension2: 0.006299
# radius3: 23.32
# texture3: 33.82
# perimeter3: 151.6
# area3: 1681.0
# smoothness3: 0.1585' metadata={'source': './original_data.csv', 'row': 46}
#
#
# 94<class 'langchain_core.documents.base.Document'>: page_content='radius3: 23.32
# texture3: 33.82
# perimeter3: 151.6
# area3: 1681.0
# smoothness3: 0.1585
# compactness3: 0.7394
# concavity3: 0.6566
# concave_points3: 0.1899
# symmetry3: 0.3313
# fractal_dimension3: 0.1339
# tumor_size: 5.0
# lymph_node_status: 4.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 46}
#
#
# 95<class 'langchain_core.documents.base.Document'>: page_content='Time: 26
# radius1: 13.8
# texture1: 15.79
# perimeter1: 90.43
# area1: 584.1
# smoothness1: 0.1007
# compactness1: 0.128
# concavity1: 0.07789
# concave_points1: 0.05069
# symmetry1: 0.1662
# fractal_dimension1: 0.06566
# radius2: 0.2787
# texture2: 0.6205
# perimeter2: 1.957
# area2: 23.35
# smoothness2: 0.004717
# compactness2: 0.02065
# concavity2: 0.01759
# concave_points2: 0.009206
# symmetry2: 0.0122
# fractal_dimension2: 0.00313
# radius3: 16.57
# texture3: 20.86
# perimeter3: 110.3
# area3: 812.4
# smoothness3: 0.1411' metadata={'source': './original_data.csv', 'row': 47}
#
#
# 96<class 'langchain_core.documents.base.Document'>: page_content='radius3: 16.57
# texture3: 20.86
# perimeter3: 110.3
# area3: 812.4
# smoothness3: 0.1411
# compactness3: 0.3542
# concavity3: 0.2779
# concave_points3: 0.1383
# symmetry3: 0.2589
# fractal_dimension3: 0.103
# tumor_size: 3.0
# lymph_node_status: 2.0
# Outcome: R' metadata={'source': './original_data.csv', 'row': 47}
#
#
# 97<class 'langchain_core.documents.base.Document'>: page_content='Time: 97
# radius1: 19.55
# texture1: 15.49
# perimeter1: 128.0
# area1: 1156.0
# smoothness1: 0.1079
# compactness1: 0.1747
# concavity1: 0.2352
# concave_points1: 0.1196
# symmetry1: 0.2616
# fractal_dimension1: 0.06752
# radius2: 1.223
# texture2: 0.4489
# perimeter2: 7.87
# area2: 168.8
# smoothness2: 0.01101
# compactness2: 0.04272
# concavity2: 0.08624
# concave_points2: 0.02737
# symmetry2: 0.06041
# fractal_dimension2: 0.007503
# radius3: 23.73
# texture3: 17.21
# perimeter3: 153.4
# area3: 1633.0
# smoothness3: 0.1534' metadata={'source': './original_data.csv', 'row': 48}
#
#
# 98<class 'langchain_core.documents.base.Document'>: page_content='radius3: 23.73
# texture3: 17.21
# perimeter3: 153.4
# area3: 1633.0
# smoothness3: 0.1534
# compactness3: 0.3391
# concavity3: 0.5819
# concave_points3: 0.22
# symmetry3: 0.4714
# fractal_dimension3: 0.09721
# tumor_size: 3.0
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 48}
#
#
# 99<class 'langchain_core.documents.base.Document'>: page_content='Time: 40
# radius1: 19.1
# texture1: 26.29
# perimeter1: 129.1
# area1: 1132.0
# smoothness1: 0.1215
# compactness1: 0.1791
# concavity1: 0.1937
# concave_points1: 0.1469
# symmetry1: 0.1634
# ...
#
#
# 366<class 'langchain_core.documents.base.Document'>: page_content='radius3: 20.03
# texture3: 22.43
# perimeter3: 130.0
# area3: 1214.0
# smoothness3: 0.09273
# compactness3: 0.1259
# concavity3: 0.08201
# concave_points3: 0.1116
# symmetry3: 0.2147
# fractal_dimension3: 0.05644
# tumor_size: 2.5
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 182}
#
#
# 367<class 'langchain_core.documents.base.Document'>: page_content='Time: 15
# radius1: 15.66
# texture1: 24.51
# perimeter1: 102.0
# area1: 771.1
# smoothness1: 0.08886
# compactness1: 0.08731
# concavity1: 0.09483
# concave_points1: 0.04286
# symmetry1: 0.1995
# fractal_dimension1: 0.05626
# radius2: 0.5016
# texture2: 1.824
# perimeter2: 4.013
# area2: 52.6
# smoothness2: 0.005164
# compactness2: 0.0231
# concavity2: 0.03871
# concave_points2: 0.0129
# symmetry2: 0.01923
# fractal_dimension2: 0.001897
# radius3: 18.47
# texture3: 35.09
# perimeter3: 124.0
# area3: 1066.0
# smoothness3: 0.1182' metadata={'source': './original_data.csv', 'row': 183}
#
#
# 368<class 'langchain_core.documents.base.Document'>: page_content='radius3: 18.47
# texture3: 35.09
# perimeter3: 124.0
# area3: 1066.0
# smoothness3: 0.1182
# compactness3: 0.2486
# concavity3: 0.3508
# concave_points3: 0.1273
# symmetry3: 0.2964
# fractal_dimension3: 0.06591
# tumor_size: 2.0
# lymph_node_status: 4.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 183}
#
#
# 369<class 'langchain_core.documents.base.Document'>: page_content='Time: 11
# radius1: 22.44
# texture1: 27.42
# perimeter1: 150.6
# area1: 1504.0
# smoothness1: 0.1211
# compactness1: 0.2082
# concavity1: 0.3579
# concave_points1: 0.1842
# symmetry1: 0.2524
# fractal_dimension1: 0.05848
# radius2: 1.083
# texture2: 3.503
# perimeter2: 7.164
# area2: 123.9
# smoothness2: 0.008771
# compactness2: 0.03241
# concavity2: 0.07453
# concave_points2: 0.02372
# symmetry2: 0.03172
# fractal_dimension2: 0.003287
# radius3: 23.99
# texture3: 32.51
# perimeter3: 161.2
# area3: 1689.0
# smoothness3: 0.133' metadata={'source': './original_data.csv', 'row': 184}
#
#
# 370<class 'langchain_core.documents.base.Document'>: page_content='radius3: 23.99
# texture3: 32.51
# perimeter3: 161.2
# area3: 1689.0
# smoothness3: 0.133
# compactness3: 0.258
# concavity3: 0.4741
# concave_points3: 0.2135
# symmetry3: 0.2809
# fractal_dimension3: 0.06318
# tumor_size: 1.0
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 184}
#
#
# 371<class 'langchain_core.documents.base.Document'>: page_content='Time: 17
# radius1: 17.98
# texture1: 23.96
# perimeter1: 120.0
# area1: 995.0
# smoothness1: 0.1157
# compactness1: 0.1739
# concavity1: 0.1954
# concave_points1: 0.1219
# symmetry1: 0.1981
# fractal_dimension1: 0.06306
# radius2: 0.7937
# texture2: 2.595
# perimeter2: 5.639
# area2: 90.08
# smoothness2: 0.007286
# compactness2: 0.03164
# concavity2: 0.04003
# concave_points2: 0.0205
# symmetry2: 0.02609
# fractal_dimension2: 0.005366
# radius3: 20.05
# texture3: 32.23
# perimeter3: 135.2
# area3: 1225.0
# smoothness3: 0.134' metadata={'source': './original_data.csv', 'row': 185}
#
#
# 372<class 'langchain_core.documents.base.Document'>: page_content='radius3: 20.05
# texture3: 32.23
# perimeter3: 135.2
# area3: 1225.0
# smoothness3: 0.134
# compactness3: 0.2606
# concavity3: 0.3124
# concave_points3: 0.1753
# symmetry3: 0.2746
# fractal_dimension3: 0.0783
# tumor_size: 2.5
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 185}
#
#
# 373<class 'langchain_core.documents.base.Document'>: page_content='Time: 17
# radius1: 13.63
# texture1: 24.7
# perimeter1: 89.65
# area1: 569.2
# smoothness1: 0.1055
# compactness1: 0.1312
# concavity1: 0.1161
# concave_points1: 0.06403
# symmetry1: 0.1791
# fractal_dimension1: 0.07058
# radius2: 0.3223
# texture2: 1.148
# perimeter2: 2.797
# area2: 25.79
# smoothness2: 0.007254
# compactness2: 0.03085
# concavity2: 0.03225
# concave_points2: 0.01585
# symmetry2: 0.01783
# fractal_dimension2: 0.004359
# radius3: 15.33
# texture3: 31.96
# perimeter3: 107.7
# area3: 712.2
# smoothness3: 0.1554' metadata={'source': './original_data.csv', 'row': 186}
#
#
# 374<class 'langchain_core.documents.base.Document'>: page_content='radius3: 15.33
# texture3: 31.96
# perimeter3: 107.7
# area3: 712.2
# smoothness3: 0.1554
# compactness3: 0.3515
# concavity3: 0.3409
# concave_points3: 0.1689
# symmetry3: 0.2739
# fractal_dimension3: 0.09945
# tumor_size: 2.0
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 186}
#
#
# 375<class 'langchain_core.documents.base.Document'>: page_content='Time: 9
# radius1: 23.01
# texture1: 33.87
# perimeter1: 156.8
# area1: 1705.0
# smoothness1: 0.1157
# compactness1: 0.1948
# concavity1: 0.2979
# concave_points1: 0.1522
# symmetry1: 0.1799
# fractal_dimension1: 0.0634
# radius2: 1.819
# texture2: 2.708
# perimeter2: 13.28
# area2: 253.8
# smoothness2: 0.008461
# compactness2: 0.03397
# concavity2: 0.05986
# concave_points2: 0.02232
# symmetry2: 0.03215
# fractal_dimension2: 0.003898
# radius3: 28.39
# texture3: 41.66
# perimeter3: 197.8
# area3: 2481.0
# smoothness3: 0.1432' metadata={'source': './original_data.csv', 'row': 187}
#
#
# 376<class 'langchain_core.documents.base.Document'>: page_content='radius3: 28.39
# texture3: 41.66
# perimeter3: 197.8
# area3: 2481.0
# smoothness3: 0.1432
# compactness3: 0.2895
# concavity3: 0.4937
# concave_points3: 0.211
# symmetry3: 0.2774
# fractal_dimension3: 0.07542
# tumor_size: 4.0
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 187}
#
#
# 377<class 'langchain_core.documents.base.Document'>: page_content='Time: 10
# radius1: 22.41
# texture1: 29.95
# perimeter1: 145.5
# area1: 1528.0
# smoothness1: 0.1119
# compactness1: 0.1699
# concavity1: 0.3076
# concave_points1: 0.1594
# symmetry1: 0.2099
# fractal_dimension1: 0.06803
# radius2: 1.463
# texture2: 1.717
# perimeter2: 9.939
# area2: 233.7
# smoothness2: 0.003676
# compactness2: 0.04185
# concavity2: 0.06688
# concave_points2: 0.01772
# symmetry2: 0.01538
# fractal_dimension2: 0.005663
# radius3: 29.27
# texture3: 38.4
# perimeter3: 194.5
# area3: 2690.0
# smoothness3: 0.1251' metadata={'source': './original_data.csv', 'row': 188}
#
#
# 378<class 'langchain_core.documents.base.Document'>: page_content='radius3: 29.27
# texture3: 38.4
# perimeter3: 194.5
# area3: 2690.0
# smoothness3: 0.1251
# compactness3: 0.3832
# concavity3: 0.5842
# concave_points3: 0.2422
# symmetry3: 0.2729
# fractal_dimension3: 0.09391
# tumor_size: 1.0
# lymph_node_status: 1.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 188}
#
#
# 379<class 'langchain_core.documents.base.Document'>: page_content='Time: 15
# radius1: 12.53
# texture1: 30.98
# perimeter1: 80.41
# area1: 490.9
# smoothness1: 0.09252
# compactness1: 0.06271
# concavity1: 0.06151
# concave_points1: 0.03938
# symmetry1: 0.1993
# fractal_dimension1: 0.06554
# radius2: 0.3708
# texture2: 1.47
# perimeter2: 2.546
# area2: 30.45
# smoothness2: 0.009003
# compactness2: 0.01059
# concavity2: 0.02372
# concave_points2: 0.01286
# symmetry2: 0.01837
# fractal_dimension2: 0.003858
# radius3: 14.95
# texture3: 41.05
# perimeter3: 96.75
# area3: 694.6
# smoothness3: 0.156' metadata={'source': './original_data.csv', 'row': 189}
#
#
# 380<class 'langchain_core.documents.base.Document'>: page_content='radius3: 14.95
# texture3: 41.05
# perimeter3: 96.75
# area3: 694.6
# smoothness3: 0.156
# compactness3: 0.1358
# concavity3: 0.2436
# concave_points3: 0.1259
# symmetry3: 0.3292
# fractal_dimension3: 0.09406
# tumor_size: 3.0
# lymph_node_status: 7.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 189}
#
#
# 381<class 'langchain_core.documents.base.Document'>: page_content='Time: 6
# radius1: 19.8
# texture1: 20.46
# perimeter1: 130.2
# area1: 1235.0
# smoothness1: 0.09652
# compactness1: 0.1077
# concavity1: 0.1599
# concave_points1: 0.08705
# symmetry1: 0.162
# fractal_dimension1: 0.05731
# radius2: 0.8215
# texture2: 1.26
# perimeter2: 6.436
# area2: 116.7
# smoothness2: 0.009331
# compactness2: 0.02827
# concavity2: 0.06039
# concave_points2: 0.02226
# symmetry2: 0.01728
# fractal_dimension2: 0.002806
# radius3: 22.61
# texture3: 25.78
# perimeter3: 155.1
# area3: 1623.0
# smoothness3: 0.1373' metadata={'source': './original_data.csv', 'row': 190}
#
#
# 382<class 'langchain_core.documents.base.Document'>: page_content='radius3: 22.61
# texture3: 25.78
# perimeter3: 155.1
# area3: 1623.0
# smoothness3: 0.1373
# compactness3: 0.2368
# concavity3: 0.3931
# concave_points3: 0.184
# symmetry3: 0.2382
# fractal_dimension3: 0.06831
# tumor_size: 2.1
# lymph_node_status: 2.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 190}
#
#
# 383<class 'langchain_core.documents.base.Document'>: page_content='Time: 8
# radius1: 19.96
# texture1: 27.41
# perimeter1: 130.8
# area1: 1238.0
# smoothness1: 0.09075
# compactness1: 0.1167
# concavity1: 0.1355
# concave_points1: 0.08397
# symmetry1: 0.16
# fractal_dimension1: 0.05461
# radius2: 0.5299
# texture2: 1.562
# perimeter2: 3.39
# area2: 66.13
# smoothness2: 0.005734
# compactness2: 0.02089
# concavity2: 0.04279
# concave_points2: 0.01392
# symmetry2: 0.01051
# fractal_dimension2: 0.0037
# radius3: 22.75
# texture3: 36.88
# perimeter3: 150.3
# area3: 1603.0
# smoothness3: 0.1293' metadata={'source': './original_data.csv', 'row': 191}
#
#
# 384<class 'langchain_core.documents.base.Document'>: page_content='radius3: 22.75
# texture3: 36.88
# perimeter3: 150.3
# area3: 1603.0
# smoothness3: 0.1293
# compactness3: 0.2513
# concavity3: 0.4106
# concave_points3: 0.1638
# symmetry3: 0.2245
# fractal_dimension3: 0.07842
# tumor_size: 4.0
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 191}
#
#
# 385<class 'langchain_core.documents.base.Document'>: page_content='Time: 3
# radius1: 19.22
# texture1: 27.18
# perimeter1: 128.8
# area1: 1134.0
# smoothness1: 0.109
# compactness1: 0.1777
# concavity1: 0.2138
# concave_points1: 0.1116
# symmetry1: 0.1924
# fractal_dimension1: 0.06389
# radius2: 0.497
# texture2: 2.403
# perimeter2: 4.493
# area2: 61.18
# smoothness2: 0.006133
# compactness2: 0.04109
# concavity2: 0.05917
# concave_points2: 0.01756
# symmetry2: 0.0218
# fractal_dimension2: 0.004305
# radius3: 22.57
# texture3: 44.6
# perimeter3: 161.0
# area3: 1565.0
# smoothness3: 0.1501
# compactness3: 0.513' metadata={'source': './original_data.csv', 'row': 192}
#
#
# 386<class 'langchain_core.documents.base.Document'>: page_content='texture3: 44.6
# perimeter3: 161.0
# area3: 1565.0
# smoothness3: 0.1501
# compactness3: 0.513
# concavity3: 0.6841
# concave_points3: 0.2099
# symmetry3: 0.3484
# fractal_dimension3: 0.09774
# tumor_size: 0.8
# lymph_node_status: 1.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 192}
#
#
# 387<class 'langchain_core.documents.base.Document'>: page_content='Time: 3
# radius1: 14.72
# texture1: 25.26
# perimeter1: 99.28
# area1: 657.5
# smoothness1: 0.1174
# compactness1: 0.2112
# concavity1: 0.1729
# concave_points1: 0.09465
# symmetry1: 0.2079
# fractal_dimension1: 0.07496
# radius2: 0.3405
# texture2: 1.158
# perimeter2: 2.188
# area2: 26.12
# smoothness2: 0.004957
# compactness2: 0.04553
# concavity2: 0.05166
# concave_points2: 0.01597
# symmetry2: 0.02539
# fractal_dimension2: 0.005548
# radius3: 16.67
# texture3: 31.97
# perimeter3: 111.6
# area3: 814.8
# smoothness3: 0.1464' metadata={'source': './original_data.csv', 'row': 193}
#
#
# 388<class 'langchain_core.documents.base.Document'>: page_content='radius3: 16.67
# texture3: 31.97
# perimeter3: 111.6
# area3: 814.8
# smoothness3: 0.1464
# compactness3: 0.5352
# concavity3: 0.5655
# concave_points3: 0.1974
# symmetry3: 0.3778
# fractal_dimension3: 0.1132
# tumor_size: 1.7
# lymph_node_status: 21.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 193}
#
#
# 389<class 'langchain_core.documents.base.Document'>: page_content='Time: 10
# radius1: 22.52
# texture1: 21.92
# perimeter1: 146.9
# area1: 1597.0
# smoothness1: 0.07592
# compactness1: 0.09162
# concavity1: 0.06862
# concave_points1: 0.06367
# symmetry1: 0.1728
# fractal_dimension1: 0.05262
# radius2: 1.374
# texture2: 2.312
# perimeter2: 9.938
# area2: 192.4
# smoothness2: 0.004422
# compactness2: 0.02679
# concavity2: 0.02433
# concave_points2: 0.02036
# symmetry2: 0.02486
# fractal_dimension2: 0.003922
# radius3: 24.67
# texture3: 24.81
# perimeter3: 162.1
# area3: 1902.0
# smoothness3: 0.08191' metadata={'source': './original_data.csv', 'row': 194}
#
#
# 390<class 'langchain_core.documents.base.Document'>: page_content='radius3: 24.67
# texture3: 24.81
# perimeter3: 162.1
# area3: 1902.0
# smoothness3: 0.08191
# compactness3: 0.1319
# concavity3: 0.1056
# concave_points3: 0.09378
# symmetry3: 0.2061
# fractal_dimension3: 0.05788
# tumor_size: 6.0
# lymph_node_status: 2.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 194}
#
#
# 391<class 'langchain_core.documents.base.Document'>: page_content='Time: 8
# radius1: 15.44
# texture1: 31.18
# perimeter1: 101.0
# area1: 740.4
# smoothness1: 0.09399
# compactness1: 0.1062
# concavity1: 0.1375
# concave_points1: 0.065
# symmetry1: 0.1735
# fractal_dimension1: 0.06105
# radius2: 0.3235
# texture2: 1.839
# perimeter2: 1.971
# area2: 32.61
# smoothness2: 0.006178
# compactness2: 0.02088
# concavity2: 0.02834
# concave_points2: 0.01079
# symmetry2: 0.02122
# fractal_dimension2: 0.003168
# radius3: 17.34
# texture3: 41.48
# perimeter3: 112.6
# area3: 929.0
# smoothness3: 0.1272' metadata={'source': './original_data.csv', 'row': 195}
#
#
# 392<class 'langchain_core.documents.base.Document'>: page_content='radius3: 17.34
# texture3: 41.48
# perimeter3: 112.6
# area3: 929.0
# smoothness3: 0.1272
# compactness3: 0.2362
# concavity3: 0.2975
# concave_points3: 0.1286
# symmetry3: 0.2914
# fractal_dimension3: 0.08024
# tumor_size: 1.5
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 195}
#
#
# 393<class 'langchain_core.documents.base.Document'>: page_content='Time: 12
# radius1: 17.17
# texture1: 29.19
# perimeter1: 110.0
# area1: 915.3
# smoothness1: 0.08952
# compactness1: 0.06655
# concavity1: 0.06583
# concave_points1: 0.05068
# symmetry1: 0.1793
# fractal_dimension1: 0.05392
# radius2: 0.6101
# texture2: 1.425
# perimeter2: 3.827
# area2: 63.02
# smoothness2: 0.00689
# compactness2: 0.01556
# concavity2: 0.03155
# concave_points2: 0.009714
# symmetry2: 0.02734
# fractal_dimension2: 0.001377
# radius3: 20.76
# texture3: 36.66
# perimeter3: 132.5
# area3: 1295.0
# smoothness3: 0.1261' metadata={'source': './original_data.csv', 'row': 196}
#
#
# 394<class 'langchain_core.documents.base.Document'>: page_content='radius3: 20.76
# texture3: 36.66
# perimeter3: 132.5
# area3: 1295.0
# smoothness3: 0.1261
# compactness3: 0.1572
# concavity3: 0.2141
# concave_points3: 0.0952
# symmetry3: 0.3362
# fractal_dimension3: 0.06033
# tumor_size: 3.7
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 196}
#
#
# 395<class 'langchain_core.documents.base.Document'>: page_content='Time: 3
# radius1: 21.42
# texture1: 22.84
# perimeter1: 145.0
# area1: 1440.0
# smoothness1: 0.107
# compactness1: 0.1939
# concavity1: 0.238
# concave_points1: 0.1318
# symmetry1: 0.1884
# fractal_dimension1: 0.06472
# radius2: 1.085
# texture2: 0.8469
# perimeter2: 8.308
# area2: 142.5
# smoothness2: 0.006831
# compactness2: 0.03541
# concavity2: 0.04948
# concave_points2: 0.0177
# symmetry2: 0.01481
# fractal_dimension2: 0.003979
# radius3: 28.34
# texture3: 27.98
# perimeter3: 198.3
# area3: 2375.0
# smoothness3: 0.1498' metadata={'source': './original_data.csv', 'row': 197}
#
#
# 396<class 'langchain_core.documents.base.Document'>: page_content='radius3: 28.34
# texture3: 27.98
# perimeter3: 198.3
# area3: 2375.0
# smoothness3: 0.1498
# compactness3: 0.4379
# concavity3: 0.5411
# concave_points3: 0.2215
# symmetry3: 0.2832
# fractal_dimension3: 0.08981
# tumor_size: 3.0
# lymph_node_status: NA
# Outcome: R' metadata={'source': './original_data.csv', 'row': 197}
#
#
# 397<class 'langchain_core.documents.base.Document'>: page_content='Time: 6
# radius1: 16.7
# texture1: 28.13
# perimeter1: 110.3
# area1: 885.4
# smoothness1: 0.08896
# compactness1: 0.1131
# concavity1: 0.1012
# concave_points1: 0.04989
# symmetry1: 0.189
# fractal_dimension1: 0.06035
# radius2: 0.6052
# texture2: 1.235
# perimeter2: 4.243
# area2: 63.91
# smoothness2: 0.007767
# compactness2: 0.02631
# concavity2: 0.03957
# concave_points2: 0.01411
# symmetry2: 0.01957
# fractal_dimension2: 0.003606
# radius3: 19.74
# texture3: 34.92
# perimeter3: 128.8
# area3: 1213.0
# smoothness3: 0.133' metadata={'source': './original_data.csv', 'row': 198}
#
#
# 398<class 'langchain_core.documents.base.Document'>: page_content='radius3: 19.74
# texture3: 34.92
# perimeter3: 128.8
# area3: 1213.0
# smoothness3: 0.133
# compactness3: 0.2808
# concavity3: 0.3455
# concave_points3: 0.1317
# symmetry3: 0.3035
# fractal_dimension3: 0.08036
# tumor_size: 3.5
# lymph_node_status: 0.0
# Outcome: N' metadata={'source': './original_data.csv', 'row': 198}

# %%
# Data source 4/4
#load the statistics from the algorithms from 'mldata.txt'

from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

#loading text file the output is a langchain Document object
mldata = TextLoader('./mldata.txt')
mldata_loader= mldata.load()
print(mldata_loader.__class__)
#spliting Document object to smaller document objects 
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 500, chunk_overlap=100, length_function=len, is_separator_regex=False)
mldata_loader_docs = text_splitter.split_documents(mldata_loader)
counter=0
for data in mldata_loader_docs:
    counter += 1
    print(f"\n\n{counter}{data.__class__}: {data}")
counter = 0
# Out:
# <class 'list'>
#
#
# 1<class 'langchain_core.documents.base.Document'>: page_content='The project aims to develop a conversational AI system to interact with a breast cancer prognosis repository,
# generate explanations and predictions based on the data, and provide insights to healthcare professionals and patients.
# The project will develop a conversational interface that allows users to interact with the LLM model and ask questions
# about breast cancer prognosis. The interface will use natural language processing (NLP) techniques to understand' metadata={'source': './mldata.txt'}
#
#
# 2<class 'langchain_core.documents.base.Document'>: page_content='user input and generate responses based on the LLM model's predictions. This project will be hosted at umerai.com
# at later stages of project completion,for general use.' metadata={'source': './mldata.txt'}
#
#
# 3<class 'langchain_core.documents.base.Document'>: page_content='Machine Learning Data
# Meta Data
# uci_id: 16
# name: Breast Cancer Wisconsin (Prognostic)
# repository_url: https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic
# data_url: https://archive.ics.uci.edu/static/public/16/data.csv
# abstract: Prognostic Wisconsin Breast Cancer Database
# area: Health and Medicine
# tasks: ['Classification', 'Regression']
# characteristics: ['Multivariate']
# num_instances: 198
# num_features: 33
# feature_types: ['Real']
# demographics: []
# target_col: ['Outcome']' metadata={'source': './mldata.txt'}
#
#
# 4<class 'langchain_core.documents.base.Document'>: page_content='num_features: 33
# feature_types: ['Real']
# demographics: []
# target_col: ['Outcome']
# index_col: ['ID']
# has_missing_values: yes
# missing_values_symbol: NaN
# year_of_dataset_creation: 1995
# last_updated: Sun Jan 14 2024
# dataset_doi: 10.24432/C5GK50
# creators: ['William Wolberg', 'W. Street', 'Olvi Mangasarian']
# intro_paper: None' metadata={'source': './mldata.txt'}
#
#
# 5<class 'langchain_core.documents.base.Document'>: page_content='additional_info: {'summary': 'Each record represents follow-up data for one breast cancer case.  These are consecutive patients seen by Dr. Wolberg since 1984, and include only those cases exhibiting invasive breast cancer and no evidence of distant metastases at the time of diagnosis. \r\n\r\nThe first 30 features are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass.  They describe characteristics of the cell nuclei present in the image. A few of the images can' metadata={'source': './mldata.txt'}
#
#
# 6<class 'langchain_core.documents.base.Document'>: page_content='They describe characteristics of the cell nuclei present in the image. A few of the images can be found at http://www.cs.wisc.edu/~street/images/\r\n\r\nThe separation described above was obtained using Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree Construction Via Linear Programming." Proceedings of the 4th Midwest Artificial Intelligence and Cognitive Science Society, pp. 97-101, 1992], a classification method which uses linear programming to construct a decision tree.' metadata={'source': './mldata.txt'}
#
#
# 7<class 'langchain_core.documents.base.Document'>: page_content='97-101, 1992], a classification method which uses linear programming to construct a decision tree.  Relevant features were selected using an exhaustive search in the space of 1-4 features and 1-3 separating planes.\r\n\r\nThe actual linear program used to obtain the separating plane in the 3-dimensional space is that described in: \r\n[K. P. Bennett and O. L. Mangasarian: "Robust Linear Programming Discrimination of Two Linearly Inseparable Sets", Optimization Methods and Software 1, 1992,' metadata={'source': './mldata.txt'}
#
#
# 8<class 'langchain_core.documents.base.Document'>: page_content='Discrimination of Two Linearly Inseparable Sets", Optimization Methods and Software 1, 1992, 23-34].\r\n\r\nThe Recurrence Surface Approximation (RSA) method is a linear programming model which predicts Time To Recur using both recurrent and nonrecurrent cases.  See references (i) and (ii) above for details of the RSA method. \r\n\r\nThis database is also available through the UW CS ftp server:\r\n\r\nftp ftp.cs.wisc.edu\r\ncd math-prog/cpo-dataset/machine-learn/WPBC/', 'purpose': None,' metadata={'source': './mldata.txt'}
#
#
# 9<class 'langchain_core.documents.base.Document'>: page_content='ftp.cs.wisc.edu\r\ncd math-prog/cpo-dataset/machine-learn/WPBC/', 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': '1) ID number\n2) Outcome (R = recur, N = nonrecur)\n3) Time (recurrence time if field 2 = R, disease-free time if \n\tfield 2\t= N)\n4-33) Ten real-valued features are computed for each cell nucleus:\n\n\ta) radius (mean of distances from center to points on' metadata={'source': './mldata.txt'}
#
#
# 10<class 'langchain_core.documents.base.Document'>: page_content='are computed for each cell nucleus:\n\n\ta) radius (mean of distances from center to points on the perimeter)\n\tb) texture (standard deviation of gray-scale values)\n\tc) perimeter\n\td) area\n\te) smoothness (local variation in radius lengths)\n\tf) compactness (perimeter^2 / area - 1.0)\n\tg) concavity (severity of concave portions of the contour)\n\th) concave points (number of concave portions of the contour)\n\ti) symmetry \n\tj) fractal dimension ("coastline approximation" - 1)\n\n34)' metadata={'source': './mldata.txt'}
#
#
# 11<class 'langchain_core.documents.base.Document'>: page_content='of the contour)\n\ti) symmetry \n\tj) fractal dimension ("coastline approximation" - 1)\n\n34) Tumor size - diameter of the excised tumor in centimeters\n35) Lymph node status - number of positive axillary lymph nodes\nobserved at time of surgery', 'citation': None}' metadata={'source': './mldata.txt'}

# %% [markdown]
# ### Step 3: Chroma Vector Store and ensure data integrity

# %%
# step 1: initializing
# https://python.langchain.com/v0.2/docs/integrations/vectorstores/chroma/
# https://python.langchain.com/v0.2/api_reference/community/vectorstores/langchain_community.vectorstores.chroma.Chroma.html#chroma
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings

vector_store = Chroma(collection_name="dpad_talk2data", embedding_function=OpenAIEmbeddings(), persist_directory="./chroma_langchain_db")

# step 2: Interacting - adding, storing, updating - playaround with the data
# adding documents with unique ids of each
from uuid import uuid4
from langchain_core.documents import Document

documents= web_page_loader_docs + data_info_table_loader + original_data_loader_docs + mldata_loader_docs
uuids = [str(uuid4()) for _ in range(len(documents))] # "_" can be "x", it does not matter. It is not used, anyway

# %%
print(uuids.__class__, len(uuids))
# Out:
# <class 'list'> 462

# %%
# storing data in chroma_langchain_db collection name is dpad_talk2data
vector_store.add_documents(documents=documents, ids=uuids)
# Out:
# ['dc42d43b-5c35-4dfe-924a-7cc0331576fd',
#  '3bdcffa6-67a9-4887-b61d-c18daf955d46',
#  '86c1f4ff-76e1-4a09-a2ac-7a7c4e470079',
#  '46477c4e-a617-4c50-95dc-b141d6cf0dd1',
#  'e7137d8f-8562-4640-a9c5-29b2b7fb6193',
#  'e0fe5791-8560-4d9c-a0b7-f239b598b44a',
#  '17e3a743-b922-439f-95fa-3b64dc92449a',
#  '1fc63272-6547-4e3d-8df9-402eacb04e92',
#  '79e1f3e8-0876-43bb-95ec-4796b5dd5530',
#  '75b480a3-3cd2-45b1-b572-58e85d80f081',
#  'f6fa04f1-6502-4cda-b196-344225937c38',
#  '7a1733f4-8830-4d9a-bc4a-12581de7c733',
#  'e03a2d62-8169-4e2c-9c2f-5b5fb6bfb8cf',
#  'c4d57ccc-1731-4103-a7bb-aebc7b02a728',
#  '7683041d-c86a-49af-a12d-31ac2df372f8',
#  'df0d99ed-5a4f-483c-adb2-a448e3906ce6',
#  '9738bb37-f7bf-414b-b7f2-5c2ff9858fb0',
#  '984477cd-884d-4288-b205-b649e09c5bb8',
#  'b6c7360f-afcd-4cb6-aa29-5ab8f22b8536',
#  'b500a7bb-bb47-4026-8586-c0e165a23603',
#  'f1d7f1e5-6475-4353-a4ad-a53c910d9a38',
#  '1304a498-7ce5-4448-a13f-a54090e8d9f3',
#  'c98ef236-f989-41ac-bf34-d759acc7869a',
#  '246dc0e5-5958-45b4-ba1e-01ae7fb7d023',
#  '5f59db5b-ee11-44f6-938b-08e93d815a71',
#  '02d67373-e7ce-4445-8af1-562811350d71',
#  '692561b8-4c1d-4f6c-aaf9-52ff99e23431',
#  '04454e63-90f5-4ab9-86eb-92bbf5e1f3cb',
#  'c846c62f-32f6-4738-9cbb-b4dd6d79e3b4',
#  '25284970-f0ab-4746-98ea-b8539062afee',
#  '1def1e4d-108e-4a22-b8fa-257b6ad2c432',
#  '5a60f050-0bb8-428c-b7ac-fa272531ebf6',
#  '86b20664-fd7f-4822-909f-85d6a6966328',
#  '62e85763-dba7-4d73-82af-65a81407b400',
#  'ef6eba92-28a9-42cc-9bf7-17f4c69e15e3',
#  '1bb07a11-4c6c-4e80-bbec-37e86c2e29b3',
#  '1979f432-08b7-4bcf-86a1-e9df54feeeb9',
#  '3a7ad616-c79a-43a4-ad92-610f883e81db',
#  'c6949858-1b2b-4afc-a7a7-f251e0f3a5c0',
#  '763d859b-6ee1-48d0-8ef0-646a5b1cf32b',
#  '955abb66-7638-4afd-ac92-9671853c8e19',
#  'f95e5a11-7e81-4ca6-a869-6ed8c726e264',
#  '3ab7a2a0-3041-4fdc-a166-e8f4e05fd34d',
#  '1f3f9ec1-43d4-4345-9e7d-915df017d8e9',
#  'f3970b47-a03d-49ed-9a31-5a5d2d17dc1d',
#  '93d94022-17db-43ed-af6c-8d4e729c5ab9',
#  '2df1d145-264f-4b9d-8a13-ce664bb1720d',
#  'ef42401e-1ada-470d-a7be-0f74881412ed',
#  '320f13b2-5be4-40ab-875b-755552c4d69b',
#  '5f0b5427-b161-455f-982b-0aedc279f232',
#  'c483dac9-f976-48ee-8047-7cf711181a17',
#  '3d8e7915-f40e-4db7-ba24-6426e290b8e8',
#  '96598493-0466-4416-8409-c2cb1b2398c8',
#  '663456fe-3232-45e5-a238-4724641d28bf',
#  'bfd8fb09-0d4c-4fb4-b653-278e25ad8631',
#  'b8040a39-2a90-4895-91f2-7e7a4fb7fa99',
#  'fd69b1b1-8319-4e75-99f6-d7be1f1d8437',
#  '8b44316a-a068-4123-859e-e48a0682c198',
#  '2c60d81b-8a06-46da-80cf-d716e75e685d',
#  'c8aa0731-58e1-4ff1-844d-681cc9a435fa',
#  'a4d3f5bc-f087-46f6-bf4b-7209b3beb07f',
#  '4256ea4e-2df5-4d51-9d9f-38cf49dbf95a',
#  'e0d4901c-667a-4073-abbd-c5c0c3bf96e4',
#  '53b6a5e0-24b7-4b01-be17-a5a326fc0955',
#  'baad3d9b-9778-4a33-a2fd-56f8d3c83ccb',
#  '17b08476-5ab4-47b8-9ede-2161c6f742d2',
#  '38989d3f-1b9e-414e-ad7e-cd75b9303f59',
#  'd673f309-b562-40db-b84b-eea156c69be4',
#  '58683232-cd44-40a7-9b22-294b92336415']

# %%
counter = 0
for x in range(len(uuids)):
    counter += 1
    print(counter, vector_store.get(uuids[x]))
# Out:
# 1 {'ids': ['dc42d43b-5c35-4dfe-924a-7cc0331576fd'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['UCI Machine Learning Repository\n\n\n\n\nBreast Cancer Wisconsin (Prognostic) - UCI Machine Learning Repository'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 2 {'ids': ['3bdcffa6-67a9-4887-b61d-c18daf955d46'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['Datasets Contribute Dataset Donate New Link External About Us Who We Are Citation Metadata Contact Information           Login       Breast Cancer Wisconsin (Prognostic)  Donated on 11/30/1995     Prognostic Wisconsin Breast Cancer Database  Dataset Characteristics Multivariate Subject Area Health and Medicine Associated Tasks Classification, Regression Feature Type Real # Instances 198 # Features 33   Dataset Information    Additional Information  Each record represents follow-up data'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 3 {'ids': ['86c1f4ff-76e1-4a09-a2ac-7a7c4e470079'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['Features 33   Dataset Information    Additional Information  Each record represents follow-up data for one breast cancer case.  These are consecutive patients seen by Dr. Wolberg since 1984, and include only those cases exhibiting invasive breast cancer and no evidence of distant metastases at the time of diagnosis.'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 4 {'ids': ['46477c4e-a617-4c50-95dc-b141d6cf0dd1'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['The first 30 features are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass.  They describe characteristics of the cell nuclei present in the image. A few of the images can be found at http://www.cs.wisc.edu/~street/images/'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 5 {'ids': ['e7137d8f-8562-4640-a9c5-29b2b7fb6193'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['The separation described above was obtained using Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree Construction Via Linear Programming." Proceedings of the 4th Midwest Artificial Intelligence and Cognitive Science Society, pp. 97-101, 1992], a classification method which uses linear programming to construct a decision tree.  Relevant features were selected using an exhaustive search in the space of 1-4 features and 1-3 separating planes.'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 6 {'ids': ['e0fe5791-8560-4d9c-a0b7-f239b598b44a'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['The actual linear program used to obtain the separating plane in the 3-dimensional space is that described in: \r\n[K. P. Bennett and O. L. Mangasarian: "Robust Linear Programming Discrimination of Two Linearly Inseparable Sets", Optimization Methods and Software 1, 1992, 23-34].'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 7 {'ids': ['17e3a743-b922-439f-95fa-3b64dc92449a'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['The Recurrence Surface Approximation (RSA) method is a linear programming model which predicts Time To Recur using both recurrent and nonrecurrent cases.  See references (i) and (ii) above for details of the RSA method. \r\n\r\nThis database is also available through the UW CS ftp server:\r\n\r\nftp ftp.cs.wisc.edu'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 8 {'ids': ['1fc63272-6547-4e3d-8df9-402eacb04e92'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['cd math-prog/cpo-dataset/machine-learn/WPBC/  Has Missing Values?  Yes     Variables Table      Variable NameRoleTypeDescriptionUnitsMissing Values IDIDIntegerno TimeFeatureIntegerno radius1FeatureContinuousno texture1FeatureContinuousno perimeter1FeatureContinuousno area1FeatureContinuousno smoothness1FeatureContinuousno compactness1FeatureContinuousno concavity1FeatureContinuousno concave_points1FeatureContinuousno  Rows per page 510152025 0 to 10 of 35    Additional Variable Information'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 9 {'ids': ['79e1f3e8-0876-43bb-95ec-4796b5dd5530'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['Rows per page 510152025 0 to 10 of 35    Additional Variable Information       1) ID number'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 10 {'ids': ['75b480a3-3cd2-45b1-b572-58e85d80f081'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['2) Outcome (R = recur, N = nonrecur)\n3) Time (recurrence time if field 2 = R, disease-free time if \n\tfield 2\t= N)\n4-33) Ten real-valued features are computed for each cell nucleus:'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 11 {'ids': ['f6fa04f1-6502-4cda-b196-344225937c38'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['a) radius (mean of distances from center to points on the perimeter)\n\tb) texture (standard deviation of gray-scale values)\n\tc) perimeter\n\td) area\n\te) smoothness (local variation in radius lengths)\n\tf) compactness (perimeter^2 / area - 1.0)\n\tg) concavity (severity of concave portions of the contour)\n\th) concave points (number of concave portions of the contour)\n\ti) symmetry \n\tj) fractal dimension ("coastline approximation" - 1)'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 12 {'ids': ['7a1733f4-8830-4d9a-bc4a-12581de7c733'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['34) Tumor size - diameter of the excised tumor in centimeters\n35) Lymph node status - number of positive axillary lymph nodes\nobserved at time of surgery  Class Labels  R = recur, N = nonrecur    Dataset Files     FileSize wpbc.data44KB wpbc.names5.7KB    Reviews    There are no reviews for this dataset yet. Login to Write a Review   Write a Review   0  Comments'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 13 {'ids': ['e03a2d62-8169-4e2c-9c2f-5b5fb6bfb8cf'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['Submit Cancel     Download (21KB)  Import in Python  Install the ucimlrepo package    pip install ucimlrepo Import the dataset into your code    from ucimlrepo import fetch_ucirepo \n  \n# fetch dataset \nbreast_cancer_wisconsin_prognostic = fetch_ucirepo(id=16) \n  \n# data (as pandas dataframes) \nX = breast_cancer_wisconsin_prognostic.data.features \ny = breast_cancer_wisconsin_prognostic.data.targets \n  \n# metadata \nprint(breast_cancer_wisconsin_prognostic.metadata) \n  \n# variable information'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 14 {'ids': ['c4d57ccc-1731-4103-a7bb-aebc7b02a728'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['# metadata \nprint(breast_cancer_wisconsin_prognostic.metadata) \n  \n# variable information \nprint(breast_cancer_wisconsin_prognostic.variables)'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 15 {'ids': ['7683041d-c86a-49af-a12d-31ac2df372f8'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['# variable information \nprint(breast_cancer_wisconsin_prognostic.variables) \n View the full documentation Cite   0 citations  43707 views Citation     Wolberg, W., Street, W., & Mangasarian, O. (1995). Breast Cancer Wisconsin (Prognostic) [Dataset]. UCI Machine Learning Repository. https://doi.org/10.24432/C5GK50. Style: APAMLAChicagoVancouverIEEEBibTeX    Creators    William Wolberg    W. Street    Olvi Mangasarian     DOI 10.24432/C5GK50  License This dataset is licensed under a'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 16 {'ids': ['df0d99ed-5a4f-483c-adb2-a448e3906ce6'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['Creative Commons Attribution 4.0 International\n(CC BY 4.0) license. This allows for the sharing and adaptation of the datasets for any purpose,\nprovided that the appropriate credit is given.  By using the UCI Machine Learning Repository,'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 17 {'ids': ['9738bb37-f7bf-414b-b7f2-5c2ff9858fb0'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['you acknowledge and accept the cookies and privacy practices used by the UCI Machine Learning Repository. Accept Read Policy  The Project About Us CML National Science Foundation Navigation Home View Datasets Donate a Dataset Logistics Contact Privacy Notice Feature Request or Bug Report  Browse Datasets Donate a Dataset Link an external Dataset  Who We Are Citation Metadata Contact Information   Login'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 18 {'ids': ['984477cd-884d-4288-b205-b649e09c5bb8'], 'embeddings': None, 'metadatas': [{'row': 0, 'source': './data_info_table.csv'}], 'documents': ['name: name\nrole: role\ntype: type\ndemographic: demographic\ndescription: description\nunits: units\nmissing_values: missing_values'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 19 {'ids': ['b6c7360f-afcd-4cb6-aa29-5ab8f22b8536'], 'embeddings': None, 'metadatas': [{'row': 1, 'source': './data_info_table.csv'}], 'documents': ['name: ID\nrole: ID\ntype: Integer\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 20 {'ids': ['b500a7bb-bb47-4026-8586-c0e165a23603'], 'embeddings': None, 'metadatas': [{'row': 2, 'source': './data_info_table.csv'}], 'documents': ['name: Time\nrole: Feature\ntype: Integer\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 21 {'ids': ['f1d7f1e5-6475-4353-a4ad-a53c910d9a38'], 'embeddings': None, 'metadatas': [{'row': 3, 'source': './data_info_table.csv'}], 'documents': ['name: radius1\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 22 {'ids': ['1304a498-7ce5-4448-a13f-a54090e8d9f3'], 'embeddings': None, 'metadatas': [{'row': 4, 'source': './data_info_table.csv'}], 'documents': ['name: texture1\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 23 {'ids': ['c98ef236-f989-41ac-bf34-d759acc7869a'], 'embeddings': None, 'metadatas': [{'row': 5, 'source': './data_info_table.csv'}], 'documents': ['name: perimeter1\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 24 {'ids': ['246dc0e5-5958-45b4-ba1e-01ae7fb7d023'], 'embeddings': None, 'metadatas': [{'row': 6, 'source': './data_info_table.csv'}], 'documents': ['name: area1\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 25 {'ids': ['5f59db5b-ee11-44f6-938b-08e93d815a71'], 'embeddings': None, 'metadatas': [{'row': 7, 'source': './data_info_table.csv'}], 'documents': ['name: smoothness1\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 26 {'ids': ['02d67373-e7ce-4445-8af1-562811350d71'], 'embeddings': None, 'metadatas': [{'row': 8, 'source': './data_info_table.csv'}], 'documents': ['name: compactness1\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 27 {'ids': ['692561b8-4c1d-4f6c-aaf9-52ff99e23431'], 'embeddings': None, 'metadatas': [{'row': 9, 'source': './data_info_table.csv'}], 'documents': ['name: concavity1\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 28 {'ids': ['04454e63-90f5-4ab9-86eb-92bbf5e1f3cb'], 'embeddings': None, 'metadatas': [{'row': 10, 'source': './data_info_table.csv'}], 'documents': ['name: concave_points1\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 29 {'ids': ['c846c62f-32f6-4738-9cbb-b4dd6d79e3b4'], 'embeddings': None, 'metadatas': [{'row': 11, 'source': './data_info_table.csv'}], 'documents': ['name: symmetry1\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 30 {'ids': ['25284970-f0ab-4746-98ea-b8539062afee'], 'embeddings': None, 'metadatas': [{'row': 12, 'source': './data_info_table.csv'}], 'documents': ['name: fractal_dimension1\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 31 {'ids': ['1def1e4d-108e-4a22-b8fa-257b6ad2c432'], 'embeddings': None, 'metadatas': [{'row': 13, 'source': './data_info_table.csv'}], 'documents': ['name: radius2\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 32 {'ids': ['5a60f050-0bb8-428c-b7ac-fa272531ebf6'], 'embeddings': None, 'metadatas': [{'row': 14, 'source': './data_info_table.csv'}], 'documents': ['name: texture2\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 33 {'ids': ['86b20664-fd7f-4822-909f-85d6a6966328'], 'embeddings': None, 'metadatas': [{'row': 15, 'source': './data_info_table.csv'}], 'documents': ['name: perimeter2\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 34 {'ids': ['62e85763-dba7-4d73-82af-65a81407b400'], 'embeddings': None, 'metadatas': [{'row': 16, 'source': './data_info_table.csv'}], 'documents': ['name: area2\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 35 {'ids': ['ef6eba92-28a9-42cc-9bf7-17f4c69e15e3'], 'embeddings': None, 'metadatas': [{'row': 17, 'source': './data_info_table.csv'}], 'documents': ['name: smoothness2\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 36 {'ids': ['429c3488-7ee2-4689-94a2-6af39028debc'], 'embeddings': None, 'metadatas': [{'row': 18, 'source': './data_info_table.csv'}], 'documents': ['name: compactness2\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 37 {'ids': ['7f0a4061-9f11-4b23-b12d-e68d16f06265'], 'embeddings': None, 'metadatas': [{'row': 19, 'source': './data_info_table.csv'}], 'documents': ['name: concavity2\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 38 {'ids': ['d02d7559-d1ef-4dce-8ece-3146a0eb0ccd'], 'embeddings': None, 'metadatas': [{'row': 20, 'source': './data_info_table.csv'}], 'documents': ['name: concave_points2\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 39 {'ids': ['c1bfd58d-8cb7-4abb-90a0-e27f3a05f9ab'], 'embeddings': None, 'metadatas': [{'row': 21, 'source': './data_info_table.csv'}], 'documents': ['name: symmetry2\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 40 {'ids': ['fd7f011c-7419-4c2a-81c5-b83a7ee55592'], 'embeddings': None, 'metadatas': [{'row': 22, 'source': './data_info_table.csv'}], 'documents': ['name: fractal_dimension2\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 41 {'ids': ['ac58e8b0-e1f1-4c57-a0d7-7cbb15e22c31'], 'embeddings': None, 'metadatas': [{'row': 23, 'source': './data_info_table.csv'}], 'documents': ['name: radius3\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 42 {'ids': ['ecd1e3b4-a203-4ebf-852c-86af6b52227b'], 'embeddings': None, 'metadatas': [{'row': 24, 'source': './data_info_table.csv'}], 'documents': ['name: texture3\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 43 {'ids': ['aff0cd86-fe17-44af-b9c1-a1a59d059347'], 'embeddings': None, 'metadatas': [{'row': 25, 'source': './data_info_table.csv'}], 'documents': ['name: perimeter3\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 44 {'ids': ['099c5ec5-50e9-4410-b7c7-12c3f4046fd1'], 'embeddings': None, 'metadatas': [{'row': 26, 'source': './data_info_table.csv'}], 'documents': ['name: area3\nrole: Feature\ntype: Integer\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 45 {'ids': ['40c29b69-d44d-4ab0-bf17-7473abf882c8'], 'embeddings': None, 'metadatas': [{'row': 27, 'source': './data_info_table.csv'}], 'documents': ['name: smoothness3\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 46 {'ids': ['19cb1291-fac5-4d77-bea2-0cbf39121129'], 'embeddings': None, 'metadatas': [{'row': 28, 'source': './data_info_table.csv'}], 'documents': ['name: compactness3\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 47 {'ids': ['06a4f6fd-b746-45fc-a92f-1fc6a794575d'], 'embeddings': None, 'metadatas': [{'row': 29, 'source': './data_info_table.csv'}], 'documents': ['name: concavity3\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 48 {'ids': ['a1defe5b-ab72-4445-bc89-edfdfeb9373f'], 'embeddings': None, 'metadatas': [{'row': 30, 'source': './data_info_table.csv'}], 'documents': ['name: concave_points3\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 49 {'ids': ['38f19b54-edc8-47bf-8f2c-21ed8d08dba4'], 'embeddings': None, 'metadatas': [{'row': 31, 'source': './data_info_table.csv'}], 'documents': ['name: symmetry3\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 50 {'ids': ['a2a23561-4ae5-4d20-aa23-65dead36365f'], 'embeddings': None, 'metadatas': [{'row': 32, 'source': './data_info_table.csv'}], 'documents': ['name: fractal_dimension3\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 51 {'ids': ['0e6c29b5-3ceb-440b-8374-c529b083fe9f'], 'embeddings': None, 'metadatas': [{'row': 33, 'source': './data_info_table.csv'}], 'documents': ['name: tumor_size\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 52 {'ids': ['64f6a797-a9ad-41d5-976a-90d56f7f9908'], 'embeddings': None, 'metadatas': [{'row': 34, 'source': './data_info_table.csv'}], 'documents': ['name: lymph_node_status\nrole: Feature\ntype: Integer\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: yes'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 53 {'ids': ['e16aa0ec-def0-49f8-9d36-955073051009'], 'embeddings': None, 'metadatas': [{'row': 35, 'source': './data_info_table.csv'}], 'documents': ['name: Outcome\nrole: Target\ntype: Categorical\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 54 {'ids': ['f38a9c14-c554-4c90-a597-c965307e1d58'], 'embeddings': None, 'metadatas': [{'row': 0, 'source': './original_data.csv'}], 'documents': ['Time: Time\nradius1: radius1\ntexture1: texture1\nperimeter1: perimeter1\narea1: area1\nsmoothness1: smoothness1\ncompactness1: compactness1\nconcavity1: concavity1\nconcave_points1: concave_points1\nsymmetry1: symmetry1\nfractal_dimension1: fractal_dimension1\nradius2: radius2\ntexture2: texture2\nperimeter2: perimeter2\narea2: area2\nsmoothness2: smoothness2\ncompactness2: compactness2\nconcavity2: concavity2\nconcave_points2: concave_points2\nsymmetry2: symmetry2\nfractal_dimension2: fractal_dimension2'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 55 {'ids': ['0ac47794-4996-4560-9d5b-34b6116f2ddb'], 'embeddings': None, 'metadatas': [{'row': 0, 'source': './original_data.csv'}], 'documents': ['concave_points2: concave_points2\nsymmetry2: symmetry2\nfractal_dimension2: fractal_dimension2\nradius3: radius3\ntexture3: texture3\nperimeter3: perimeter3\narea3: area3\nsmoothness3: smoothness3\ncompactness3: compactness3\nconcavity3: concavity3\nconcave_points3: concave_points3\nsymmetry3: symmetry3\nfractal_dimension3: fractal_dimension3\ntumor_size: tumor_size\nlymph_node_status: lymph_node_status\nOutcome: Outcome'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 56 {'ids': ['a74ebbb1-e3d0-44a3-8853-42ccb902e880'], 'embeddings': None, 'metadatas': [{'row': 1, 'source': './original_data.csv'}], 'documents': ['Time: 31\nradius1: 18.02\ntexture1: 27.6\nperimeter1: 117.5\narea1: 1013.0\nsmoothness1: 0.09489\ncompactness1: 0.1036\nconcavity1: 0.1086\nconcave_points1: 0.07055\nsymmetry1: 0.1865\nfractal_dimension1: 0.06333\nradius2: 0.6249\ntexture2: 1.89\nperimeter2: 3.972\narea2: 71.55\nsmoothness2: 0.004433\ncompactness2: 0.01421\nconcavity2: 0.03233\nconcave_points2: 0.009854\nsymmetry2: 0.01694\nfractal_dimension2: 0.003495\nradius3: 21.63\ntexture3: 37.08\nperimeter3: 139.7\narea3: 1436.0\nsmoothness3: 0.1195'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
#
], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 81 {'ids': ['a4221509-cad5-4afc-a877-6c7a96a488e6'], 'embeddings': None, 'metadatas': [{'row': 13, 'source': './original_data.csv'}], 'documents': ['radius3: 16.84\ntexture3: 27.66\nperimeter3: 112.0\narea3: 876.5\nsmoothness3: 0.1131\ncompactness3: 0.1924\nconcavity3: 0.2322\nconcave_points3: 0.1119\nsymmetry3: 0.2809\nfractal_dimension3: 0.06287\ntumor_size: 1.0\nlymph_node_status: 0.0\nOutcome: N'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 82 {'ids': ['cc72559d-0048-4b6f-9962-97741090a269'], 'embeddings': None, 'metadatas': [{'row': 14, 'source': './original_data.csv'}], 'documents': ['Time: 36\nradius1: 14.54\ntexture1: 27.54\nperimeter1: 96.73\narea1: 658.8\nsmoothness1: 0.1139\ncompactness1: 0.1595\nconcavity1: 0.1639\nconcave_points1: 0.07364\nsymmetry1: 0.2303\nfractal_dimension1: 0.07077\nradius2: 0.37\ntexture2: 1.033\nperimeter2: 2.879\narea2: 32.55\nsmoothness2: 0.005607\ncompactness2: 0.0424\nconcavity2: 0.04741\nconcave_points2: 0.0109\nsymmetry2: 0.01857\nfractal_dimension2: 0.005466\nradius3: 17.46\ntexture3: 37.13\nperimeter3: 124.1\narea3: 943.2\nsmoothness3: 0.1678\ncompactness3: 0.6577'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 83 {'ids': ['cccc8e1d-3aaa-40b3-959b-dec38eaaa2f6'], 'embeddings': None, 'metadatas': [{'row': 14, 'source': './original_data.csv'}], 'documents': ['texture3: 37.13\nperimeter3: 124.1\narea3: 943.2\nsmoothness3: 0.1678\ncompactness3: 0.6577\nconcavity3: 0.7026\nconcave_points3: 0.1712\nsymmetry3: 0.4218\nfractal_dimension3: 0.1341\ntumor_size: 6.0\nlymph_node_status: 6.0\nOutcome: R'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 84 {'ids': ['f83f67dd-db93-4b6b-963e-7001ba36c6bc'], 'embeddings': None, 'metadatas': [{'row': 15, 'source': './original_data.csv'}], 'documents': ['Time: 123\nradius1: 14.68\ntexture1: 20.13\nperimeter1: 94.74\narea1: 684.5\nsmoothness1: 0.09867\ncompactness1: 0.072\nconcavity1: 0.07395\nconcave_points1: 0.05259\nsymmetry1: 0.1586\nfractal_dimension1: 0.05922\nradius2: 0.4727\ntexture2: 1.24\nperimeter2: 3.195\narea2: 45.4\nsmoothness2: 0.005718\ncompactness2: 0.01162\nconcavity2: 0.01998\nconcave_points2: 0.01109\nsymmetry2: 0.0141\nfractal_dimension2: 0.002085\nradius3: 19.07\ntexture3: 30.88\nperimeter3: 123.4\narea3: 1138.0\nsmoothness3: 0.1464'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 85 {'ids': ['870e8c9a-e583-452b-9149-2aee5bb6610d'], 'embeddings': None, 'metadatas': [{'row': 15, 'source': './original_data.csv'}], 'documents': ['radius3: 19.07\ntexture3: 30.88\nperimeter3: 123.4\narea3: 1138.0\nsmoothness3: 0.1464\ncompactness3: 0.1871\nconcavity3: 0.2914\nconcave_points3: 0.1609\nsymmetry3: 0.3029\nfractal_dimension3: 0.08216\ntumor_size: 1.1\nlymph_node_status: 0.0\nOutcome: N'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
#
nOutcome: R'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 450 {'ids': ['fd69b1b1-8319-4e75-99f6-d7be1f1d8437'], 'embeddings': None, 'metadatas': [{'row': 198, 'source': './original_data.csv'}], 'documents': ['Time: 6\nradius1: 16.7\ntexture1: 28.13\nperimeter1: 110.3\narea1: 885.4\nsmoothness1: 0.08896\ncompactness1: 0.1131\nconcavity1: 0.1012\nconcave_points1: 0.04989\nsymmetry1: 0.189\nfractal_dimension1: 0.06035\nradius2: 0.6052\ntexture2: 1.235\nperimeter2: 4.243\narea2: 63.91\nsmoothness2: 0.007767\ncompactness2: 0.02631\nconcavity2: 0.03957\nconcave_points2: 0.01411\nsymmetry2: 0.01957\nfractal_dimension2: 0.003606\nradius3: 19.74\ntexture3: 34.92\nperimeter3: 128.8\narea3: 1213.0\nsmoothness3: 0.133'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 451 {'ids': ['8b44316a-a068-4123-859e-e48a0682c198'], 'embeddings': None, 'metadatas': [{'row': 198, 'source': './original_data.csv'}], 'documents': ['radius3: 19.74\ntexture3: 34.92\nperimeter3: 128.8\narea3: 1213.0\nsmoothness3: 0.133\ncompactness3: 0.2808\nconcavity3: 0.3455\nconcave_points3: 0.1317\nsymmetry3: 0.3035\nfractal_dimension3: 0.08036\ntumor_size: 3.5\nlymph_node_status: 0.0\nOutcome: N'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 452 {'ids': ['2c60d81b-8a06-46da-80cf-d716e75e685d'], 'embeddings': None, 'metadatas': [{'source': './mldata.txt'}], 'documents': ['The project aims to develop a conversational AI system to interact with a breast cancer prognosis repository, \ngenerate explanations and predictions based on the data, and provide insights to healthcare professionals and patients. \nThe project will develop a conversational interface that allows users to interact with the LLM model and ask questions \nabout breast cancer prognosis. The interface will use natural language processing (NLP) techniques to understand'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 453 {'ids': ['c8aa0731-58e1-4ff1-844d-681cc9a435fa'], 'embeddings': None, 'metadatas': [{'source': './mldata.txt'}], 'documents': ["user input and generate responses based on the LLM model's predictions. This project will be hosted at umerai.com \nat later stages of project completion,for general use."], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 454 {'ids': ['a4d3f5bc-f087-46f6-bf4b-7209b3beb07f'], 'embeddings': None, 'metadatas': [{'source': './mldata.txt'}], 'documents': ["Machine Learning Data\nMeta Data\nuci_id: 16\nname: Breast Cancer Wisconsin (Prognostic)\nrepository_url: https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic\ndata_url: https://archive.ics.uci.edu/static/public/16/data.csv\nabstract: Prognostic Wisconsin Breast Cancer Database\narea: Health and Medicine\ntasks: ['Classification', 'Regression']\ncharacteristics: ['Multivariate']\nnum_instances: 198\nnum_features: 33\nfeature_types: ['Real']\ndemographics: []\ntarget_col: ['Outcome']"], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 455 {'ids': ['4256ea4e-2df5-4d51-9d9f-38cf49dbf95a'], 'embeddings': None, 'metadatas': [{'source': './mldata.txt'}], 'documents': ["num_features: 33\nfeature_types: ['Real']\ndemographics: []\ntarget_col: ['Outcome']\nindex_col: ['ID']\nhas_missing_values: yes\nmissing_values_symbol: NaN\nyear_of_dataset_creation: 1995\nlast_updated: Sun Jan 14 2024\ndataset_doi: 10.24432/C5GK50\ncreators: ['William Wolberg', 'W. Street', 'Olvi Mangasarian']\nintro_paper: None"], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 456 {'ids': ['e0d4901c-667a-4073-abbd-c5c0c3bf96e4'], 'embeddings': None, 'metadatas': [{'source': './mldata.txt'}], 'documents': ["additional_info: {'summary': 'Each record represents follow-up data for one breast cancer case.  These are consecutive patients seen by Dr. Wolberg since 1984, and include only those cases exhibiting invasive breast cancer and no evidence of distant metastases at the time of diagnosis. \\r\\n\\r\\nThe first 30 features are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass.  They describe characteristics of the cell nuclei present in the image. A few of the images can"], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 457 {'ids': ['53b6a5e0-24b7-4b01-be17-a5a326fc0955'], 'embeddings': None, 'metadatas': [{'source': './mldata.txt'}], 'documents': ['They describe characteristics of the cell nuclei present in the image. A few of the images can be found at http://www.cs.wisc.edu/~street/images/\\r\\n\\r\\nThe separation described above was obtained using Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree Construction Via Linear Programming." Proceedings of the 4th Midwest Artificial Intelligence and Cognitive Science Society, pp. 97-101, 1992], a classification method which uses linear programming to construct a decision tree.'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 458 {'ids': ['baad3d9b-9778-4a33-a2fd-56f8d3c83ccb'], 'embeddings': None, 'metadatas': [{'source': './mldata.txt'}], 'documents': ['97-101, 1992], a classification method which uses linear programming to construct a decision tree.  Relevant features were selected using an exhaustive search in the space of 1-4 features and 1-3 separating planes.\\r\\n\\r\\nThe actual linear program used to obtain the separating plane in the 3-dimensional space is that described in: \\r\\n[K. P. Bennett and O. L. Mangasarian: "Robust Linear Programming Discrimination of Two Linearly Inseparable Sets", Optimization Methods and Software 1, 1992,'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 459 {'ids': ['17b08476-5ab4-47b8-9ede-2161c6f742d2'], 'embeddings': None, 'metadatas': [{'source': './mldata.txt'}], 'documents': ['Discrimination of Two Linearly Inseparable Sets", Optimization Methods and Software 1, 1992, 23-34].\\r\\n\\r\\nThe Recurrence Surface Approximation (RSA) method is a linear programming model which predicts Time To Recur using both recurrent and nonrecurrent cases.  See references (i) and (ii) above for details of the RSA method. \\r\\n\\r\\nThis database is also available through the UW CS ftp server:\\r\\n\\r\\nftp ftp.cs.wisc.edu\\r\\ncd math-prog/cpo-dataset/machine-learn/WPBC/\', \'purpose\': None,'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 460 {'ids': ['38989d3f-1b9e-414e-ad7e-cd75b9303f59'], 'embeddings': None, 'metadatas': [{'source': './mldata.txt'}], 'documents': ["ftp.cs.wisc.edu\\r\\ncd math-prog/cpo-dataset/machine-learn/WPBC/', 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': '1) ID number\\n2) Outcome (R = recur, N = nonrecur)\\n3) Time (recurrence time if field 2 = R, disease-free time if \\n\\tfield 2\\t= N)\\n4-33) Ten real-valued features are computed for each cell nucleus:\\n\\n\\ta) radius (mean of distances from center to points on"], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 461 {'ids': ['d673f309-b562-40db-b84b-eea156c69be4'], 'embeddings': None, 'metadatas': [{'source': './mldata.txt'}], 'documents': ['are computed for each cell nucleus:\\n\\n\\ta) radius (mean of distances from center to points on the perimeter)\\n\\tb) texture (standard deviation of gray-scale values)\\n\\tc) perimeter\\n\\td) area\\n\\te) smoothness (local variation in radius lengths)\\n\\tf) compactness (perimeter^2 / area - 1.0)\\n\\tg) concavity (severity of concave portions of the contour)\\n\\th) concave points (number of concave portions of the contour)\\n\\ti) symmetry \\n\\tj) fractal dimension ("coastline approximation" - 1)\\n\\n34)'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 462 {'ids': ['58683232-cd44-40a7-9b22-294b92336415'], 'embeddings': None, 'metadatas': [{'source': './mldata.txt'}], 'documents': ['of the contour)\\n\\ti) symmetry \\n\\tj) fractal dimension ("coastline approximation" - 1)\\n\\n34) Tumor size - diameter of the excised tumor in centimeters\\n35) Lymph node status - number of positive axillary lymph nodes\\nobserved at time of surgery\', \'citation\': None}'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}

# %%
counter = 0
for x in range(len(uuids)):
    counter += 1
    print(counter, vector_store.get(uuids[x]))
vector_store.delete_collection()
# Out:
# 1 {'ids': ['dc42d43b-5c35-4dfe-924a-7cc0331576fd'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['UCI Machine Learning Repository\n\n\n\n\nBreast Cancer Wisconsin (Prognostic) - UCI Machine Learning Repository'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 2 {'ids': ['3bdcffa6-67a9-4887-b61d-c18daf955d46'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['Datasets Contribute Dataset Donate New Link External About Us Who We Are Citation Metadata Contact Information           Login       Breast Cancer Wisconsin (Prognostic)  Donated on 11/30/1995     Prognostic Wisconsin Breast Cancer Database  Dataset Characteristics Multivariate Subject Area Health and Medicine Associated Tasks Classification, Regression Feature Type Real # Instances 198 # Features 33   Dataset Information    Additional Information  Each record represents follow-up data'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 3 {'ids': ['86c1f4ff-76e1-4a09-a2ac-7a7c4e470079'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['Features 33   Dataset Information    Additional Information  Each record represents follow-up data for one breast cancer case.  These are consecutive patients seen by Dr. Wolberg since 1984, and include only those cases exhibiting invasive breast cancer and no evidence of distant metastases at the time of diagnosis.'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 4 {'ids': ['46477c4e-a617-4c50-95dc-b141d6cf0dd1'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['The first 30 features are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass.  They describe characteristics of the cell nuclei present in the image. A few of the images can be found at http://www.cs.wisc.edu/~street/images/'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 5 {'ids': ['e7137d8f-8562-4640-a9c5-29b2b7fb6193'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['The separation described above was obtained using Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree Construction Via Linear Programming." Proceedings of the 4th Midwest Artificial Intelligence and Cognitive Science Society, pp. 97-101, 1992], a classification method which uses linear programming to construct a decision tree.  Relevant features were selected using an exhaustive search in the space of 1-4 features and 1-3 separating planes.'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 6 {'ids': ['e0fe5791-8560-4d9c-a0b7-f239b598b44a'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['The actual linear program used to obtain the separating plane in the 3-dimensional space is that described in: \r\n[K. P. Bennett and O. L. Mangasarian: "Robust Linear Programming Discrimination of Two Linearly Inseparable Sets", Optimization Methods and Software 1, 1992, 23-34].'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 7 {'ids': ['17e3a743-b922-439f-95fa-3b64dc92449a'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['The Recurrence Surface Approximation (RSA) method is a linear programming model which predicts Time To Recur using both recurrent and nonrecurrent cases.  See references (i) and (ii) above for details of the RSA method. \r\n\r\nThis database is also available through the UW CS ftp server:\r\n\r\nftp ftp.cs.wisc.edu'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 8 {'ids': ['1fc63272-6547-4e3d-8df9-402eacb04e92'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['cd math-prog/cpo-dataset/machine-learn/WPBC/  Has Missing Values?  Yes     Variables Table      Variable NameRoleTypeDescriptionUnitsMissing Values IDIDIntegerno TimeFeatureIntegerno radius1FeatureContinuousno texture1FeatureContinuousno perimeter1FeatureContinuousno area1FeatureContinuousno smoothness1FeatureContinuousno compactness1FeatureContinuousno concavity1FeatureContinuousno concave_points1FeatureContinuousno  Rows per page 510152025 0 to 10 of 35    Additional Variable Information'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 9 {'ids': ['79e1f3e8-0876-43bb-95ec-4796b5dd5530'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['Rows per page 510152025 0 to 10 of 35    Additional Variable Information       1) ID number'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 10 {'ids': ['75b480a3-3cd2-45b1-b572-58e85d80f081'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['2) Outcome (R = recur, N = nonrecur)\n3) Time (recurrence time if field 2 = R, disease-free time if \n\tfield 2\t= N)\n4-33) Ten real-valued features are computed for each cell nucleus:'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 11 {'ids': ['f6fa04f1-6502-4cda-b196-344225937c38'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['a) radius (mean of distances from center to points on the perimeter)\n\tb) texture (standard deviation of gray-scale values)\n\tc) perimeter\n\td) area\n\te) smoothness (local variation in radius lengths)\n\tf) compactness (perimeter^2 / area - 1.0)\n\tg) concavity (severity of concave portions of the contour)\n\th) concave points (number of concave portions of the contour)\n\ti) symmetry \n\tj) fractal dimension ("coastline approximation" - 1)'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 12 {'ids': ['7a1733f4-8830-4d9a-bc4a-12581de7c733'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['34) Tumor size - diameter of the excised tumor in centimeters\n35) Lymph node status - number of positive axillary lymph nodes\nobserved at time of surgery  Class Labels  R = recur, N = nonrecur    Dataset Files     FileSize wpbc.data44KB wpbc.names5.7KB    Reviews    There are no reviews for this dataset yet. Login to Write a Review   Write a Review   0  Comments'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 13 {'ids': ['e03a2d62-8169-4e2c-9c2f-5b5fb6bfb8cf'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['Submit Cancel     Download (21KB)  Import in Python  Install the ucimlrepo package    pip install ucimlrepo Import the dataset into your code    from ucimlrepo import fetch_ucirepo \n  \n# fetch dataset \nbreast_cancer_wisconsin_prognostic = fetch_ucirepo(id=16) \n  \n# data (as pandas dataframes) \nX = breast_cancer_wisconsin_prognostic.data.features \ny = breast_cancer_wisconsin_prognostic.data.targets \n  \n# metadata \nprint(breast_cancer_wisconsin_prognostic.metadata) \n  \n# variable information'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 14 {'ids': ['c4d57ccc-1731-4103-a7bb-aebc7b02a728'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['# metadata \nprint(breast_cancer_wisconsin_prognostic.metadata) \n  \n# variable information \nprint(breast_cancer_wisconsin_prognostic.variables)'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 15 {'ids': ['7683041d-c86a-49af-a12d-31ac2df372f8'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['# variable information \nprint(breast_cancer_wisconsin_prognostic.variables) \n View the full documentation Cite   0 citations  43707 views Citation     Wolberg, W., Street, W., & Mangasarian, O. (1995). Breast Cancer Wisconsin (Prognostic) [Dataset]. UCI Machine Learning Repository. https://doi.org/10.24432/C5GK50. Style: APAMLAChicagoVancouverIEEEBibTeX    Creators    William Wolberg    W. Street    Olvi Mangasarian     DOI 10.24432/C5GK50  License This dataset is licensed under a'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 16 {'ids': ['df0d99ed-5a4f-483c-adb2-a448e3906ce6'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['Creative Commons Attribution 4.0 International\n(CC BY 4.0) license. This allows for the sharing and adaptation of the datasets for any purpose,\nprovided that the appropriate credit is given.  By using the UCI Machine Learning Repository,'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 17 {'ids': ['9738bb37-f7bf-414b-b7f2-5c2ff9858fb0'], 'embeddings': None, 'metadatas': [{'description': 'Discover datasets around the world!', 'language': 'en', 'source': 'https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic', 'title': 'UCI Machine Learning Repository'}], 'documents': ['you acknowledge and accept the cookies and privacy practices used by the UCI Machine Learning Repository. Accept Read Policy  The Project About Us CML National Science Foundation Navigation Home View Datasets Donate a Dataset Logistics Contact Privacy Notice Feature Request or Bug Report  Browse Datasets Donate a Dataset Link an external Dataset  Who We Are Citation Metadata Contact Information   Login'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 18 {'ids': ['984477cd-884d-4288-b205-b649e09c5bb8'], 'embeddings': None, 'metadatas': [{'row': 0, 'source': './data_info_table.csv'}], 'documents': ['name: name\nrole: role\ntype: type\ndemographic: demographic\ndescription: description\nunits: units\nmissing_values: missing_values'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 19 {'ids': ['b6c7360f-afcd-4cb6-aa29-5ab8f22b8536'], 'embeddings': None, 'metadatas': [{'row': 1, 'source': './data_info_table.csv'}], 'documents': ['name: ID\nrole: ID\ntype: Integer\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 20 {'ids': ['b500a7bb-bb47-4026-8586-c0e165a23603'], 'embeddings': None, 'metadatas': [{'row': 2, 'source': './data_info_table.csv'}], 'documents': ['name: Time\nrole: Feature\ntype: Integer\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 21 {'ids': ['f1d7f1e5-6475-4353-a4ad-a53c910d9a38'], 'embeddings': None, 'metadatas': [{'row': 3, 'source': './data_info_table.csv'}], 'documents': ['name: radius1\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 22 {'ids': ['1304a498-7ce5-4448-a13f-a54090e8d9f3'], 'embeddings': None, 'metadatas': [{'row': 4, 'source': './data_info_table.csv'}], 'documents': ['name: texture1\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 23 {'ids': ['c98ef236-f989-41ac-bf34-d759acc7869a'], 'embeddings': None, 'metadatas': [{'row': 5, 'source': './data_info_table.csv'}], 'documents': ['name: perimeter1\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 24 {'ids': ['246dc0e5-5958-45b4-ba1e-01ae7fb7d023'], 'embeddings': None, 'metadatas': [{'row': 6, 'source': './data_info_table.csv'}], 'documents': ['name: area1\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 25 {'ids': ['5f59db5b-ee11-44f6-938b-08e93d815a71'], 'embeddings': None, 'metadatas': [{'row': 7, 'source': './data_info_table.csv'}], 'documents': ['name: smoothness1\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 26 {'ids': ['02d67373-e7ce-4445-8af1-562811350d71'], 'embeddings': None, 'metadatas': [{'row': 8, 'source': './data_info_table.csv'}], 'documents': ['name: compactness1\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 27 {'ids': ['692561b8-4c1d-4f6c-aaf9-52ff99e23431'], 'embeddings': None, 'metadatas': [{'row': 9, 'source': './data_info_table.csv'}], 'documents': ['name: concavity1\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 28 {'ids': ['04454e63-90f5-4ab9-86eb-92bbf5e1f3cb'], 'embeddings': None, 'metadatas': [{'row': 10, 'source': './data_info_table.csv'}], 'documents': ['name: concave_points1\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 29 {'ids': ['c846c62f-32f6-4738-9cbb-b4dd6d79e3b4'], 'embeddings': None, 'metadatas': [{'row': 11, 'source': './data_info_table.csv'}], 'documents': ['name: symmetry1\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 30 {'ids': ['25284970-f0ab-4746-98ea-b8539062afee'], 'embeddings': None, 'metadatas': [{'row': 12, 'source': './data_info_table.csv'}], 'documents': ['name: fractal_dimension1\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 31 {'ids': ['1def1e4d-108e-4a22-b8fa-257b6ad2c432'], 'embeddings': None, 'metadatas': [{'row': 13, 'source': './data_info_table.csv'}], 'documents': ['name: radius2\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 32 {'ids': ['5a60f050-0bb8-428c-b7ac-fa272531ebf6'], 'embeddings': None, 'metadatas': [{'row': 14, 'source': './data_info_table.csv'}], 'documents': ['name: texture2\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 33 {'ids': ['86b20664-fd7f-4822-909f-85d6a6966328'], 'embeddings': None, 'metadatas': [{'row': 15, 'source': './data_info_table.csv'}], 'documents': ['name: perimeter2\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 34 {'ids': ['62e85763-dba7-4d73-82af-65a81407b400'], 'embeddings': None, 'metadatas': [{'row': 16, 'source': './data_info_table.csv'}], 'documents': ['name: area2\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 35 {'ids': ['ef6eba92-28a9-42cc-9bf7-17f4c69e15e3'], 'embeddings': None, 'metadatas': [{'row': 17, 'source': './data_info_table.csv'}], 'documents': ['name: smoothness2\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 36 {'ids': ['429c3488-7ee2-4689-94a2-6af39028debc'], 'embeddings': None, 'metadatas': [{'row': 18, 'source': './data_info_table.csv'}], 'documents': ['name: compactness2\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 37 {'ids': ['7f0a4061-9f11-4b23-b12d-e68d16f06265'], 'embeddings': None, 'metadatas': [{'row': 19, 'source': './data_info_table.csv'}], 'documents': ['name: concavity2\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 38 {'ids': ['d02d7559-d1ef-4dce-8ece-3146a0eb0ccd'], 'embeddings': None, 'metadatas': [{'row': 20, 'source': './data_info_table.csv'}], 'documents': ['name: concave_points2\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 39 {'ids': ['c1bfd58d-8cb7-4abb-90a0-e27f3a05f9ab'], 'embeddings': None, 'metadatas': [{'row': 21, 'source': './data_info_table.csv'}], 'documents': ['name: symmetry2\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 40 {'ids': ['fd7f011c-7419-4c2a-81c5-b83a7ee55592'], 'embeddings': None, 'metadatas': [{'row': 22, 'source': './data_info_table.csv'}], 'documents': ['name: fractal_dimension2\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 41 {'ids': ['ac58e8b0-e1f1-4c57-a0d7-7cbb15e22c31'], 'embeddings': None, 'metadatas': [{'row': 23, 'source': './data_info_table.csv'}], 'documents': ['name: radius3\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 42 {'ids': ['ecd1e3b4-a203-4ebf-852c-86af6b52227b'], 'embeddings': None, 'metadatas': [{'row': 24, 'source': './data_info_table.csv'}], 'documents': ['name: texture3\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 43 {'ids': ['aff0cd86-fe17-44af-b9c1-a1a59d059347'], 'embeddings': None, 'metadatas': [{'row': 25, 'source': './data_info_table.csv'}], 'documents': ['name: perimeter3\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 44 {'ids': ['099c5ec5-50e9-4410-b7c7-12c3f4046fd1'], 'embeddings': None, 'metadatas': [{'row': 26, 'source': './data_info_table.csv'}], 'documents': ['name: area3\nrole: Feature\ntype: Integer\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 45 {'ids': ['40c29b69-d44d-4ab0-bf17-7473abf882c8'], 'embeddings': None, 'metadatas': [{'row': 27, 'source': './data_info_table.csv'}], 'documents': ['name: smoothness3\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 46 {'ids': ['19cb1291-fac5-4d77-bea2-0cbf39121129'], 'embeddings': None, 'metadatas': [{'row': 28, 'source': './data_info_table.csv'}], 'documents': ['name: compactness3\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 47 {'ids': ['06a4f6fd-b746-45fc-a92f-1fc6a794575d'], 'embeddings': None, 'metadatas': [{'row': 29, 'source': './data_info_table.csv'}], 'documents': ['name: concavity3\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 48 {'ids': ['a1defe5b-ab72-4445-bc89-edfdfeb9373f'], 'embeddings': None, 'metadatas': [{'row': 30, 'source': './data_info_table.csv'}], 'documents': ['name: concave_points3\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 49 {'ids': ['38f19b54-edc8-47bf-8f2c-21ed8d08dba4'], 'embeddings': None, 'metadatas': [{'row': 31, 'source': './data_info_table.csv'}], 'documents': ['name: symmetry3\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 50 {'ids': ['a2a23561-4ae5-4d20-aa23-65dead36365f'], 'embeddings': None, 'metadatas': [{'row': 32, 'source': './data_info_table.csv'}], 'documents': ['name: fractal_dimension3\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 51 {'ids': ['0e6c29b5-3ceb-440b-8374-c529b083fe9f'], 'embeddings': None, 'metadatas': [{'row': 33, 'source': './data_info_table.csv'}], 'documents': ['name: tumor_size\nrole: Feature\ntype: Continuous\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 52 {'ids': ['64f6a797-a9ad-41d5-976a-90d56f7f9908'], 'embeddings': None, 'metadatas': [{'row': 34, 'source': './data_info_table.csv'}], 'documents': ['name: lymph_node_status\nrole: Feature\ntype: Integer\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: yes'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 53 {'ids': ['e16aa0ec-def0-49f8-9d36-955073051009'], 'embeddings': None, 'metadatas': [{'row': 35, 'source': './data_info_table.csv'}], 'documents': ['name: Outcome\nrole: Target\ntype: Categorical\ndemographic: NA\ndescription: NA\nunits: NA\nmissing_values: no'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 54 {'ids': ['f38a9c14-c554-4c90-a597-c965307e1d58'], 'embeddings': None, 'metadatas': [{'row': 0, 'source': './original_data.csv'}], 'documents': ['Time: Time\nradius1: radius1\ntexture1: texture1\nperimeter1: perimeter1\narea1: area1\nsmoothness1: smoothness1\ncompactness1: compactness1\nconcavity1: concavity1\nconcave_points1: concave_points1\nsymmetry1: symmetry1\nfractal_dimension1: fractal_dimension1\nradius2: radius2\ntexture2: texture2\nperimeter2: perimeter2\narea2: area2\nsmoothness2: smoothness2\ncompactness2: compactness2\nconcavity2: concavity2\nconcave_points2: concave_points2\nsymmetry2: symmetry2\nfractal_dimension2: fractal_dimension2'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 55 {'ids': ['0ac47794-4996-4560-9d5b-34b6116f2ddb'], 'embeddings': None, 'metadatas': [{'row': 0, 'source': './original_data.csv'}], 'documents': ['concave_points2: concave_points2\nsymmetry2: symmetry2\nfractal_dimension2: fractal_dimension2\nradius3: radius3\ntexture3: texture3\nperimeter3: perimeter3\narea3: area3\nsmoothness3: smoothness3\ncompactness3: compactness3\nconcavity3: concavity3\nconcave_points3: concave_points3\nsymmetry3: symmetry3\nfractal_dimension3: fractal_dimension3\ntumor_size: tumor_size\nlymph_node_status: lymph_node_status\nOutcome: Outcome'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
#
], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 61 {'ids': ['4ac1dfe1-f656-4ac2-9b90-a11316369875'], 'embeddings': None, 'metadatas': [{'row': 3, 'source': './original_data.csv'}], 'documents': ['radius3: 24.9\ntexture3: 20.98\nperimeter3: 159.1\narea3: 1949.0\nsmoothness3: 0.1188\ncompactness3: 0.3449\nconcavity3: 0.3414\nconcave_points3: 0.2032\nsymmetry3: 0.4334\nfractal_dimension3: 0.09067\ntumor_size: 2.5\nlymph_node_status: 0.0\nOutcome: N'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 62 {'ids': ['ebd84d61-5705-4146-b397-ab3b3c09d255'], 'embeddings': None, 'metadatas': [{'row': 4, 'source': './original_data.csv'}], 'documents': ['Time: 123\nradius1: 11.42\ntexture1: 20.38\nperimeter1: 77.58\narea1: 386.1\nsmoothness1: 0.1425\ncompactness1: 0.2839\nconcavity1: 0.2414\nconcave_points1: 0.1052\nsymmetry1: 0.2597\nfractal_dimension1: 0.09744\nradius2: 0.4956\ntexture2: 1.156\nperimeter2: 3.445\narea2: 27.23\nsmoothness2: 0.00911\ncompactness2: 0.07458\nconcavity2: 0.05661\nconcave_points2: 0.01867\nsymmetry2: 0.05963\nfractal_dimension2: 0.009208\nradius3: 14.91\ntexture3: 26.5\nperimeter3: 98.87\narea3: 567.7\nsmoothness3: 0.2098'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 63 {'ids': ['6b8eaf51-2885-4e1e-ba18-29432d093873'], 'embeddings': None, 'metadatas': [{'row': 4, 'source': './original_data.csv'}], 'documents': ['radius3: 14.91\ntexture3: 26.5\nperimeter3: 98.87\narea3: 567.7\nsmoothness3: 0.2098\ncompactness3: 0.8663\nconcavity3: 0.6869\nconcave_points3: 0.2575\nsymmetry3: 0.6638\nfractal_dimension3: 0.173\ntumor_size: 2.0\nlymph_node_status: 0.0\nOutcome: N'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 64 {'ids': ['144afdff-fd30-4c7b-847d-3723f16cb4cb'], 'embeddings': None, 'metadatas': [{'row': 5, 'source': './original_data.csv'}], 'documents': ['Time: 27\nradius1: 20.29\ntexture1: 14.34\nperimeter1: 135.1\narea1: 1297.0\nsmoothness1: 0.1003\ncompactness1: 0.1328\nconcavity1: 0.198\nconcave_points1: 0.1043\nsymmetry1: 0.1809\nfractal_dimension1: 0.05883\nradius2: 0.7572\ntexture2: 0.7813\nperimeter2: 5.438\narea2: 94.44\nsmoothness2: 0.01149\ncompactness2: 0.02461\nconcavity2: 0.05688\nconcave_points2: 0.01885\nsymmetry2: 0.01756\nfractal_dimension2: 0.005115\nradius3: 22.54\ntexture3: 16.67\nperimeter3: 152.2\narea3: 1575.0\nsmoothness3: 0.1374'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 65 {'ids': ['48865318-5fbc-4e76-9682-f2d955419d2a'], 'embeddings': None, 'metadatas': [{'row': 5, 'source': './original_data.csv'}], 'documents': ['radius3: 22.54\ntexture3: 16.67\nperimeter3: 152.2\narea3: 1575.0\nsmoothness3: 0.1374\ncompactness3: 0.205\nconcavity3: 0.4\nconcave_points3: 0.1625\nsymmetry3: 0.2364\nfractal_dimension3: 0.07678\ntumor_size: 3.5\nlymph_node_status: 0.0\nOutcome: R'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
#
], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 81 {'ids': ['a4221509-cad5-4afc-a877-6c7a96a488e6'], 'embeddings': None, 'metadatas': [{'row': 13, 'source': './original_data.csv'}], 'documents': ['radius3: 16.84\ntexture3: 27.66\nperimeter3: 112.0\narea3: 876.5\nsmoothness3: 0.1131\ncompactness3: 0.1924\nconcavity3: 0.2322\nconcave_points3: 0.1119\nsymmetry3: 0.2809\nfractal_dimension3: 0.06287\ntumor_size: 1.0\nlymph_node_status: 0.0\nOutcome: N'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 82 {'ids': ['cc72559d-0048-4b6f-9962-97741090a269'], 'embeddings': None, 'metadatas': [{'row': 14, 'source': './original_data.csv'}], 'documents': ['Time: 36\nradius1: 14.54\ntexture1: 27.54\nperimeter1: 96.73\narea1: 658.8\nsmoothness1: 0.1139\ncompactness1: 0.1595\nconcavity1: 0.1639\nconcave_points1: 0.07364\nsymmetry1: 0.2303\nfractal_dimension1: 0.07077\nradius2: 0.37\ntexture2: 1.033\nperimeter2: 2.879\narea2: 32.55\nsmoothness2: 0.005607\ncompactness2: 0.0424\nconcavity2: 0.04741\nconcave_points2: 0.0109\nsymmetry2: 0.01857\nfractal_dimension2: 0.005466\nradius3: 17.46\ntexture3: 37.13\nperimeter3: 124.1\narea3: 943.2\nsmoothness3: 0.1678\ncompactness3: 0.6577'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 83 {'ids': ['cccc8e1d-3aaa-40b3-959b-dec38eaaa2f6'], 'embeddings': None, 'metadatas': [{'row': 14, 'source': './original_data.csv'}], 'documents': ['texture3: 37.13\nperimeter3: 124.1\narea3: 943.2\nsmoothness3: 0.1678\ncompactness3: 0.6577\nconcavity3: 0.7026\nconcave_points3: 0.1712\nsymmetry3: 0.4218\nfractal_dimension3: 0.1341\ntumor_size: 6.0\nlymph_node_status: 6.0\nOutcome: R'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 84 {'ids': ['f83f67dd-db93-4b6b-963e-7001ba36c6bc'], 'embeddings': None, 'metadatas': [{'row': 15, 'source': './original_data.csv'}], 'documents': ['Time: 123\nradius1: 14.68\ntexture1: 20.13\nperimeter1: 94.74\narea1: 684.5\nsmoothness1: 0.09867\ncompactness1: 0.072\nconcavity1: 0.07395\nconcave_points1: 0.05259\nsymmetry1: 0.1586\nfractal_dimension1: 0.05922\nradius2: 0.4727\ntexture2: 1.24\nperimeter2: 3.195\narea2: 45.4\nsmoothness2: 0.005718\ncompactness2: 0.01162\nconcavity2: 0.01998\nconcave_points2: 0.01109\nsymmetry2: 0.0141\nfractal_dimension2: 0.002085\nradius3: 19.07\ntexture3: 30.88\nperimeter3: 123.4\narea3: 1138.0\nsmoothness3: 0.1464'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 85 {'ids': ['870e8c9a-e583-452b-9149-2aee5bb6610d'], 'embeddings': None, 'metadatas': [{'row': 15, 'source': './original_data.csv'}], 'documents': ['radius3: 19.07\ntexture3: 30.88\nperimeter3: 123.4\narea3: 1138.0\nsmoothness3: 0.1464\ncompactness3: 0.1871\nconcavity3: 0.2914\nconcave_points3: 0.1609\nsymmetry3: 0.3029\nfractal_dimension3: 0.08216\ntumor_size: 1.1\nlymph_node_status: 0.0\nOutcome: N'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
#
], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 91 {'ids': ['66ecd00d-d998-469d-ae3e-57a6308460eb'], 'embeddings': None, 'metadatas': [{'row': 18, 'source': './original_data.csv'}], 'documents': ['radius3: 29.17\ntexture3: 35.59\nperimeter3: 188.0\narea3: 2615.0\nsmoothness3: 0.1401\ncompactness3: 0.26\nconcavity3: 0.3155\nconcave_points3: 0.2009\nsymmetry3: 0.2822\nfractal_dimension3: 0.07526\ntumor_size: 4.0\nlymph_node_status: 1.0\nOutcome: R'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 92 {'ids': ['e425b19b-e8f2-4a0f-970b-6e4664627cda'], 'embeddings': None, 'metadatas': [{'row': 19, 'source': './original_data.csv'}], 'documents': ['Time: 96\nradius1: 16.65\ntexture1: 21.38\nperimeter1: 110.0\narea1: 904.6\nsmoothness1: 0.1121\ncompactness1: 0.1457\nconcavity1: 0.1525\nconcave_points1: 0.0917\nsymmetry1: 0.1995\nfractal_dimension1: 0.0633\nradius2: 0.8068\ntexture2: 0.9017\nperimeter2: 5.455\narea2: 102.6\nsmoothness2: 0.006048\ncompactness2: 0.01882\nconcavity2: 0.02741\nconcave_points2: 0.0113\nsymmetry2: 0.01468\nfractal_dimension2: 0.002801\nradius3: 26.46\ntexture3: 31.56\nperimeter3: 177.0\narea3: 2215.0\nsmoothness3: 0.1805'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# ...
# 437 {'ids': ['1f3f9ec1-43d4-4345-9e7d-915df017d8e9'], 'embeddings': None, 'metadatas': [{'row': 191, 'source': './original_data.csv'}], 'documents': ['radius3: 22.75\ntexture3: 36.88\nperimeter3: 150.3\narea3: 1603.0\nsmoothness3: 0.1293\ncompactness3: 0.2513\nconcavity3: 0.4106\nconcave_points3: 0.1638\nsymmetry3: 0.2245\nfractal_dimension3: 0.07842\ntumor_size: 4.0\nlymph_node_status: 0.0\nOutcome: N'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 438 {'ids': ['f3970b47-a03d-49ed-9a31-5a5d2d17dc1d'], 'embeddings': None, 'metadatas': [{'row': 192, 'source': './original_data.csv'}], 'documents': ['Time: 3\nradius1: 19.22\ntexture1: 27.18\nperimeter1: 128.8\narea1: 1134.0\nsmoothness1: 0.109\ncompactness1: 0.1777\nconcavity1: 0.2138\nconcave_points1: 0.1116\nsymmetry1: 0.1924\nfractal_dimension1: 0.06389\nradius2: 0.497\ntexture2: 2.403\nperimeter2: 4.493\narea2: 61.18\nsmoothness2: 0.006133\ncompactness2: 0.04109\nconcavity2: 0.05917\nconcave_points2: 0.01756\nsymmetry2: 0.0218\nfractal_dimension2: 0.004305\nradius3: 22.57\ntexture3: 44.6\nperimeter3: 161.0\narea3: 1565.0\nsmoothness3: 0.1501\ncompactness3: 0.513'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 439 {'ids': ['93d94022-17db-43ed-af6c-8d4e729c5ab9'], 'embeddings': None, 'metadatas': [{'row': 192, 'source': './original_data.csv'}], 'documents': ['texture3: 44.6\nperimeter3: 161.0\narea3: 1565.0\nsmoothness3: 0.1501\ncompactness3: 0.513\nconcavity3: 0.6841\nconcave_points3: 0.2099\nsymmetry3: 0.3484\nfractal_dimension3: 0.09774\ntumor_size: 0.8\nlymph_node_status: 1.0\nOutcome: N'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 440 {'ids': ['2df1d145-264f-4b9d-8a13-ce664bb1720d'], 'embeddings': None, 'metadatas': [{'row': 193, 'source': './original_data.csv'}], 'documents': ['Time: 3\nradius1: 14.72\ntexture1: 25.26\nperimeter1: 99.28\narea1: 657.5\nsmoothness1: 0.1174\ncompactness1: 0.2112\nconcavity1: 0.1729\nconcave_points1: 0.09465\nsymmetry1: 0.2079\nfractal_dimension1: 0.07496\nradius2: 0.3405\ntexture2: 1.158\nperimeter2: 2.188\narea2: 26.12\nsmoothness2: 0.004957\ncompactness2: 0.04553\nconcavity2: 0.05166\nconcave_points2: 0.01597\nsymmetry2: 0.02539\nfractal_dimension2: 0.005548\nradius3: 16.67\ntexture3: 31.97\nperimeter3: 111.6\narea3: 814.8\nsmoothness3: 0.1464'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 441 {'ids': ['ef42401e-1ada-470d-a7be-0f74881412ed'], 'embeddings': None, 'metadatas': [{'row': 193, 'source': './original_data.csv'}], 'documents': ['radius3: 16.67\ntexture3: 31.97\nperimeter3: 111.6\narea3: 814.8\nsmoothness3: 0.1464\ncompactness3: 0.5352\nconcavity3: 0.5655\nconcave_points3: 0.1974\nsymmetry3: 0.3778\nfractal_dimension3: 0.1132\ntumor_size: 1.7\nlymph_node_status: 21.0\nOutcome: N'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 442 {'ids': ['320f13b2-5be4-40ab-875b-755552c4d69b'], 'embeddings': None, 'metadatas': [{'row': 194, 'source': './original_data.csv'}], 'documents': ['Time: 10\nradius1: 22.52\ntexture1: 21.92\nperimeter1: 146.9\narea1: 1597.0\nsmoothness1: 0.07592\ncompactness1: 0.09162\nconcavity1: 0.06862\nconcave_points1: 0.06367\nsymmetry1: 0.1728\nfractal_dimension1: 0.05262\nradius2: 1.374\ntexture2: 2.312\nperimeter2: 9.938\narea2: 192.4\nsmoothness2: 0.004422\ncompactness2: 0.02679\nconcavity2: 0.02433\nconcave_points2: 0.02036\nsymmetry2: 0.02486\nfractal_dimension2: 0.003922\nradius3: 24.67\ntexture3: 24.81\nperimeter3: 162.1\narea3: 1902.0\nsmoothness3: 0.08191'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 443 {'ids': ['5f0b5427-b161-455f-982b-0aedc279f232'], 'embeddings': None, 'metadatas': [{'row': 194, 'source': './original_data.csv'}], 'documents': ['radius3: 24.67\ntexture3: 24.81\nperimeter3: 162.1\narea3: 1902.0\nsmoothness3: 0.08191\ncompactness3: 0.1319\nconcavity3: 0.1056\nconcave_points3: 0.09378\nsymmetry3: 0.2061\nfractal_dimension3: 0.05788\ntumor_size: 6.0\nlymph_node_status: 2.0\nOutcome: N'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
#
], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 449 {'ids': ['b8040a39-2a90-4895-91f2-7e7a4fb7fa99'], 'embeddings': None, 'metadatas': [{'row': 197, 'source': './original_data.csv'}], 'documents': ['radius3: 28.34\ntexture3: 27.98\nperimeter3: 198.3\narea3: 2375.0\nsmoothness3: 0.1498\ncompactness3: 0.4379\nconcavity3: 0.5411\nconcave_points3: 0.2215\nsymmetry3: 0.2832\nfractal_dimension3: 0.08981\ntumor_size: 3.0\nlymph_node_status: NA\nOutcome: R'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 450 {'ids': ['fd69b1b1-8319-4e75-99f6-d7be1f1d8437'], 'embeddings': None, 'metadatas': [{'row': 198, 'source': './original_data.csv'}], 'documents': ['Time: 6\nradius1: 16.7\ntexture1: 28.13\nperimeter1: 110.3\narea1: 885.4\nsmoothness1: 0.08896\ncompactness1: 0.1131\nconcavity1: 0.1012\nconcave_points1: 0.04989\nsymmetry1: 0.189\nfractal_dimension1: 0.06035\nradius2: 0.6052\ntexture2: 1.235\nperimeter2: 4.243\narea2: 63.91\nsmoothness2: 0.007767\ncompactness2: 0.02631\nconcavity2: 0.03957\nconcave_points2: 0.01411\nsymmetry2: 0.01957\nfractal_dimension2: 0.003606\nradius3: 19.74\ntexture3: 34.92\nperimeter3: 128.8\narea3: 1213.0\nsmoothness3: 0.133'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 451 {'ids': ['8b44316a-a068-4123-859e-e48a0682c198'], 'embeddings': None, 'metadatas': [{'row': 198, 'source': './original_data.csv'}], 'documents': ['radius3: 19.74\ntexture3: 34.92\nperimeter3: 128.8\narea3: 1213.0\nsmoothness3: 0.133\ncompactness3: 0.2808\nconcavity3: 0.3455\nconcave_points3: 0.1317\nsymmetry3: 0.3035\nfractal_dimension3: 0.08036\ntumor_size: 3.5\nlymph_node_status: 0.0\nOutcome: N'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 452 {'ids': ['2c60d81b-8a06-46da-80cf-d716e75e685d'], 'embeddings': None, 'metadatas': [{'source': './mldata.txt'}], 'documents': ['The project aims to develop a conversational AI system to interact with a breast cancer prognosis repository, \ngenerate explanations and predictions based on the data, and provide insights to healthcare professionals and patients. \nThe project will develop a conversational interface that allows users to interact with the LLM model and ask questions \nabout breast cancer prognosis. The interface will use natural language processing (NLP) techniques to understand'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 453 {'ids': ['c8aa0731-58e1-4ff1-844d-681cc9a435fa'], 'embeddings': None, 'metadatas': [{'source': './mldata.txt'}], 'documents': ["user input and generate responses based on the LLM model's predictions. This project will be hosted at umerai.com \nat later stages of project completion,for general use."], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 454 {'ids': ['a4d3f5bc-f087-46f6-bf4b-7209b3beb07f'], 'embeddings': None, 'metadatas': [{'source': './mldata.txt'}], 'documents': ["Machine Learning Data\nMeta Data\nuci_id: 16\nname: Breast Cancer Wisconsin (Prognostic)\nrepository_url: https://archive.ics.uci.edu/dataset/16/breast+cancer+wisconsin+prognostic\ndata_url: https://archive.ics.uci.edu/static/public/16/data.csv\nabstract: Prognostic Wisconsin Breast Cancer Database\narea: Health and Medicine\ntasks: ['Classification', 'Regression']\ncharacteristics: ['Multivariate']\nnum_instances: 198\nnum_features: 33\nfeature_types: ['Real']\ndemographics: []\ntarget_col: ['Outcome']"], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 455 {'ids': ['4256ea4e-2df5-4d51-9d9f-38cf49dbf95a'], 'embeddings': None, 'metadatas': [{'source': './mldata.txt'}], 'documents': ["num_features: 33\nfeature_types: ['Real']\ndemographics: []\ntarget_col: ['Outcome']\nindex_col: ['ID']\nhas_missing_values: yes\nmissing_values_symbol: NaN\nyear_of_dataset_creation: 1995\nlast_updated: Sun Jan 14 2024\ndataset_doi: 10.24432/C5GK50\ncreators: ['William Wolberg', 'W. Street', 'Olvi Mangasarian']\nintro_paper: None"], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 456 {'ids': ['e0d4901c-667a-4073-abbd-c5c0c3bf96e4'], 'embeddings': None, 'metadatas': [{'source': './mldata.txt'}], 'documents': ["additional_info: {'summary': 'Each record represents follow-up data for one breast cancer case.  These are consecutive patients seen by Dr. Wolberg since 1984, and include only those cases exhibiting invasive breast cancer and no evidence of distant metastases at the time of diagnosis. \\r\\n\\r\\nThe first 30 features are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass.  They describe characteristics of the cell nuclei present in the image. A few of the images can"], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 457 {'ids': ['53b6a5e0-24b7-4b01-be17-a5a326fc0955'], 'embeddings': None, 'metadatas': [{'source': './mldata.txt'}], 'documents': ['They describe characteristics of the cell nuclei present in the image. A few of the images can be found at http://www.cs.wisc.edu/~street/images/\\r\\n\\r\\nThe separation described above was obtained using Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree Construction Via Linear Programming." Proceedings of the 4th Midwest Artificial Intelligence and Cognitive Science Society, pp. 97-101, 1992], a classification method which uses linear programming to construct a decision tree.'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 458 {'ids': ['baad3d9b-9778-4a33-a2fd-56f8d3c83ccb'], 'embeddings': None, 'metadatas': [{'source': './mldata.txt'}], 'documents': ['97-101, 1992], a classification method which uses linear programming to construct a decision tree.  Relevant features were selected using an exhaustive search in the space of 1-4 features and 1-3 separating planes.\\r\\n\\r\\nThe actual linear program used to obtain the separating plane in the 3-dimensional space is that described in: \\r\\n[K. P. Bennett and O. L. Mangasarian: "Robust Linear Programming Discrimination of Two Linearly Inseparable Sets", Optimization Methods and Software 1, 1992,'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 459 {'ids': ['17b08476-5ab4-47b8-9ede-2161c6f742d2'], 'embeddings': None, 'metadatas': [{'source': './mldata.txt'}], 'documents': ['Discrimination of Two Linearly Inseparable Sets", Optimization Methods and Software 1, 1992, 23-34].\\r\\n\\r\\nThe Recurrence Surface Approximation (RSA) method is a linear programming model which predicts Time To Recur using both recurrent and nonrecurrent cases.  See references (i) and (ii) above for details of the RSA method. \\r\\n\\r\\nThis database is also available through the UW CS ftp server:\\r\\n\\r\\nftp ftp.cs.wisc.edu\\r\\ncd math-prog/cpo-dataset/machine-learn/WPBC/\', \'purpose\': None,'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 460 {'ids': ['38989d3f-1b9e-414e-ad7e-cd75b9303f59'], 'embeddings': None, 'metadatas': [{'source': './mldata.txt'}], 'documents': ["ftp.cs.wisc.edu\\r\\ncd math-prog/cpo-dataset/machine-learn/WPBC/', 'purpose': None, 'funded_by': None, 'instances_represent': None, 'recommended_data_splits': None, 'sensitive_data': None, 'preprocessing_description': None, 'variable_info': '1) ID number\\n2) Outcome (R = recur, N = nonrecur)\\n3) Time (recurrence time if field 2 = R, disease-free time if \\n\\tfield 2\\t= N)\\n4-33) Ten real-valued features are computed for each cell nucleus:\\n\\n\\ta) radius (mean of distances from center to points on"], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 461 {'ids': ['d673f309-b562-40db-b84b-eea156c69be4'], 'embeddings': None, 'metadatas': [{'source': './mldata.txt'}], 'documents': ['are computed for each cell nucleus:\\n\\n\\ta) radius (mean of distances from center to points on the perimeter)\\n\\tb) texture (standard deviation of gray-scale values)\\n\\tc) perimeter\\n\\td) area\\n\\te) smoothness (local variation in radius lengths)\\n\\tf) compactness (perimeter^2 / area - 1.0)\\n\\tg) concavity (severity of concave portions of the contour)\\n\\th) concave points (number of concave portions of the contour)\\n\\ti) symmetry \\n\\tj) fractal dimension ("coastline approximation" - 1)\\n\\n34)'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}
# 462 {'ids': ['58683232-cd44-40a7-9b22-294b92336415'], 'embeddings': None, 'metadatas': [{'source': './mldata.txt'}], 'documents': ['of the contour)\\n\\ti) symmetry \\n\\tj) fractal dimension ("coastline approximation" - 1)\\n\\n34) Tumor size - diameter of the excised tumor in centimeters\\n35) Lymph node status - number of positive axillary lymph nodes\\nobserved at time of surgery\', \'citation\': None}'], 'uris': None, 'data': None, 'included': ['metadatas', 'documents']}

# %%
from uuid import uuid4

from langchain_core.documents import Document

document_1 = Document(
    page_content="I had chocalate chip pancakes and scrambled eggs for breakfast this morning.",
    metadata={"source": "tweet"},
    id=1,
)

document_2 = Document(
    page_content="The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees.",
    metadata={"source": "news"},
    id=2,
)

document_3 = Document(
    page_content="Building an exciting new project with LangChain - come check it out!",
    metadata={"source": "tweet"},
    id=3,
)

document_4 = Document(
    page_content="Robbers broke into the city bank and stole $1 million in cash.",
    metadata={"source": "news"},
    id=4,
)

document_5 = Document(
    page_content="Wow! That was an amazing movie. I can't wait to see it again.",
    metadata={"source": "tweet"},
    id=5,
)

document_6 = Document(
    page_content="Is the new iPhone worth the price? Read this review to find out.",
    metadata={"source": "website"},
    id=6,
)

document_7 = Document(
    page_content="The top 10 soccer players in the world right now.",
    metadata={"source": "website"},
    id=7,
)

document_8 = Document(
    page_content="LangGraph is the best framework for building stateful, agentic applications!",
    metadata={"source": "tweet"},
    id=8,
)

document_9 = Document(
    page_content="The stock market is down 500 points today due to fears of a recession.",
    metadata={"source": "news"},
    id=9,
)

document_10 = Document(
    page_content="I have a bad feeling I am going to get deleted :(",
    metadata={"source": "tweet"},
    id=10,
)

documents = [
    document_1,
    document_2,
    document_3,
    document_4,
    document_5,
    document_6,
    document_7,
    document_8,
    document_9,
    document_10,
]
uuids = [str(uuid4()) for _ in range(len(documents))]

vector_store.add_documents(documents=documents, ids=uuids)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 79
#      65 documents = [
#      66     document_1,
#      67     document_2,
#    (...)
#      75     document_10,
#      76 ]
#      77 uuids = [str(uuid4()) for _ in range(len(documents))]
# ---> 79 vector_store.add_documents(documents=documents, ids=uuids)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_core\vectorstores\base.py:282, in VectorStore.add_documents(self, documents, **kwargs)
#     280     texts = [doc.page_content for doc in documents]
#     281     metadatas = [doc.metadata for doc in documents]
# --> 282     return self.add_texts(texts, metadatas, **kwargs)
#     283 raise NotImplementedError(
#     284     f"`add_documents` and `add_texts` has not been implemented "
#     285     f"for {self.__class__.__name__} "
#     286 )
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_chroma\vectorstores.py:425, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#     423             raise ValueError(e.args[0] + "\n\n" + msg)
#     424         else:
# --> 425             raise e
#     426 if empty_ids:
#     427     texts_without_metadatas = [texts[j] for j in empty_ids]
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_chroma\vectorstores.py:411, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#     409 ids_with_metadata = [ids[idx] for idx in non_empty_ids]
#     410 try:
# --> 411     self._collection.upsert(
#     412         metadatas=metadatas,  # type: ignore
#     413         embeddings=embeddings_with_metadatas,  # type: ignore
#     414         documents=texts_with_metadatas,
#     415         ids=ids_with_metadata,
#     416     )
#     417 except ValueError as e:
#     418     if "Expected metadata value to be" in str(e):
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_chroma\vectorstores.py:221, in Chroma._collection(self)
#     219 """Returns the underlying Chroma collection or throws an exception."""
#     220 if self._chroma_collection is None:
# --> 221     raise ValueError(
#     222         "Chroma collection not initialized. "
#     223         "Use `reset_collection` to re-create and initialize the collection. "
#     224     )
#     225 return self._chroma_collection
#
# ValueError: Chroma collection not initialized. Use `reset_collection` to re-create and initialize the collection.

# %%
updated_document_1 = Document(
    page_content="I had chocalate chip pancakes and fried eggs for breakfast this morning.",
    metadata={"source": "tweet"},
    id=1,
)

updated_document_2 = Document(
    page_content="The weather forecast for tomorrow is sunny and warm, with a high of 82 degrees.",
    metadata={"source": "news"},
    id=2,
)

vector_store.update_document(document_id=uuids[0], document=updated_document_1)
# You can also update multiple documents at once
vector_store.update_documents(
    ids=uuids[:2], documents=[updated_document_1, updated_document_1]
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 13
#       1 updated_document_1 = Document(
#       2     page_content="I had chocalate chip pancakes and fried eggs for breakfast this morning.",
#       3     metadata={"source": "tweet"},
#       4     id=1,
#       5 )
#       7 updated_document_2 = Document(
#       8     page_content="The weather forecast for tomorrow is sunny and warm, with a high of 82 degrees.",
#       9     metadata={"source": "news"},
#      10     id=2,
#      11 )
# ---> 13 vector_store.update_document(document_id=uuids[0], document=updated_document_1)
#      14 # You can also update multiple documents at once
#      15 vector_store.update_documents(
#      16     ids=uuids[:2], documents=[updated_document_1, updated_document_1]
#      17 )
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_chroma\vectorstores.py:771, in Chroma.update_document(self, document_id, document)
#     764 def update_document(self, document_id: str, document: Document) -> None:
#     765     """Update a document in the collection.
#     766
#     767     Args:
#     768         document_id: ID of the document to update.
#     769         document: Document to update.
#     770     """
# --> 771     return self.update_documents([document_id], [document])
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_chroma\vectorstores.py:793, in Chroma.update_documents(self, ids, documents)
#     787     raise ValueError(
#     788         "For update, you must specify an embedding function on creation."
#     789     )
#     790 embeddings = self._embedding_function.embed_documents(text)
#     792 if hasattr(
# --> 793     self._collection._client, "max_batch_size"
#     794 ):  # for Chroma 0.4.10 and above
#     795     from chromadb.utils.batch_utils import create_batches
#     797     for batch in create_batches(
#     798         api=self._collection._client,
#     799         ids=ids,
#    (...)
#     802         embeddings=embeddings,  # type: ignore
#     803     ):
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_chroma\vectorstores.py:221, in Chroma._collection(self)
#     219 """Returns the underlying Chroma collection or throws an exception."""
#     220 if self._chroma_collection is None:
# --> 221     raise ValueError(
#     222         "Chroma collection not initialized. "
#     223         "Use `reset_collection` to re-create and initialize the collection. "
#     224     )
#     225 return self._chroma_collection
#
# ValueError: Chroma collection not initialized. Use `reset_collection` to re-create and initialize the collection.

# %%
counter = 0
for x in range(len(uuids)):
    counter += 1
    print(counter, vector_store.get(uuids[x]))
    for key, val in vector_store.get(uuids[x]).items():
        print(f"\nkey: {key} ; value: {val}")
#vector_store.delete_collection()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 4
#       2 for x in range(len(uuids)):
#       3     counter += 1
# ----> 4     print(counter, vector_store.get(uuids[x]))
#       5     for key, val in vector_store.get(uuids[x]).items():
#       6         print(f"\nkey: {key} ; value: {val}")
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_chroma\vectorstores.py:762, in Chroma.get(self, ids, where, limit, offset, where_document, include)
#     759 if include is not None:
#     760     kwargs["include"] = include
# --> 762 return self._collection.get(**kwargs)
#
# File c:\Users\Admin\miniconda3\envs\talk2_medical_analysis\Lib\site-packages\langchain_chroma\vectorstores.py:221, in Chroma._collection(self)
#     219 """Returns the underlying Chroma collection or throws an exception."""
#     220 if self._chroma_collection is None:
# --> 221     raise ValueError(
#     222         "Chroma collection not initialized. "
#     223         "Use `reset_collection` to re-create and initialize the collection. "
#     224     )
#     225 return self._chroma_collection
#
# ValueError: Chroma collection not initialized. Use `reset_collection` to re-create and initialize the collection.

# %%
from langchain_openai import OpenAIEmbeddings

embeddings_model = OpenAIEmbeddings()

# %%
embeddings = embeddings_model.embed_documents(
    [
        "Hi there!",
        "Oh, hello!",
        "What's your name?",
        "My friends call me World",
        "Hello World!"
    ]
)
len(embeddings), len(embeddings[0])
# Out:
# (5, 1536)

# %%
embedded_query = embeddings_model.embed_query("What was the name mentioned in the conversation?")
embedded_query[:50]
# Out:
# [0.005377273540943861,
#  -0.0006527779041789472,
#  0.038980286568403244,
#  -0.002967397216707468,
#  -0.008834563195705414,
#  0.0211923960596323,
#  -0.017154492437839508,
#  -0.0017368923872709274,
#  -0.003005335107445717,
#  -0.010418055579066277,
#  0.022393209859728813,
#  0.009157859720289707,
#  0.003971925005316734,
#  -0.00932280719280243,
#  -0.010154140181839466,
#  0.002856882754713297,
#  0.0364203080534935,
#  0.0043216124176979065,
#  0.020572194829583168,
#  -0.03235601261258125,
#  -0.0032214156817644835,
#  -0.0056642815470695496,
#  0.0015241106739267707,
#  0.02623317763209343,
#  -0.011434128507971764,
#  0.019648492336273193,
#  0.02815975993871689,
#  -0.01842128485441208,
#  -0.002541834022849798,
#  -0.016824597492814064,
#  0.011434128507971764,
#  0.0010465889936313033,
#  -0.01475286390632391,
#  0.006822209805250168,
#  -0.05090925469994545,
#  -0.003925739787518978,
#  0.005565313156694174,
#  -0.017867064103484154,
#  0.02668183296918869,
#  0.004661403596401215,
#  0.022775888442993164,
#  0.001755036530084908,
#  -0.005403664894402027,
#  -0.017946237698197365,
#  -0.018922723829746246,
#  0.024649685248732567,
#  0.006653963588178158,
#  0.007653542794287205,
#  -0.01411946676671505,
#  0.014251423999667168]

# %%
# Build a sample vectorDB
from langchain_chroma import Chroma
from langchain_community.document_loaders import WebBaseLoader
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Load blog post
loader = WebBaseLoader("https://lilianweng.github.io/posts/2023-06-23-agent/")
data = loader.load()

# Split
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=0)
splits = text_splitter.split_documents(data)

# VectorDB
embedding = OpenAIEmbeddings(model="text-embedding-3-large")
vectordb = Chroma.from_documents(documents=splits, embedding=embedding)

# %%
from langchain.retrievers.multi_query import MultiQueryRetriever
from langchain_openai import ChatOpenAI

question = "What are the approaches to Task Decomposition?"
llm = ChatOpenAI(temperature=0)
retriever_from_llm = MultiQueryRetriever.from_llm(
    retriever=vectordb.as_retriever(), llm=llm
)

# %%
# Set logging for the queries
import logging

logging.basicConfig()
logging.getLogger("langchain.retrievers.multi_query").setLevel(logging.INFO)

# %%
unique_docs = retriever_from_llm.invoke(question)
len(unique_docs)
# Out:
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. How can Task Decomposition be achieved through different methods?', '2. What strategies are commonly used for Task Decomposition?', '3. In what ways can Task Decomposition be approached and implemented effectively?']
# 4

# %%
from typing import List

from langchain_core.output_parsers import BaseOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field


# Output parser will split the LLM result into a list of queries
class LineListOutputParser(BaseOutputParser[List[str]]):
    """Output parser for a list of lines."""

    def parse(self, text: str) -> List[str]:
        lines = text.strip().split("\n")
        return list(filter(None, lines))  # Remove empty lines


output_parser = LineListOutputParser()

QUERY_PROMPT = PromptTemplate(
    input_variables=["question"],
    template="""You are an AI language model assistant. Your task is to generate five 
    different versions of the given user question to retrieve relevant documents from a vector 
    database. By generating multiple perspectives on the user question, your goal is to help
    the user overcome some of the limitations of the distance-based similarity search. 
    Provide these alternative questions separated by newlines.
    Original question: {question}""",
)
llm = ChatOpenAI(temperature=0)

# Chain
llm_chain = QUERY_PROMPT | llm | output_parser

# Other inputs
question = "What are the approaches to Task Decomposition?"

# %%
# Run
retriever = MultiQueryRetriever(
    retriever=vectordb.as_retriever(), llm_chain=llm_chain, parser_key="lines"
)  # "lines" is the key (attribute name) of the parsed output

# Results
unique_docs = retriever.invoke("What does the course say about regression?")
len(unique_docs)
# Out:
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. Can you provide insights from the course on regression analysis?', '2. How is regression discussed in the course material?', '3. What topics related to regression are covered in the course?', '4. What information does the course offer about regression techniques?', '5. In what ways does the course address the topic of regression?']
# 9
